# %%
import pandas as pd
import re
import os
import sys
import pickle as pkl
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import json

df_annotations = pd.read_csv("../../data/ctgov/annotations/all_annotations.csv")

# %% [markdown]
# # Get data

# %%
with open("../../data/ctgov/protocols.pkl.gz", "rb") as f:
    file_to_pages = pkl.load(f)

# %%
texts = []

for i in range(len(df_annotations)):
    file_name = df_annotations.file.iloc[i]
    
    pages= file_to_pages[file_name]

    texts.append(" ".join(pages))
df_annotations["text"] = texts

# %%
del file_to_pages

# %%
df_annotations_num_arms_known = df_annotations[~df_annotations.num_arms.isna()]

# %%
df_annotations_num_arms_known = df_annotations_num_arms_known.sample(1000)

# %%
def get_num_arms_clean(num):
    if num >= 5:
        num = 5
    return num
df_annotations_num_arms_known["num_arms_clean"] = df_annotations_num_arms_known["num_arms"].apply(get_num_arms_clean)

# %% [markdown]
# # Train and evaluate the number of arms extractor

# %%
sys.path.append("../../front_end")
from util.page_tokeniser import tokenise_pages, tokenise_text, tokenise_text_and_lowercase

# %%
import spacy
from spacy.matcher import Matcher
import spacy

nlp = spacy.load('en_core_web_sm', disable=['ner', 'tagger', 'parser', 'lemmatizer'])

# %%
word2num = {'one': 1,
 'two': 2,
 'three': 3,
 'four': 4,
 'five': 5,
 'six': 6,
 'seven': 7,
 'eight': 8,
 'nine': 9,
 'ten': 10,
 'eleven': 11,
 'twelve': 12,
 'thirteen': 13,
 'fourteen': 14,
 'fifteen': 15,
 'sixteen': 16,
 'seventeen': 17,
 'eighteen': 18,
 'nineteen': 19,
 'both': 2,
 'single': 2}

# %%
number_words = list(word2num)

# %%
for n in range(1, 20):
    word2num[str(n)]= n

# %%
numbers_above_3 = list([w for w in word2num if word2num[w] >= 3])

# %%
matcher = Matcher(nlp.vocab)
patterns = [ #[{"LIKE_NUM":True},  {"LOWER": {"IN": ["treatment", "study", "dose"]}, "OP":"?"}, {"LOWER": {"IN": ["arm", "arms", "group", "groups", "subgroup", "subgroups", "cohort", "cohorts"]}}],
           [{"LOWER":{"IN":number_words}},  {"LOWER": {"IN": ["treatment", "study", "dose"]}}, {"LOWER": {"IN": ["arm", "arms", "group", "groups", "subgroup", "subgroups", "cohort", "cohorts"]}}],
#            [{"LOWER":{"IN":number_words}},  {"LOWER": {"IN": ["group", "groups", "subgroup", "subgroups", "cohort", "cohorts"]}}],
             [{"LOWER":{"IN":list(word2num)}},{"LOWER":"-", "OP":"?"}, {"LOWER": {"IN": [ "armed"]}}],
        [{"LOWER":{"IN":["the", "with", "between", "of", "into", "to"]}}, {"LOWER":{"IN":list(word2num)}},{"LOWER":{"IN": ["treatment", "study", "dose"]}, "OP":"?"}, {"LOWER": {"IN": ["arm", "arms", "group", "groups", "subgroup", "subgroups", "cohort", "cohorts"]}}]
]
matcher.add("arms", patterns)

# %%
doc = spacy.tokens.doc.Doc(
            nlp.vocab, words=["5", "arms"])
matcher(doc)
# Out:
# []

# %%
#tokenised_pages = [["5", "arms"]]
# if True:
def process(self, tokenised_pages: list) -> tuple:
    """
    Identify the trial phase.
    :param tokenised_pages: List of lists of tokens of each page.
    :return: The prediction (str) and a map from phase to the pages it's mentioned in.
    """

    tokenised_pages = [[string.lower() for string in sublist] for sublist in tokenised_pages]

    phase_to_pages = {}

    for page_number, page_tokens in enumerate(tokenised_pages):
        doc = spacy.tokens.doc.Doc(
            nlp.vocab, words=page_tokens)
        matches = matcher(doc)
        for word, start, end in matches:
            phase_number = doc[start:end]
            if phase_number not in phase_to_pages:
                phase_to_pages[phase_number] = []
            phase_to_pages[phase_number].append(page_number)

    phase_to_pages = sorted(phase_to_pages.items(), key=lambda v: min(v[1]))

    prediction = 0
    if len(phase_to_pages) == 1 or \
        (len(phase_to_pages) > 1 and min(phase_to_pages[0][1]) < min(phase_to_pages[1][1])):
        for word in phase_to_pages[0][0]:
            if word.text in word2num:
                prediction = word2num[word.text]
                break
    if prediction > 5:
        prediction = 5
                
    phase_to_pages = [(phrase.text, value) for phrase, value in phase_to_pages]

    return {"prediction": prediction, "pages": dict(phase_to_pages)}

# %%
df_val = df_annotations_num_arms_known[df_annotations_num_arms_known.train_val == "val"]

# %%
df_train = df_annotations_num_arms_known[df_annotations_num_arms_known.train_val == "train"]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, auc, roc_curve
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.pipeline import make_pipeline

# %%
VOCAB = {"assignment arm",
"single arm",
"experimental arm",
"two arms",
"study arms",
"control arm",
"placebo arm",
"both arms",
"three arm",
"treated arm",
"each arm",
"per arm",
"treatment arms",
"placebo arms",
"intervention arm",
"interventions arm",
"intervention arms",
"parallel arms",
"1 arm",
"chemotherapy arm",
"between arms",
"study arm",
"second arm",
"imaging arm",
"dose arm",
"control arms",
"3 arm",
"2 arm",
"active arms",
"comparator arm",
"vaccine arm",
"injection arm",
"vaccine arms",
"adjuvanted arms",
"across arms",
"boost arms",
"blinded arm",
"by arm",
"comparing arms",
"reference arms",
"two arm",
"therapy arms",
"three arms",
"interventional arm",
"observation arms",
"monotherapy arms",
"therapy arm",
"3 arms",
"combination arms",
"monotherapy arm",
"treatments arm",
"chemotherapy arms",
"radiation arms",
"all arms",
"measurement arm",
"radiotherapy arm",
"investigational arm",
"4 arm",
"radiation arm",
"immunotherapy arm",
"5 arms",
"5 arm",
"4 arms",
"doses arm",
"regimen arm",
"multiple arm",
"various arms",
"ii arm",
"iii arm",
"iv arm",
"vi arm",
"vii arm",
"viii arm",
"ix arm",
"cancer arm",
"excluded arm",
"carcinoma arm",
"observational arm",
"procedure arm",
"allocation arm",
"allocation arms",
"trial arm",
"independent arms",
"dosing arms",
"dosing arm",
"schedule arm",
"schedules arms",
"controlled arm",
"care arms",
"randomized arms",
"18 arm",
"single armed",
"one armed",
"response arm",
"multi arm",
"experimental arms",
"investigational arms",
"randomized arm",
"diabetic arms",
"diabetic arm",
"patient arms"}

# %%
for v in list(VOCAB):
    if "arm" in v:
        VOCAB.add(re.sub("arm", "cohort", v))

# %%
for i in word2num:
    VOCAB.add(f"{i} arm")
    VOCAB.add(f"{i} arms")
    VOCAB.add(f"{i} cohort")
    VOCAB.add(f"{i} cohorts")
    VOCAB.add(f"{i} armed")
    VOCAB.add(f"{i} study")
    VOCAB.add(f"{i} investigational")
    VOCAB.add(f"{i} dose")
    VOCAB.add(f"{i} treatment")

# %%
VOCAB = VOCAB.union({
                                "arm", "group", "subgroup", "cohort", "arms", "groups", "subgroups", "cohorts",
                    "randomise", "randomize", "randomisation", "randomization", "randomised", "randomized",
                    "placebo", "unblinded", "unblinding", "blinded", "blinding", "blind", "compare", "double",
                    "controlled", "control", "differences", "vs", "outcomes", "hypothesis", "experimental", "compared",
                    "effects", "variables", "variables", "ratio", "versus", "outcome", "monotherapy", "polytherapy", "proprietary",
                    "criterion", "healthy", "remission", "separately", "separate", "separated", "assay", "dosing", "dose", "doses",
                    "treatment", "treatments", "study", "studies", "either", "both",
                            "metastatic", "metastases", "metastasis", "measurable", "transplant",
                            "refractory","recist", "tumor", "insulin", "cognitive", "discharge",
                            "dsmb", "itt", "block","mortality", "scores", "questionnaire",
                            "recruitment", "power", "item", "controlled","participants", "children",
                            "side", "sided", "unit", "dmc", "alpha", "beta", "inflammatory",
                            "outcomes", "effects", "cardiac", "average", "significance",
                            "intervention","sap","adherence", "database", "primary", "standard", "trial",
                            "statistical", "factors", "significantly", "unscheduled", "amended",
                            "three", "two", "four", "five", "six", "seven", "eight", "nine"})

# %%
NUM_FEATURES = 1500

stops = set(stopwords.words('english')).union(set(stopwords.words('french')))
stops.remove("both")
stops.remove("all")

# Specially engineered regex to include 95%, 95%ci, etc
vectoriser = CountVectorizer(lowercase=True,
                             token_pattern=r'[a-z][a-z]+|\d+', 
                            ngram_range=[1,2],
                            vocabulary=VOCAB)
transformer = TfidfTransformer()

nb = MultinomialNB()
nb = ComplementNB()
model = make_pipeline(vectoriser, transformer, nb)

# %%
df_train.num_arms_clean.value_counts()
# Out:
# 2.0    343
# 1.0    212
# 3.0    118
# 5.0     67
# 4.0     65
# Name: num_arms_clean, dtype: int64

# %%
model.fit(df_train.text, df_train.num_arms_clean)
# Out:
# Pipeline(steps=[('countvectorizer',
#                  CountVectorizer(ngram_range=[1, 2],
#                                  token_pattern='[a-z][a-z]+|\\d+',
#                                  vocabulary={'1 arm', '1 armed', '1 arms',
#                                              '1 cohort', '1 cohorts', '1 dose',
#                                              '1 investigational', '1 study',
#                                              '1 treatment', '10 arm',
#                                              '10 armed', '10 arms', '10 cohort',
#                                              '10 cohorts', '10 dose',
#                                              '10 investigational', '10 study',
#                                              '10 treatment', '11 arm',
#                                              '11 armed', '11 arms', '11 cohort',
#                                              '11 cohorts', '11 dose',
#                                              '11 investigational', '11 study',
#                                              '11 treatment', '12 arm',
#                                              '12 armed', '12 arms', ...})),
#                 ('tfidftransformer', TfidfTransformer()),
#                 ('complementnb', ComplementNB())])

# %%
#df_val["pred_num_arms_nb"]  = model.predict(df_val.text.apply(lambda t : " ".join(t)))
df_val["pred_num_arms_nb"]  = model.predict(df_val.text)
# Out:
# /tmp/ipykernel_7891/2795239110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["pred_num_arms_nb"]  = model.predict(df_val.text)

# %%
df_val.pred_num_arms_nb.value_counts()
# Out:
# 2.0    67
# 1.0    28
# 5.0     1
# Name: pred_num_arms_nb, dtype: int64

# %%
def get_num_arms_and_pages(text):
    pages = [text]
    toks = tokenise_pages(pages)
    result = process(None, toks)
    return result

# %%
spacy_output = df_val.text.apply(get_num_arms_and_pages)
df_val["pred_num_arms_spacy"] = spacy_output.apply(lambda x : x["prediction"])
df_val["pages"] = spacy_output.apply(lambda x : x["pages"])
# Out:
# /tmp/ipykernel_7891/1696606368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["pred_num_arms_spacy"] = spacy_output.apply(lambda x : x["prediction"])
# /tmp/ipykernel_7891/1696606368.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["pages"] = spacy_output.apply(lambda x : x["pages"])

# %%
df_val["pred_num_arms_spacy"].value_counts()
# Out:
# 0    80
# 2    14
# 5     2
# Name: pred_num_arms_spacy, dtype: int64

# %%
pred_num_arms = []
for i in range(len(df_val)):
    if df_val.pred_num_arms_spacy.iloc[i] > 0:
        pred = df_val.pred_num_arms_spacy.iloc[i]
    else:
        pred = df_val.pred_num_arms_nb.iloc[i]
    pred_num_arms.append(pred)
df_val["pred_num_arms"] = pred_num_arms
pred_num_arms= df_val["pred_num_arms"]
# Out:
# /tmp/ipykernel_7891/521656970.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["pred_num_arms"] = pred_num_arms

# %%
pred_num_arms
# Out:
# 920      2.0
# 6088     2.0
# 8838     1.0
# 11672    1.0
# 3082     2.0
#         ...
# 4940     2.0
# 10248    1.0
# 988      2.0
# 227      2.0
# 4578     5.0
# Name: pred_num_arms, Length: 96, dtype: float64

# %%
pred_num_arms.value_counts()
# Out:
# 2.0    69
# 1.0    25
# 5.0     2
# Name: pred_num_arms, dtype: int64

# %%
num_arms_ground_truths = df_val.num_arms_clean

# %%
acc = accuracy_score(num_arms_ground_truths, pred_num_arms)
print (f"Num arms accuracy {acc}")
# Out:
# Num arms accuracy 0.5416666666666666

# %%
ConfusionMatrixDisplay.from_predictions(num_arms_ground_truths, pred_num_arms)
plt.xticks(rotation=90)
;
# Out:
# ''

# %%
accuracy_score(num_arms_ground_truths[pred_num_arms > 0], pred_num_arms[pred_num_arms > 0])
# Out:
# 0.5416666666666666

# %%
for i in range(len(df_val)):
    print (df_val.num_arms_clean.iloc[i], df_val.pages.iloc[i])
# Out:
# 2.0 {'the two cohorts': [0]}
# 2.0 {'both treatment arms': [0], 'the two groups': [0]}
# 2.0 {'two treatment arms': [0], 'the two treatment arms': [0]}
# 1.0 {}
# 2.0 {'three dose groups': [0], 'the three dose groups': [0], 'both treatment groups': [0]}
# 5.0 {'five treatment groups': [0], 'of five treatment groups': [0], 'into 5 treatment groups': [0], 'two treatment groups': [0], 'into two groups': [0], 'the two treatment groups': [0], 'of two groups': [0], 'the two groups': [0], 'two dose groups': [0], 'the two dose groups': [0], 'four treatment groups': [0], 'to 3 group': [0]}
# 2.0 {'of 2 treatment groups': [0], 'to both groups': [0], 'both treatment groups': [0], 'to both treatment groups': [0]}
# 2.0 {'of 2 arms': [0], 'between two groups': [0]}
# 2.0 {}
# 3.0 {'into two cohorts': [0], 'two treatment arms': [0], 'the two treatment arms': [0], 'two treatment groups': [0], 'the two treatment groups': [0], 'the 2 treatment arms': [0], 'the two groups': [0]}
# 2.0 {}
# 1.0 {'with 2 cohorts': [0], 'the 3 group': [0], 'eight dose groups': [0], 'the two cohorts': [0], 'with 3 cohorts': [0]}
# 2.0 {}
# 2.0 {'into 2 subgroups': [0]}
# 2.0 {'both study groups': [0], 'of 4 groups': [0], 'of 2 groups': [0]}
# 2.0 {'of 2 treatment groups': [0]}
# 1.0 {}
# 2.0 {}
# 2.0 {}
# 2.0 {'the two groups': [0], 'into two groups': [0], 'two treatment groups': [0], 'of two treatment groups': [0], 'two treatment group': [0], 'the two treatment group': [0]}
# 1.0 {'between both arms': [0]}
# 2.0 {'the 2 treatment arms': [0]}
# 1.0 {}
# 4.0 {'the two groups': [0]}
# 2.0 {'the two groups': [0]}
# 3.0 {'three treatment groups': [0], 'the three treatment groups': [0], 'of three treatment groups': [0]}
# 3.0 {}
# 5.0 {'both treatment groups': [0], 'both treatment arms': [0], 'two treatment groups': [0], 'the two treatment groups': [0], 'eight treatment groups': [0], 'into eight treatment groups': [0], 'both study arms': [0], 'the two groups': [0]}
# 1.0 {}
# 5.0 {}
# 2.0 {'into 2 subgroups': [0]}
# 2.0 {}
# 2.0 {'two treatment groups': [0], 'the two treatment groups': [0]}
# 2.0 {'both treatment arms': [0], 'two treatment arms': [0], 'the two treatment arms': [0], 'between two treatment arms': [0], 'with both arms': [0], 'of two arms': [0]}
# 2.0 {'both treatment arms': [0], 'two treatment arms': [0], 'the two treatment arms': [0], 'the two groups': [0], 'both study arms': [0]}
# 1.0 {}
# 4.0 {}
# 1.0 {}
# 2.0 {'between both groups': [0], 'the two arms': [0]}
# 1.0 {}
# 1.0 {}
# 5.0 {'the 2 study arms': [0], 'between 2 treatment arms': [0], 'both treatment groups': [0]}
# 2.0 {}
# 4.0 {'the two arms': [0]}
# 1.0 {'the two cohorts': [0]}
# 2.0 {'to 4 cohorts': [0], 'to 2 cohorts': [0], 'both treatment groups': [0], 'two treatment groups': [0], 'the two treatment groups': [0]}
# 1.0 {'three study arms': [0], 'of three study arms': [0], 'three study groups': [0], 'the three study groups': [0]}
# 3.0 {}
# 2.0 {}
# 3.0 {}
# 3.0 {}
# 1.0 {}
# 5.0 {}
# 2.0 {'into four groups': [0], 'between three groups': [0], 'the two groups': [0]}
# 3.0 {'three treatment arms': [0], 'of three treatment arms': [0], 'the 3 groups': [0]}
# 4.0 {'of 4 treatment groups': [0], 'two treatment groups': [0], 'of two treatment groups': [0]}
# 2.0 {'the 2 treatment arms': [0], 'two treatment groups': [0], 'between two treatment groups': [0]}
# 2.0 {'of 2 treatment groups': [0], 'both treatment arms': [0], 'both treatment groups': [0]}
# 2.0 {'into 2 groups': [0], 'of 10 group': [0], 'to both groups': [0], 'to two groups': [0], 'into two groups': [0], 'two treatment arms': [0], 'of two treatment arms': [0]}
# 4.0 {}
# 3.0 {'of 18 arm': [0]}
# 4.0 {'four study groups': [0]}
# 1.0 {'two treatment groups': [0], 'between two treatment groups': [0]}
# 1.0 {}
# 2.0 {'the 2 treatment groups': [0], 'the two arms': [0], 'the two groups': [0]}
# 1.0 {}
# 2.0 {'the 2 groups': [0]}
# 1.0 {}
# 2.0 {'both treatment groups': [0]}
# 2.0 {'both treatment groups': [0]}
# 1.0 {'the single arm': [0], 'the two subgroups': [0]}
# 2.0 {'two treatment arms': [0], 'the two treatment arms': [0]}
# 2.0 {'of two groups': [0]}
# 2.0 {'one treatment group': [0], 'into two arms': [0]}
# 5.0 {'single dose cohort': [0], 'of three arms': [0]}
# 2.0 {'two treatment groups': [0], 'of two treatment groups': [0]}
# 1.0 {}
# 1.0 {}
# 1.0 {'three dose cohorts': [0], 'the three dose cohorts': [0]}
# 1.0 {}
# 1.0 {}
# 3.0 {}
# 2.0 {'the two groups': [0]}
# 1.0 {}
# 2.0 {'two treatment groups': [0], 'both treatment groups': [0]}
# 5.0 {'four treatment arms': [0], 'the four treatment arms': [0], 'the 4 treatment arms': [0], 'the 4 arms': [0], 'two treatment groups': [0], 'the two treatment groups': [0]}
# 2.0 {'the two arms': [0]}
# 4.0 {}
# 2.0 {'the two groups': [0]}
# 1.0 {}
# 2.0 {}
# 1.0 {'the two groups': [0]}
# 2.0 {}
# 5.0 {'of seven groups': [0], 'of two groups': [0]}
# 1.0 {}
# 5.0 {'to 5 cohorts': [0]}

# %%
df_val
# Out:
#                                   file       nct_id train_val  num_arms  \
# 920        07_NCT03883607_Prot_000.pdf  NCT03883607       val       2.0
# 6088   51_NCT01826851_Prot_SAP_000.pdf  NCT01826851       val       2.0
# 8838       74_NCT02823574_Prot_000.pdf  NCT02823574       val       2.0
# 11672  98_NCT01807598_Prot_SAP_000.pdf  NCT01807598       val       1.0
# 3082   25_NCT04805125_Prot_SAP_000.pdf  NCT04805125       val       2.0
# ...                                ...          ...       ...       ...
# 4940       41_NCT02859441_Prot_000.pdf  NCT02859441       val       1.0
# 10248      86_NCT01889186_Prot_000.pdf  NCT01889186       val       2.0
# 988    08_NCT02814708_Prot_SAP_000.pdf  NCT02814708       val       7.0
# 227    01_NCT03852901_Prot_SAP_000.pdf  NCT03852901       val       1.0
# 4578       38_NCT02865538_Prot_000.pdf  NCT02865538       val       5.0
#
#        num_subjects            phase intervention_type  \
# 920             NaN          Phase 2              Drug
# 6088            NaN          Phase 2              Drug
# 8838            NaN          Phase 2        Biological
# 11672           NaN          Phase 2              Drug
# 3082            NaN          Phase 3        Biological
# ...             ...              ...               ...
# 4940            NaN  Phase 1/Phase 2              Drug
# 10248           NaN          Phase 2              Drug
# 988             NaN          Phase 2        Biological
# 227             NaN          Phase 1              Drug
# 4578            NaN  Phase 1/Phase 2              Drug
#
#                                                  country  has_sap  \
# 920                                                   US        0
# 6088                                                  US        1
# 8838   US,AR,BE,BR,CA,CL,CZ,FI,FR,IE,IT,MX,NL,NO,RO,R...        0
# 11672                                                 US        1
# 3082                                                  CH        1
# ...                                                  ...      ...
# 4940                                                  US        0
# 10248                               US,AU,CA,FR,DE,PL,GB        0
# 988                                                   AT        1
# 227                                                   US        1
# 4578                                                  US        0
#
#                                                     text  num_arms_clean  \
# 920    \nCli ni c al Tri al G F T 5 0 5 E -2 1 8 -1  ...             2.0
# 6088   \nParasternal intercostal nerve block in cardi...             2.0
# 8838   \n \nClinical Protocol CA209714\nBMS-936558 ni...             2.0
# 11672  \n  \n\n \nA study of brentuximab vedotin (SGN...             1.0
# 3082   \nClinical Study first sub-protocol \n \n\nRan...             2.0
# ...                                                  ...             ...
# 4940   \nER-VHL November 7, 2018 \n \n\nVersion 7.0 C...             1.0
# 10248  \nNCT01889186\n\n \nVenetoclax (ABT-199)\nM13-...             2.0
# 988    \nrTSST-1 Variant Vaccine Phase 2/ BioMED 0515...             5.0
# 227    \n \n\nCLINICAL RESEARCH PROTOCOL \nNATIONAL I...             1.0
# 4578   \n \n\n \n\n \n\nDocument Type: Study Protocol...             5.0
#
#        pred_num_arms_nb  pred_num_arms_spacy  \
# 920                 2.0                    0
# 6088                2.0                    0
# 8838                1.0                    0
# 11672               1.0                    0
# 3082                2.0                    0
# ...                 ...                  ...
# 4940                2.0                    2
# 10248               1.0                    0
# 988                 2.0                    0
# 227                 2.0                    0
# 4578                5.0                    5
#
#                                                    pages  pred_num_arms
# 920                             {'the two cohorts': [0]}            2.0
# 6088   {'both treatment arms': [0], 'the two groups':...            2.0
# 8838   {'two treatment arms': [0], 'the two treatment...            1.0
# 11672                                                 {}            1.0
# 3082   {'three dose groups': [0], 'the three dose gro...            2.0
# ...                                                  ...            ...
# 4940                             {'the two groups': [0]}            2.0
# 10248                                                 {}            1.0
# 988       {'of seven groups': [0], 'of two groups': [0]}            2.0
# 227                                                   {}            2.0
# 4578                               {'to 5 cohorts': [0]}            5.0
#
# [96 rows x 15 columns]

# %%
fake_document = " ".join(vectoriser.vocabulary_)
vectorised_document = vectoriser.transform([fake_document])
transformed_document = transformer.transform(vectorised_document)
probas = np.zeros((transformed_document.shape[1]))

for prediction_idx in range(5):
    print(f"Strongest predictors for class {prediction_idx}\n")
    for i in range(transformed_document.shape[1]):
        zeros = np.zeros(transformed_document.shape)
        zeros[0, i] = transformed_document[0, i]
        proba = nb.predict_log_proba(zeros)
        probas[i] = proba[0, prediction_idx]

    for ctr, j in enumerate(np.argsort(-probas)):
        for w, i in vectoriser.vocabulary_.items():
            if i == j:
                print(f"{ctr}\t{w}")
# Out:
# Strongest predictors for class 0
#
# 0	cohort
# 1	dose
# 2	cohorts
# 3	treatment
# 4	single arm
# 5	study
# 6	nine
# 7	two cohort
# 8	eight
# 9	six
# 10	monotherapy
# 11	metastasis
# 12	transplant
# 13	four
# 14	refractory
# 15	metastatic
# 16	ii arm
# 17	tumor
# 18	measurable
# 19	metastases
# 20	two dose
# 21	recist
# 22	treated cohort
# 23	remission
# 24	2 dose
# 25	dose cohort
# 26	three
# 27	dosing
# 28	3 dose
# 29	7 investigational
# 30	five
# 31	4 dose
# 32	8 dose
# 33	7 dose
# 34	5 dose
# 35	control cohort
# 36	doses
# 37	vaccine cohort
# 38	three dose
# 39	5 investigational
# 40	patient cohorts
# 41	11 study
# 42	children
# 43	interventional cohort
# 44	one dose
# 45	proprietary
# 46	four dose
# 47	1 investigational
# 48	observational arm
# 49	assay
# 50	1 dose
# 51	both
# 52	single study
# 53	8 investigational
# 54	4 treatment
# 55	dosing arm
# 56	amended
# 57	2 study
# 58	6 dose
# 59	6 investigational
# 60	studies
# 61	10 dose
# 62	2 investigational
# 63	5 treatment
# 64	3 cohort
# 65	3 treatment
# 66	cardiac
# 67	9 investigational
# 68	3 investigational
# 69	15 dose
# 70	one armed
# 71	1 study
# 72	comparator cohort
# 73	factors
# 74	standard
# 75	database
# 76	3 study
# 77	10 study
# 78	two
# 79	significantly
# 80	intervention
# 81	8 study
# 82	17 investigational
# 83	doses cohort
# 84	treatment cohorts
# 85	treatments
# 86	2 cohorts
# 87	hypothesis
# 88	study cohorts
# 89	14 dose
# 90	2 cohort
# 91	single cohort
# 92	trial
# 93	18 cohort
# 94	1 treatment
# 95	either
# 96	four treatment
# 97	15 treatment
# 98	5 study
# 99	4 study
# 100	beta
# 101	primary
# 102	seven
# 103	statistical
# 104	outcome
# 105	alpha
# 106	separate
# 107	radiotherapy arm
# 108	separately
# 109	6 study
# 110	therapy cohort
# 111	6 treatment
# 112	one treatment
# 113	unscheduled
# 114	2 treatment
# 115	19 dose
# 116	7 study
# 117	control arms
# 118	single treatment
# 119	each cohort
# 120	assignment cohort
# 121	second cohort
# 122	12 study
# 123	inflammatory
# 124	separated
# 125	effects
# 126	single dose
# 127	carcinoma cohort
# 128	dosing cohorts
# 129	mortality
# 130	participants
# 131	compared
# 132	schedule arm
# 133	17 treatment
# 134	average
# 135	recruitment
# 136	side
# 137	control cohorts
# 138	versus
# 139	healthy
# 140	cancer arm
# 141	significance
# 142	19 cohorts
# 143	14 study
# 144	13 investigational
# 145	radiotherapy cohort
# 146	measurement arm
# 147	unit
# 148	six dose
# 149	both study
# 150	1 cohort
# 151	9 study
# 152	18 investigational
# 153	criterion
# 154	outcomes
# 155	three cohorts
# 156	15 study
# 157	11 dose
# 158	per cohort
# 159	chemotherapy cohort
# 160	ratio
# 161	16 study
# 162	across cohorts
# 163	vs
# 164	5 cohort
# 165	cancer cohort
# 166	all cohorts
# 167	study cohort
# 168	nine study
# 169	cognitive
# 170	7 treatment
# 171	group
# 172	16 treatment
# 173	13 study
# 174	by cohort
# 175	multi arm
# 176	one study
# 177	subgroups
# 178	differences
# 179	15 investigational
# 180	polytherapy
# 181	both investigational
# 182	12 dose
# 183	4 cohort
# 184	sided
# 185	power
# 186	both dose
# 187	fifteen study
# 188	9 dose
# 189	independent cohorts
# 190	dsmb
# 191	adherence
# 192	four cohorts
# 193	variables
# 194	both cohorts
# 195	four cohort
# 196	8 cohort
# 197	18 treatment
# 198	8 treatment
# 199	1 arm
# 200	15 cohorts
# 201	16 cohorts
# 202	17 cohorts
# 203	blinding
# 204	12 cohort
# 205	14 cohort
# 206	4 arms
# 207	11 treatment
# 208	item
# 209	sap
# 210	12 cohorts
# 211	14 cohorts
# 212	13 dose
# 213	14 treatment
# 214	one cohort
# 215	eleven cohort
# 216	questionnaire
# 217	groups
# 218	13 treatment
# 219	radiation arm
# 220	regimen cohort
# 221	multi cohort
# 222	7 cohorts
# 223	6 cohort
# 224	vaccine arm
# 225	subgroup
# 226	five dose
# 227	16 dose
# 228	10 treatment
# 229	two investigational
# 230	1 cohorts
# 231	trial cohort
# 232	between cohorts
# 233	dose arm
# 234	single armed
# 235	4 investigational
# 236	chemotherapy arm
# 237	5 cohorts
# 238	17 study
# 239	compare
# 240	three study
# 241	12 treatment
# 242	double
# 243	combination arms
# 244	both cohort
# 245	four study
# 246	12 arm
# 247	randomised
# 248	imaging arm
# 249	intervention arm
# 250	therapy cohorts
# 251	both arm
# 252	excluded arm
# 253	vii arm
# 254	ix arm
# 255	vi arm
# 256	viii arm
# 257	iii arm
# 258	carcinoma arm
# 259	vaccine cohorts
# 260	17 arm
# 261	controlled cohort
# 262	interventions arm
# 263	five study
# 264	reference arms
# 265	assignment arm
# 266	response arm
# 267	2 armed
# 268	13 arms
# 269	placebo cohorts
# 270	16 cohort
# 271	13 cohort
# 272	twelve study
# 273	five arm
# 274	across arms
# 275	dosing arms
# 276	19 arm
# 277	various arms
# 278	multiple arm
# 279	10 arm
# 280	seven dose
# 281	8 arm
# 282	19 study
# 283	7 arm
# 284	twelve cohort
# 285	vaccine arms
# 286	randomized cohort
# 287	17 dose
# 288	18 dose
# 289	9 cohorts
# 290	investigational arms
# 291	7 cohort
# 292	treatments arm
# 293	ii cohort
# 294	injection arm
# 295	two cohorts
# 296	18 arm
# 297	13 arm
# 298	seven cohorts
# 299	patient arms
# 300	11 cohort
# 301	controlled arm
# 302	four investigational
# 303	immunotherapy arm
# 304	placebo arm
# 305	9 cohort
# 306	response cohort
# 307	procedure arm
# 308	16 armed
# 309	schedules arms
# 310	schedules cohorts
# 311	nineteen dose
# 312	procedure cohort
# 313	17 arms
# 314	observation cohorts
# 315	17 armed
# 316	nineteen treatment
# 317	nineteen study
# 318	reference cohorts
# 319	15 armed
# 320	15 arms
# 321	15 cohort
# 322	nineteen cohorts
# 323	one cohorted
# 324	radiation arms
# 325	nineteen cohort
# 326	16 arms
# 327	one cohorts
# 328	nineteen investigational
# 329	16 investigational
# 330	observation arms
# 331	one arms
# 332	six arms
# 333	seven arm
# 334	thirteen study
# 335	thirteen investigational
# 336	thirteen dose
# 337	thirteen cohorts
# 338	thirteen cohort
# 339	thirteen arms
# 340	thirteen armed
# 341	thirteen arm
# 342	ten treatment
# 343	ten study
# 344	ten investigational
# 345	ten dose
# 346	ten cohorts
# 347	ten cohort
# 348	ten arms
# 349	thirteen treatment
# 350	three cohort
# 351	11 cohorts
# 352	11 arms
# 353	vii cohort
# 354	vi cohort
# 355	1 armed
# 356	various cohorts
# 357	10 armed
# 358	10 arms
# 359	two armed
# 360	ten armed
# 361	10 cohort
# 362	twelve investigational
# 363	twelve dose
# 364	twelve cohorts
# 365	twelve arms
# 366	twelve armed
# 367	twelve arm
# 368	11 armed
# 369	twelve treatment
# 370	14 armed
# 371	ten arm
# 372	12 arms
# 373	seventeen treatment
# 374	seventeen study
# 375	seventeen investigational
# 376	seventeen dose
# 377	seventeen cohorts
# 378	seventeen cohort
# 379	seventeen arms
# 380	seventeen armed
# 381	seventeen arm
# 382	seven treatment
# 383	seven study
# 384	seven investigational
# 385	seven cohort
# 386	seven arms
# 387	seven armed
# 388	13 cohorts
# 389	single arms
# 390	single cohorted
# 391	single cohorts
# 392	sixteen treatment
# 393	sixteen study
# 394	sixteen investigational
# 395	sixteen dose
# 396	sixteen cohorts
# 397	sixteen cohort
# 398	sixteen arms
# 399	12 armed
# 400	sixteen armed
# 401	six investigational
# 402	six cohorts
# 403	six cohort
# 404	nineteen arms
# 405	six armed
# 406	six arm
# 407	13 armed
# 408	sixteen arm
# 409	nineteen armed
# 410	9 arms
# 411	nine treatment
# 412	eighteen arms
# 413	eighteen cohort
# 414	eighteen cohorts
# 415	eighteen dose
# 416	eighteen investigational
# 417	eighteen study
# 418	eighteen treatment
# 419	nineteen arm
# 420	eleven arm
# 421	eleven armed
# 422	eleven arms
# 423	eleven cohorts
# 424	eleven dose
# 425	eleven investigational
# 426	eleven study
# 427	eleven treatment
# 428	excluded cohort
# 429	five cohorts
# 430	five cohort
# 431	five armed
# 432	viii cohort
# 433	fifteen treatment
# 434	fifteen investigational
# 435	eighteen armed
# 436	fifteen dose
# 437	fifteen cohort
# 438	fifteen arms
# 439	fifteen armed
# 440	fifteen arm
# 441	experimental cohorts
# 442	experimental cohort
# 443	fifteen cohorts
# 444	eighteen arm
# 445	eight treatment
# 446	eight investigational
# 447	7 armed
# 448	7 arms
# 449	both armed
# 450	boost cohorts
# 451	boost arms
# 452	blinded cohort
# 453	care cohorts
# 454	8 armed
# 455	allocation cohorts
# 456	allocation cohort
# 457	allocation arms
# 458	adjuvanted cohorts
# 459	adjuvanted arms
# 460	active cohorts
# 461	8 arms
# 462	five investigational
# 463	chemotherapy arms
# 464	comparing arms
# 465	eight dose
# 466	eight cohorts
# 467	eight cohort
# 468	eight arms
# 469	eight armed
# 470	eight arm
# 471	chemotherapy cohorts
# 472	4 armed
# 473	diabetic cohort
# 474	diabetic arms
# 475	diabetic arm
# 476	5 armed
# 477	5 arms
# 478	comparing cohorts
# 479	diabetic cohorts
# 480	four armed
# 481	17 cohort
# 482	9 armed
# 483	nine investigational
# 484	intervention cohorts
# 485	investigational cohorts
# 486	nine dose
# 487	nine cohorts
# 488	nine cohort
# 489	investigational cohort
# 490	monotherapy cohort
# 491	19 arms
# 492	iii cohort
# 493	nine armed
# 494	imaging cohort
# 495	monotherapy cohorts
# 496	nine arm
# 497	interventions cohort
# 498	independent arms
# 499	injection cohort
# 500	18 cohorts
# 501	nine arms
# 502	fourteen treatment
# 503	19 armed
# 504	fourteen investigational
# 505	ix cohort
# 506	18 arms
# 507	fourteen arm
# 508	fourteen study
# 509	fourteen armed
# 510	fourteen arms
# 511	fourteen cohort
# 512	measurement cohort
# 513	18 armed
# 514	fourteen cohorts
# 515	fourteen dose
# 516	six treatment
# 517	randomized arm
# 518	dmc
# 519	6 arms
# 520	eight study
# 521	14 arms
# 522	10 cohorts
# 523	interventional arm
# 524	care arms
# 525	16 arm
# 526	3 cohorts
# 527	treatments cohort
# 528	scores
# 529	8 cohorts
# 530	19 investigational
# 531	discharge
# 532	9 arm
# 533	three arm
# 534	12 investigational
# 535	parallel cohorts
# 536	3 arms
# 537	trial arm
# 538	blind
# 539	1 arms
# 540	therapy arms
# 541	19 treatment
# 542	4 cohorts
# 543	iv arm
# 544	six study
# 545	15 arm
# 546	controlled
# 547	four arms
# 548	blinded arm
# 549	6 arm
# 550	14 arm
# 551	combination cohorts
# 552	three investigational
# 553	19 cohort
# 554	9 treatment
# 555	allocation arm
# 556	randomized arms
# 557	four arm
# 558	control
# 559	block
# 560	dosing cohort
# 561	immunotherapy cohort
# 562	five treatment
# 563	randomization
# 564	monotherapy arm
# 565	multiple cohort
# 566	single investigational
# 567	6 armed
# 568	monotherapy arms
# 569	placebo cohort
# 570	two study
# 571	schedule cohort
# 572	doses arm
# 573	11 arm
# 574	10 investigational
# 575	radiation cohort
# 576	all arms
# 577	iv cohort
# 578	randomized cohorts
# 579	by arm
# 580	14 investigational
# 581	both arms
# 582	18 study
# 583	experimental arm
# 584	observational cohort
# 585	three armed
# 586	experimental arms
# 587	one investigational
# 588	intervention cohort
# 589	placebo arms
# 590	both treatment
# 591	6 cohorts
# 592	insulin
# 593	unblinded
# 594	parallel arms
# 595	intervention arms
# 596	unblinding
# 597	3 arm
# 598	comparator arm
# 599	between arms
# 600	treatment arms
# 601	11 investigational
# 602	3 armed
# 603	two arm
# 604	2 arms
# 605	control arm
# 606	regimen arm
# 607	randomise
# 608	five arms
# 609	5 arm
# 610	two arms
# 611	4 arm
# 612	active arms
# 613	randomize
# 614	per arm
# 615	treated arm
# 616	itt
# 617	each arm
# 618	therapy arm
# 619	radiation cohorts
# 620	three treatment
# 621	two treatment
# 622	study arms
# 623	three arms
# 624	study arm
# 625	randomisation
# 626	investigational arm
# 627	2 arm
# 628	second arm
# 629	one arm
# 630	experimental
# 631	blinded
# 632	randomized
# 633	placebo
# 634	arm
# 635	arms
# Strongest predictors for class 1
# 0	arm
# 1	arms
# 2	experimental
# 3	randomized
# 4	treatment
# 5	study
# 6	placebo
# 7	two
# 8	seven
# 9	blinded
# 10	itt
# 11	two treatment
# 12	study arm
# 13	control
# 14	block
# 15	both
# 16	control arm
# 17	insulin
# 18	two arms
# 19	controlled
# 20	one arm
# 21	scores
# 22	randomization
# 23	intervention
# 24	five
# 25	both treatment
# 26	questionnaire
# 27	dsmb
# 28	compare
# 29	both arms
# 30	discharge
# 31	cognitive
# 32	vs
# 33	subgroup
# 34	randomize
# 35	blind
# 36	unblinding
# 37	side
# 38	double
# 39	item
# 40	mortality
# 41	variables
# 42	alpha
# 43	versus
# 44	outcomes
# 45	2 arm
# 46	power
# 47	investigational arm
# 48	groups
# 49	each arm
# 50	recruitment
# 51	trial
# 52	effects
# 53	study arms
# 54	average
# 55	compared
# 56	treatment arms
# 57	beta
# 58	inflammatory
# 59	adherence
# 60	differences
# 61	ratio
# 62	randomised
# 63	group
# 64	sided
# 65	second arm
# 66	hypothesis
# 67	unblinded
# 68	randomisation
# 69	experimental arm
# 70	significance
# 71	unit
# 72	outcome
# 73	blinding
# 74	significantly
# 75	treatments
# 76	standard
# 77	2 treatment
# 78	primary
# 79	factors
# 80	participants
# 81	database
# 82	either
# 83	statistical
# 84	placebo arm
# 85	cardiac
# 86	children
# 87	studies
# 88	separate
# 89	three
# 90	per arm
# 91	subgroups
# 92	3 study
# 93	5 study
# 94	6 treatment
# 95	criterion
# 96	9 study
# 97	6 study
# 98	1 study
# 99	amended
# 100	recist
# 101	sap
# 102	one study
# 103	two study
# 104	metastases
# 105	4 study
# 106	2 study
# 107	two arm
# 108	healthy
# 109	separately
# 110	7 study
# 111	8 treatment
# 112	10 study
# 113	therapy arm
# 114	dmc
# 115	unscheduled
# 116	16 study
# 117	four
# 118	assay
# 119	1 dose
# 120	8 study
# 121	doses
# 122	5 treatment
# 123	15 study
# 124	transplant
# 125	one dose
# 126	single dose
# 127	remission
# 128	proprietary
# 129	1 treatment
# 130	tumor
# 131	12 study
# 132	both study
# 133	4 treatment
# 134	6 dose
# 135	dosing cohort
# 136	9 treatment
# 137	separated
# 138	metastatic
# 139	measurable
# 140	3 treatment
# 141	3 investigational
# 142	10 treatment
# 143	2 dose
# 144	18 study
# 145	between cohorts
# 146	2 investigational
# 147	13 study
# 148	3 dose
# 149	14 study
# 150	7 treatment
# 151	between arms
# 152	dosing
# 153	1 investigational
# 154	metastasis
# 155	4 dose
# 156	comparator arm
# 157	placebo arms
# 158	each cohort
# 159	7 dose
# 160	one treatment
# 161	refractory
# 162	2 arms
# 163	eight
# 164	11 study
# 165	5 dose
# 166	six
# 167	randomise
# 168	intervention arm
# 169	1 arm
# 170	two cohorts
# 171	19 study
# 172	11 treatment
# 173	both investigational
# 174	by arm
# 175	6 investigational
# 176	two dose
# 177	second cohort
# 178	per cohort
# 179	study cohort
# 180	single arm
# 181	15 treatment
# 182	15 dose
# 183	10 dose
# 184	single treatment
# 185	4 investigational
# 186	16 treatment
# 187	by cohort
# 188	monotherapy
# 189	17 study
# 190	randomized cohort
# 191	both dose
# 192	7 investigational
# 193	10 investigational
# 194	four dose
# 195	1 cohort
# 196	control arms
# 197	8 dose
# 198	three dose
# 199	9 dose
# 200	monotherapy arm
# 201	both cohorts
# 202	parallel arms
# 203	2 cohorts
# 204	5 investigational
# 205	5 arm
# 206	3 cohorts
# 207	9 investigational
# 208	8 investigational
# 209	dose cohort
# 210	14 treatment
# 211	2 cohort
# 212	one cohort
# 213	19 treatment
# 214	12 treatment
# 215	single study
# 216	dosing cohorts
# 217	13 treatment
# 218	13 investigational
# 219	6 arm
# 220	all cohorts
# 221	13 dose
# 222	three study
# 223	3 arm
# 224	all arms
# 225	dose arm
# 226	placebo cohort
# 227	17 treatment
# 228	treatment cohorts
# 229	three arms
# 230	study cohorts
# 231	regimen arm
# 232	intervention cohort
# 233	ii cohort
# 234	9 arm
# 235	6 cohorts
# 236	11 investigational
# 237	12 dose
# 238	5 cohorts
# 239	16 dose
# 240	multi cohort
# 241	three treatment
# 242	multiple cohort
# 243	schedule arm
# 244	placebo cohorts
# 245	4 cohort
# 246	three cohorts
# 247	randomized arms
# 248	3 cohort
# 249	trial arm
# 250	patient cohorts
# 251	intervention arms
# 252	7 arm
# 253	doses arm
# 254	across cohorts
# 255	11 arm
# 256	18 treatment
# 257	7 cohort
# 258	observational cohort
# 259	3 arms
# 260	three arm
# 261	cancer cohort
# 262	14 dose
# 263	17 dose
# 264	6 cohort
# 265	one investigational
# 266	four cohorts
# 267	multi arm
# 268	6 armed
# 269	11 dose
# 270	5 cohort
# 271	15 investigational
# 272	combination arms
# 273	1 cohorts
# 274	four treatment
# 275	injection arm
# 276	19 dose
# 277	dosing arm
# 278	8 arm
# 279	both arm
# 280	4 cohorts
# 281	single armed
# 282	treatments arm
# 283	12 arm
# 284	two investigational
# 285	investigational arms
# 286	single cohort
# 287	six study
# 288	treatments cohort
# 289	measurement arm
# 290	allocation arm
# 291	18 dose
# 292	1 arms
# 293	19 arm
# 294	4 arms
# 295	19 investigational
# 296	8 cohort
# 297	15 arm
# 298	chemotherapy arm
# 299	therapy cohort
# 300	three investigational
# 301	six treatment
# 302	17 investigational
# 303	11 cohort
# 304	4 arm
# 305	cancer arm
# 306	eight study
# 307	across arms
# 308	blinded arm
# 309	parallel cohorts
# 310	six dose
# 311	four arms
# 312	19 cohort
# 313	treated cohort
# 314	14 cohorts
# 315	assignment arm
# 316	nine
# 317	control cohort
# 318	chemotherapy cohort
# 319	regimen cohort
# 320	iv arm
# 321	nine study
# 322	trial cohort
# 323	care arms
# 324	interventional arm
# 325	14 arm
# 326	experimental arms
# 327	active arms
# 328	8 cohorts
# 329	imaging arm
# 330	randomized arm
# 331	iv cohort
# 332	assignment cohort
# 333	patient arms
# 334	therapy arms
# 335	immunotherapy arm
# 336	four investigational
# 337	12 investigational
# 338	13 arm
# 339	four study
# 340	18 arm
# 341	doses cohort
# 342	therapy cohorts
# 343	vaccine arms
# 344	7 cohorts
# 345	twelve cohort
# 346	vaccine arm
# 347	dosing arms
# 348	five treatment
# 349	12 cohorts
# 350	9 cohorts
# 351	various arms
# 352	multiple arm
# 353	9 cohort
# 354	13 cohort
# 355	16 cohort
# 356	monotherapy arms
# 357	13 arms
# 358	2 armed
# 359	response arm
# 360	18 investigational
# 361	17 arm
# 362	18 cohort
# 363	vi arm
# 364	ix arm
# 365	carcinoma arm
# 366	viii arm
# 367	vii arm
# 368	excluded arm
# 369	iii arm
# 370	treated arm
# 371	combination cohorts
# 372	schedule cohort
# 373	both cohort
# 374	vaccine cohorts
# 375	controlled cohort
# 376	interventions arm
# 377	five study
# 378	reference arms
# 379	five dose
# 380	twelve study
# 381	five arm
# 382	radiation arm
# 383	10 arm
# 384	seven dose
# 385	eleven cohort
# 386	seven cohorts
# 387	14 cohort
# 388	12 cohort
# 389	17 cohorts
# 390	16 cohorts
# 391	15 cohorts
# 392	controlled arm
# 393	four cohort
# 394	6 arms
# 395	independent cohorts
# 396	fifteen study
# 397	14 arms
# 398	10 cohorts
# 399	16 arm
# 400	polytherapy
# 401	three armed
# 402	radiotherapy cohort
# 403	19 cohorts
# 404	control cohorts
# 405	observational arm
# 406	carcinoma cohort
# 407	four arm
# 408	radiotherapy arm
# 409	immunotherapy cohort
# 410	single investigational
# 411	comparator cohort
# 412	one armed
# 413	radiation cohort
# 414	randomized cohorts
# 415	interventional cohort
# 416	vaccine cohort
# 417	ii arm
# 418	3 armed
# 419	six cohorts
# 420	single cohorts
# 421	sixteen dose
# 422	allocation cohort
# 423	sixteen investigational
# 424	12 armed
# 425	single cohorted
# 426	sixteen study
# 427	boost arms
# 428	sixteen treatment
# 429	seventeen treatment
# 430	adjuvanted cohorts
# 431	adjuvanted arms
# 432	sixteen cohorts
# 433	sixteen armed
# 434	sixteen arms
# 435	active cohorts
# 436	sixteen arm
# 437	six arm
# 438	blinded cohort
# 439	allocation cohorts
# 440	single arms
# 441	six armed
# 442	six arms
# 443	allocation arms
# 444	six cohort
# 445	12 arms
# 446	six investigational
# 447	sixteen cohort
# 448	9 arms
# 449	thirteen armed
# 450	8 arms
# 451	18 armed
# 452	17 cohort
# 453	17 arms
# 454	17 armed
# 455	16 investigational
# 456	16 arms
# 457	16 armed
# 458	twelve arm
# 459	twelve armed
# 460	twelve arms
# 461	twelve cohorts
# 462	twelve dose
# 463	twelve investigational
# 464	twelve treatment
# 465	15 cohort
# 466	two armed
# 467	15 arms
# 468	15 armed
# 469	1 armed
# 470	14 armed
# 471	13 cohorts
# 472	13 armed
# 473	various cohorts
# 474	vi cohort
# 475	vii cohort
# 476	18 arms
# 477	9 armed
# 478	18 cohorts
# 479	19 armed
# 480	8 armed
# 481	7 arms
# 482	7 armed
# 483	5 arms
# 484	5 armed
# 485	ten arm
# 486	ten armed
# 487	ten arms
# 488	ten cohort
# 489	ten cohorts
# 490	ten dose
# 491	ten investigational
# 492	ten study
# 493	ten treatment
# 494	4 armed
# 495	thirteen arm
# 496	seventeen study
# 497	thirteen arms
# 498	thirteen cohort
# 499	thirteen cohorts
# 500	thirteen dose
# 501	thirteen investigational
# 502	thirteen study
# 503	thirteen treatment
# 504	19 arms
# 505	three cohort
# 506	seventeen investigational
# 507	fourteen arm
# 508	seventeen cohorts
# 509	measurement cohort
# 510	experimental cohort
# 511	excluded cohort
# 512	eleven treatment
# 513	eleven study
# 514	monotherapy cohort
# 515	monotherapy cohorts
# 516	eleven investigational
# 517	eleven dose
# 518	eleven cohorts
# 519	eleven arms
# 520	nine arm
# 521	nine armed
# 522	nine arms
# 523	nine cohort
# 524	nine cohorts
# 525	nine dose
# 526	nine investigational
# 527	eleven armed
# 528	nine treatment
# 529	nineteen arm
# 530	nineteen armed
# 531	nineteen arms
# 532	nineteen cohort
# 533	nineteen cohorts
# 534	nineteen dose
# 535	nineteen investigational
# 536	experimental cohorts
# 537	fifteen arm
# 538	ix cohort
# 539	fifteen armed
# 540	fourteen armed
# 541	fourteen arms
# 542	fourteen cohort
# 543	fourteen cohorts
# 544	fourteen dose
# 545	fourteen investigational
# 546	fourteen study
# 547	fourteen treatment
# 548	four armed
# 549	iii cohort
# 550	five investigational
# 551	imaging cohort
# 552	independent arms
# 553	seventeen dose
# 554	five cohorts
# 555	injection cohort
# 556	five armed
# 557	viii cohort
# 558	fifteen treatment
# 559	intervention cohorts
# 560	interventions cohort
# 561	fifteen investigational
# 562	fifteen dose
# 563	investigational cohort
# 564	investigational cohorts
# 565	fifteen cohorts
# 566	fifteen cohort
# 567	fifteen arms
# 568	five cohort
# 569	nineteen treatment
# 570	nineteen study
# 571	observation cohorts
# 572	observation arms
# 573	10 armed
# 574	diabetic arm
# 575	11 arms
# 576	11 cohorts
# 577	comparing cohorts
# 578	reference cohorts
# 579	comparing arms
# 580	response cohort
# 581	chemotherapy cohorts
# 582	schedules arms
# 583	schedules cohorts
# 584	diabetic cohort
# 585	chemotherapy arms
# 586	boost cohorts
# 587	seven arm
# 588	seven armed
# 589	seven arms
# 590	seven cohort
# 591	seven investigational
# 592	seven study
# 593	seven treatment
# 594	seventeen arm
# 595	seventeen armed
# 596	seventeen arms
# 597	seventeen cohort
# 598	both armed
# 599	diabetic cohorts
# 600	diabetic arms
# 601	radiation arms
# 602	eleven arm
# 603	one arms
# 604	eighteen treatment
# 605	one cohorted
# 606	one cohorts
# 607	eighteen study
# 608	eighteen investigational
# 609	eighteen dose
# 610	eighteen cohorts
# 611	eighteen cohort
# 612	eighteen arms
# 613	eighteen armed
# 614	eighteen arm
# 615	eight treatment
# 616	eight investigational
# 617	eight dose
# 618	eight arms
# 619	10 arms
# 620	11 armed
# 621	procedure cohort
# 622	procedure arm
# 623	eight arm
# 624	eight armed
# 625	care cohorts
# 626	eight cohort
# 627	eight cohorts
# 628	10 cohort
# 629	14 investigational
# 630	five arms
# 631	two cohort
# 632	radiation cohorts
# 633	dose
# 634	cohort
# 635	cohorts
# Strongest predictors for class 2
#
# 0	cohorts
# 1	arms
# 2	cohort
# 3	14 investigational
# 4	three treatment
# 5	radiation cohorts
# 6	three arms
# 7	treated arm
# 8	3 armed
# 9	3 arm
# 10	active arms
# 11	3 arms
# 12	randomized cohorts
# 13	dose arm
# 14	radiation cohort
# 15	one investigational
# 16	chemotherapy arm
# 17	4 investigational
# 18	three arm
# 19	4 cohorts
# 20	monotherapy arms
# 21	single investigational
# 22	four study
# 23	11 investigational
# 24	immunotherapy cohort
# 25	combination cohorts
# 26	iv arm
# 27	study cohort
# 28	1 cohorts
# 29	three study
# 30	injection arm
# 31	16 arm
# 32	all arms
# 33	experimental arms
# 34	by cohort
# 35	three cohorts
# 36	dosing arms
# 37	randomized arm
# 38	across arms
# 39	trial arm
# 40	intervention arms
# 41	9 cohort
# 42	multi cohort
# 43	five arm
# 44	twelve study
# 45	reference arms
# 46	interventions arm
# 47	fourteen cohorts
# 48	fourteen cohort
# 49	fourteen arms
# 50	diabetic cohort
# 51	eighteen arm
# 52	fourteen arm
# 53	fourteen dose
# 54	diabetic cohorts
# 55	eight arm
# 56	eight armed
# 57	fourteen armed
# 58	fourteen investigational
# 59	diabetic arms
# 60	fourteen treatment
# 61	ix cohort
# 62	chemotherapy arms
# 63	chemotherapy cohorts
# 64	investigational cohorts
# 65	investigational cohort
# 66	comparing arms
# 67	fourteen study
# 68	interventions cohort
# 69	intervention cohorts
# 70	injection cohort
# 71	diabetic arm
# 72	independent arms
# 73	imaging cohort
# 74	iii cohort
# 75	comparing cohorts
# 76	four armed
# 77	five cohorts
# 78	five cohort
# 79	eight dose
# 80	eleven cohorts
# 81	eleven arms
# 82	eleven armed
# 83	eleven arm
# 84	eighteen treatment
# 85	eight investigational
# 86	eighteen study
# 87	eighteen investigational
# 88	eighteen dose
# 89	eighteen cohorts
# 90	eight treatment
# 91	eighteen cohort
# 92	eighteen arms
# 93	eighteen armed
# 94	eight cohorts
# 95	eleven dose
# 96	eleven investigational
# 97	eleven study
# 98	five armed
# 99	viii cohort
# 100	fifteen treatment
# 101	fifteen investigational
# 102	fifteen dose
# 103	fifteen cohorts
# 104	fifteen cohort
# 105	five investigational
# 106	fifteen arms
# 107	eight arms
# 108	fifteen arm
# 109	experimental cohorts
# 110	experimental cohort
# 111	eight cohort
# 112	excluded cohort
# 113	measurement cohort
# 114	fifteen armed
# 115	twelve arm
# 116	eleven treatment
# 117	monotherapy cohorts
# 118	sixteen treatment
# 119	sixteen study
# 120	sixteen investigational
# 121	sixteen dose
# 122	sixteen cohorts
# 123	sixteen cohort
# 124	sixteen arms
# 125	sixteen armed
# 126	sixteen arm
# 127	six investigational
# 128	six cohorts
# 129	six cohort
# 130	six arms
# 131	six armed
# 132	six arm
# 133	twelve treatment
# 134	single cohorts
# 135	single cohorted
# 136	single arms
# 137	twelve investigational
# 138	seventeen treatment
# 139	ten arm
# 140	ten arms
# 141	twelve arms
# 142	twelve cohorts
# 143	twelve dose
# 144	three cohort
# 145	thirteen treatment
# 146	thirteen study
# 147	thirteen investigational
# 148	thirteen dose
# 149	thirteen cohorts
# 150	thirteen cohort
# 151	thirteen arms
# 152	thirteen armed
# 153	thirteen arm
# 154	ten treatment
# 155	ten study
# 156	ten investigational
# 157	ten dose
# 158	ten cohorts
# 159	ten cohort
# 160	ten armed
# 161	monotherapy cohort
# 162	seventeen study
# 163	seventeen dose
# 164	observation cohorts
# 165	observation arms
# 166	nineteen treatment
# 167	nineteen study
# 168	nineteen investigational
# 169	nineteen dose
# 170	nineteen cohorts
# 171	nineteen cohort
# 172	nineteen arms
# 173	nineteen armed
# 174	nineteen arm
# 175	nine treatment
# 176	nine investigational
# 177	care cohorts
# 178	nine cohorts
# 179	nine cohort
# 180	nine arms
# 181	nine armed
# 182	nine arm
# 183	one arms
# 184	seventeen investigational
# 185	one cohorted
# 186	procedure arm
# 187	seventeen cohorts
# 188	seventeen cohort
# 189	seventeen arms
# 190	seventeen armed
# 191	seventeen arm
# 192	seven treatment
# 193	seven study
# 194	seven investigational
# 195	seven cohort
# 196	seven arms
# 197	seven armed
# 198	seven arm
# 199	two armed
# 200	schedules cohorts
# 201	schedules arms
# 202	response cohort
# 203	reference cohorts
# 204	radiation arms
# 205	procedure cohort
# 206	one cohorts
# 207	nine dose
# 208	twelve armed
# 209	15 armed
# 210	15 cohort
# 211	active cohorts
# 212	10 cohort
# 213	13 armed
# 214	15 arms
# 215	allocation arms
# 216	9 arms
# 217	14 armed
# 218	19 arms
# 219	9 armed
# 220	10 arms
# 221	11 armed
# 222	19 armed
# 223	7 armed
# 224	7 arms
# 225	12 arms
# 226	12 armed
# 227	8 armed
# 228	8 arms
# 229	18 arms
# 230	11 cohorts
# 231	18 armed
# 232	11 arms
# 233	10 armed
# 234	blinded cohort
# 235	5 armed
# 236	1 armed
# 237	allocation cohort
# 238	allocation cohorts
# 239	17 cohort
# 240	17 arms
# 241	17 armed
# 242	adjuvanted cohorts
# 243	adjuvanted arms
# 244	vi cohort
# 245	5 arms
# 246	4 armed
# 247	16 investigational
# 248	both armed
# 249	vii cohort
# 250	16 armed
# 251	16 arms
# 252	various cohorts
# 253	13 cohorts
# 254	boost cohorts
# 255	18 cohorts
# 256	boost arms
# 257	vaccine cohorts
# 258	8 cohorts
# 259	eight study
# 260	three armed
# 261	5 cohorts
# 262	imaging arm
# 263	cancer cohort
# 264	monotherapy arm
# 265	combination arms
# 266	vaccine arm
# 267	8 dose
# 268	measurement arm
# 269	six study
# 270	treatments cohort
# 271	13 treatment
# 272	trial cohort
# 273	18 dose
# 274	iv cohort
# 275	ii cohort
# 276	2 cohort
# 277	7 treatment
# 278	single cohort
# 279	dosing arm
# 280	excluded arm
# 281	vii arm
# 282	iii arm
# 283	ix arm
# 284	viii arm
# 285	vi arm
# 286	carcinoma arm
# 287	17 arm
# 288	controlled cohort
# 289	therapy cohorts
# 290	five study
# 291	response arm
# 292	schedule cohort
# 293	2 armed
# 294	13 arms
# 295	five dose
# 296	16 cohort
# 297	13 cohort
# 298	multiple arm
# 299	various arms
# 300	radiation arm
# 301	10 arm
# 302	seven dose
# 303	eleven cohort
# 304	randomized arms
# 305	twelve cohort
# 306	vaccine arms
# 307	18 arm
# 308	13 arm
# 309	seven cohorts
# 310	14 cohort
# 311	12 cohort
# 312	15 cohorts
# 313	17 cohorts
# 314	16 cohorts
# 315	controlled arm
# 316	four investigational
# 317	immunotherapy arm
# 318	7 arm
# 319	four cohort
# 320	3 cohorts
# 321	6 arms
# 322	independent cohorts
# 323	both arm
# 324	9 cohorts
# 325	fifteen study
# 326	1 arms
# 327	14 arms
# 328	10 cohorts
# 329	interventional arm
# 330	care arms
# 331	polytherapy
# 332	investigational arms
# 333	one cohort
# 334	three investigational
# 335	parallel cohorts
# 336	radiotherapy cohort
# 337	7 cohort
# 338	7 cohorts
# 339	19 cohorts
# 340	six treatment
# 341	control cohorts
# 342	two investigational
# 343	assignment arm
# 344	carcinoma cohort
# 345	monotherapy
# 346	19 arm
# 347	10 investigational
# 348	chemotherapy cohort
# 349	study cohorts
# 350	allocation arm
# 351	12 cohorts
# 352	14 cohorts
# 353	four arm
# 354	treatments arm
# 355	radiotherapy arm
# 356	12 treatment
# 357	patient arms
# 358	11 cohort
# 359	12 arm
# 360	6 armed
# 361	19 investigational
# 362	nine study
# 363	12 investigational
# 364	single armed
# 365	comparator cohort
# 366	8 arm
# 367	regimen cohort
# 368	18 investigational
# 369	one armed
# 370	17 dose
# 371	18 cohort
# 372	15 investigational
# 373	11 arm
# 374	18 treatment
# 375	5 investigational
# 376	four arms
# 377	assignment cohort
# 378	blinded arm
# 379	14 arm
# 380	15 arm
# 381	14 dose
# 382	19 cohort
# 383	2 cohorts
# 384	3 cohort
# 385	five treatment
# 386	13 investigational
# 387	multiple cohort
# 388	interventional cohort
# 389	cancer arm
# 390	six dose
# 391	per arm
# 392	therapy arms
# 393	6 arm
# 394	vaccine cohort
# 395	5 cohort
# 396	9 arm
# 397	doses arm
# 398	intervention cohort
# 399	doses cohort
# 400	control cohort
# 401	randomized cohort
# 402	both cohort
# 403	17 investigational
# 404	11 treatment
# 405	1 arm
# 406	1 cohort
# 407	multi arm
# 408	8 cohort
# 409	between arms
# 410	across cohorts
# 411	placebo cohort
# 412	intervention arm
# 413	therapy cohort
# 414	four cohorts
# 415	16 dose
# 416	19 dose
# 417	4 arm
# 418	4 cohort
# 419	placebo cohorts
# 420	study arms
# 421	2 arms
# 422	4 arms
# 423	sap
# 424	6 cohort
# 425	18 study
# 426	observational arm
# 427	parallel arms
# 428	13 dose
# 429	11 dose
# 430	schedule arm
# 431	17 treatment
# 432	10 treatment
# 433	7 investigational
# 434	8 investigational
# 435	five arms
# 436	treatment cohorts
# 437	12 dose
# 438	control arms
# 439	all cohorts
# 440	randomise
# 441	therapy arm
# 442	14 treatment
# 443	patient cohorts
# 444	1 treatment
# 445	both dose
# 446	15 treatment
# 447	16 treatment
# 448	14 study
# 449	3 treatment
# 450	second arm
# 451	unscheduled
# 452	one study
# 453	two dose
# 454	1 investigational
# 455	9 study
# 456	proprietary
# 457	by arm
# 458	healthy
# 459	single dose
# 460	4 study
# 461	comparator arm
# 462	observational cohort
# 463	randomisation
# 464	8 study
# 465	each arm
# 466	ii arm
# 467	19 treatment
# 468	12 study
# 469	treated cohort
# 470	two study
# 471	dosing cohorts
# 472	4 dose
# 473	both investigational
# 474	6 cohorts
# 475	8 treatment
# 476	15 dose
# 477	single study
# 478	three
# 479	5 arm
# 480	one dose
# 481	separated
# 482	10 dose
# 483	regimen arm
# 484	placebo arms
# 485	three dose
# 486	dmc
# 487	dosing
# 488	both cohorts
# 489	15 study
# 490	amended
# 491	19 study
# 492	treatment arms
# 493	13 study
# 494	each cohort
# 495	9 investigational
# 496	6 study
# 497	2 investigational
# 498	separately
# 499	criterion
# 500	second cohort
# 501	two cohorts
# 502	blinding
# 503	9 dose
# 504	3 dose
# 505	7 dose
# 506	3 study
# 507	children
# 508	6 investigational
# 509	2 study
# 510	two arm
# 511	16 study
# 512	between cohorts
# 513	5 dose
# 514	randomize
# 515	doses
# 516	unblinded
# 517	per cohort
# 518	blind
# 519	participants
# 520	both study
# 521	1 study
# 522	separate
# 523	11 study
# 524	assay
# 525	10 study
# 526	7 study
# 527	placebo arm
# 528	5 study
# 529	5 treatment
# 530	unblinding
# 531	item
# 532	one treatment
# 533	group
# 534	1 dose
# 535	statistical
# 536	double
# 537	one arm
# 538	groups
# 539	2 dose
# 540	significance
# 541	either
# 542	single treatment
# 543	discharge
# 544	differences
# 545	primary
# 546	ratio
# 547	hypothesis
# 548	sided
# 549	randomised
# 550	4 treatment
# 551	remission
# 552	unit
# 553	outcome
# 554	subgroups
# 555	3 investigational
# 556	2 treatment
# 557	inflammatory
# 558	adherence
# 559	studies
# 560	cardiac
# 561	controlled
# 562	standard
# 563	treatments
# 564	dosing cohort
# 565	compared
# 566	questionnaire
# 567	refractory
# 568	four dose
# 569	variables
# 570	6 treatment
# 571	effects
# 572	dose cohort
# 573	two cohort
# 574	power
# 575	database
# 576	outcomes
# 577	factors
# 578	significantly
# 579	6 dose
# 580	compare
# 581	placebo
# 582	scores
# 583	versus
# 584	both arms
# 585	side
# 586	average
# 587	randomization
# 588	subgroup
# 589	investigational arm
# 590	recruitment
# 591	experimental arm
# 592	alpha
# 593	beta
# 594	both treatment
# 595	cognitive
# 596	mortality
# 597	insulin
# 598	four treatment
# 599	control arm
# 600	vs
# 601	9 treatment
# 602	blinded
# 603	dsmb
# 604	measurable
# 605	trial
# 606	control
# 607	study arm
# 608	intervention
# 609	tumor
# 610	two arms
# 611	five
# 612	metastatic
# 613	both
# 614	two treatment
# 615	metastasis
# 616	recist
# 617	dose
# 618	experimental
# 619	2 arm
# 620	itt
# 621	block
# 622	17 study
# 623	metastases
# 624	randomized
# 625	transplant
# 626	study
# 627	single arm
# 628	two
# 629	eight
# 630	seven
# 631	four
# 632	six
# 633	nine
# 634	treatment
# 635	arm
# Strongest predictors for class 3
# 0	four treatment
# 1	17 study
# 2	14 arms
# 3	15 arm
# 4	19 cohort
# 5	controlled arm
# 6	four arms
# 7	blinded arm
# 8	comparing cohorts
# 9	comparing arms
# 10	eleven investigational
# 11	various cohorts
# 12	one cohorts
# 13	chemotherapy cohorts
# 14	chemotherapy arms
# 15	care cohorts
# 16	procedure arm
# 17	one arms
# 18	one cohorted
# 19	observation arms
# 20	procedure cohort
# 21	nine treatment
# 22	nineteen arm
# 23	nineteen armed
# 24	nineteen arms
# 25	nineteen cohort
# 26	nineteen cohorts
# 27	observation cohorts
# 28	nineteen dose
# 29	diabetic cohorts
# 30	diabetic cohort
# 31	diabetic arms
# 32	diabetic arm
# 33	nineteen study
# 34	nineteen treatment
# 35	nineteen investigational
# 36	radiation arms
# 37	vi cohort
# 38	nine investigational
# 39	seventeen armed
# 40	7 armed
# 41	7 arms
# 42	seventeen arm
# 43	seven treatment
# 44	seven study
# 45	seven investigational
# 46	8 armed
# 47	8 arms
# 48	seven cohort
# 49	seven arms
# 50	9 armed
# 51	9 arms
# 52	seven armed
# 53	seven arm
# 54	twelve investigational
# 55	active cohorts
# 56	boost cohorts
# 57	boost arms
# 58	blinded cohort
# 59	two armed
# 60	reference cohorts
# 61	twelve treatment
# 62	both armed
# 63	vii cohort
# 64	allocation cohort
# 65	allocation arms
# 66	schedules arms
# 67	schedules cohorts
# 68	adjuvanted cohorts
# 69	adjuvanted arms
# 70	allocation cohorts
# 71	nine dose
# 72	nine cohort
# 73	seventeen arms
# 74	fifteen cohorts
# 75	fifteen dose
# 76	fifteen investigational
# 77	fifteen treatment
# 78	viii cohort
# 79	five armed
# 80	five cohort
# 81	five cohorts
# 82	five investigational
# 83	monotherapy cohort
# 84	four armed
# 85	fourteen arm
# 86	fourteen armed
# 87	fourteen arms
# 88	fifteen cohort
# 89	fourteen cohort
# 90	fourteen dose
# 91	fourteen investigational
# 92	fourteen study
# 93	fourteen treatment
# 94	measurement cohort
# 95	ix cohort
# 96	iii cohort
# 97	imaging cohort
# 98	independent arms
# 99	investigational cohorts
# 100	injection cohort
# 101	investigational cohort
# 102	interventions cohort
# 103	intervention cohorts
# 104	fourteen cohorts
# 105	fifteen arms
# 106	fifteen armed
# 107	fifteen arm
# 108	nine arms
# 109	eight arm
# 110	eight armed
# 111	eight arms
# 112	eight cohort
# 113	eight cohorts
# 114	eight dose
# 115	eight investigational
# 116	eight treatment
# 117	eighteen arm
# 118	eighteen armed
# 119	eighteen arms
# 120	eighteen cohort
# 121	eighteen cohorts
# 122	eighteen dose
# 123	eighteen investigational
# 124	eighteen study
# 125	monotherapy cohorts
# 126	experimental cohorts
# 127	experimental cohort
# 128	excluded cohort
# 129	eleven treatment
# 130	eleven study
# 131	nine cohorts
# 132	nine arm
# 133	eleven cohorts
# 134	eleven arms
# 135	eleven armed
# 136	eleven arm
# 137	nine armed
# 138	eighteen treatment
# 139	eleven dose
# 140	seventeen cohort
# 141	response cohort
# 142	seventeen dose
# 143	sixteen arms
# 144	ten cohort
# 145	sixteen armed
# 146	sixteen arm
# 147	ten cohorts
# 148	ten dose
# 149	15 cohort
# 150	15 arms
# 151	15 armed
# 152	six investigational
# 153	ten investigational
# 154	ten study
# 155	ten treatment
# 156	six cohorts
# 157	14 armed
# 158	thirteen arm
# 159	six cohort
# 160	16 armed
# 161	thirteen armed
# 162	16 arms
# 163	16 investigational
# 164	19 armed
# 165	18 cohorts
# 166	18 arms
# 167	sixteen treatment
# 168	18 armed
# 169	sixteen study
# 170	twelve arms
# 171	seventeen cohorts
# 172	sixteen investigational
# 173	17 cohort
# 174	17 arms
# 175	17 armed
# 176	sixteen dose
# 177	sixteen cohorts
# 178	ten arm
# 179	sixteen cohort
# 180	ten armed
# 181	ten arms
# 182	six arms
# 183	19 arms
# 184	10 cohort
# 185	seventeen investigational
# 186	single arms
# 187	5 armed
# 188	thirteen treatment
# 189	5 arms
# 190	twelve armed
# 191	11 armed
# 192	six armed
# 193	10 armed
# 194	twelve cohorts
# 195	twelve arm
# 196	twelve dose
# 197	seventeen treatment
# 198	seventeen study
# 199	10 arms
# 200	single cohorted
# 201	thirteen study
# 202	1 armed
# 203	13 cohorts
# 204	13 armed
# 205	4 armed
# 206	single cohorts
# 207	thirteen cohort
# 208	six arm
# 209	thirteen arms
# 210	12 armed
# 211	thirteen cohorts
# 212	thirteen dose
# 213	thirteen investigational
# 214	11 cohorts
# 215	11 arms
# 216	12 arms
# 217	three cohort
# 218	19 treatment
# 219	seven dose
# 220	10 arm
# 221	patient arms
# 222	three investigational
# 223	observational arm
# 224	observational cohort
# 225	1 arms
# 226	assignment arm
# 227	doses arm
# 228	iii arm
# 229	ix arm
# 230	carcinoma arm
# 231	vii arm
# 232	viii arm
# 233	vi arm
# 234	excluded arm
# 235	vaccine cohorts
# 236	17 arm
# 237	controlled cohort
# 238	interventions arm
# 239	five study
# 240	reference arms
# 241	response arm
# 242	2 armed
# 243	13 arms
# 244	five dose
# 245	13 cohort
# 246	16 cohort
# 247	twelve study
# 248	five arm
# 249	various arms
# 250	multiple arm
# 251	radiation arm
# 252	eleven cohort
# 253	twelve cohort
# 254	vaccine arms
# 255	therapy arms
# 256	7 cohorts
# 257	18 arm
# 258	13 arm
# 259	seven cohorts
# 260	14 cohort
# 261	12 cohort
# 262	16 cohorts
# 263	15 cohorts
# 264	17 cohorts
# 265	four investigational
# 266	immunotherapy arm
# 267	four cohort
# 268	6 arms
# 269	independent cohorts
# 270	active arms
# 271	fifteen study
# 272	10 cohorts
# 273	interventional arm
# 274	care arms
# 275	16 arm
# 276	polytherapy
# 277	six study
# 278	parallel cohorts
# 279	radiotherapy cohort
# 280	19 cohorts
# 281	control cohorts
# 282	trial cohort
# 283	carcinoma cohort
# 284	regimen cohort
# 285	allocation arm
# 286	four arm
# 287	radiotherapy arm
# 288	imaging arm
# 289	therapy cohorts
# 290	immunotherapy cohort
# 291	single investigational
# 292	vaccine arm
# 293	6 armed
# 294	dosing arms
# 295	19 arm
# 296	12 dose
# 297	comparator cohort
# 298	12 arm
# 299	12 cohorts
# 300	14 cohorts
# 301	9 cohorts
# 302	treatments arm
# 303	4 cohort
# 304	one armed
# 305	11 cohort
# 306	11 arm
# 307	9 cohort
# 308	four study
# 309	randomized arm
# 310	eight study
# 311	radiation cohort
# 312	4 arm
# 313	8 cohort
# 314	19 dose
# 315	randomized cohorts
# 316	19 investigational
# 317	nine study
# 318	12 investigational
# 319	single armed
# 320	18 investigational
# 321	interventional cohort
# 322	18 cohort
# 323	both arm
# 324	5 cohort
# 325	assignment cohort
# 326	vaccine cohort
# 327	14 arm
# 328	combination cohorts
# 329	6 cohort
# 330	six
# 331	chemotherapy cohort
# 332	across arms
# 333	two investigational
# 334	intervention cohort
# 335	17 dose
# 336	18 dose
# 337	investigational arms
# 338	4 arms
# 339	five treatment
# 340	8 arm
# 341	multiple cohort
# 342	cancer arm
# 343	14 treatment
# 344	treatments cohort
# 345	8 cohorts
# 346	monotherapy arms
# 347	18 treatment
# 348	schedule cohort
# 349	both cohort
# 350	four cohorts
# 351	iv arm
# 352	7 arm
# 353	across cohorts
# 354	7 cohort
# 355	six dose
# 356	doses cohort
# 357	randomized arms
# 358	3 armed
# 359	9 arm
# 360	17 investigational
# 361	three armed
# 362	15 investigational
# 363	multi arm
# 364	injection arm
# 365	9 treatment
# 366	six treatment
# 367	intervention arms
# 368	five arms
# 369	11 investigational
# 370	parallel arms
# 371	iv cohort
# 372	trial arm
# 373	measurement arm
# 374	combination arms
# 375	schedule arm
# 376	6 arm
# 377	randomise
# 378	all arms
# 379	control cohort
# 380	16 dose
# 381	ii cohort
# 382	placebo cohorts
# 383	2 arm
# 384	radiation cohorts
# 385	14 dose
# 386	one investigational
# 387	both cohorts
# 388	13 dose
# 389	experimental arms
# 390	5 cohorts
# 391	17 treatment
# 392	cancer cohort
# 393	1 cohorts
# 394	nine
# 395	randomized cohort
# 396	10 investigational
# 397	5 arm
# 398	3 cohorts
# 399	13 treatment
# 400	placebo cohort
# 401	chemotherapy arm
# 402	12 treatment
# 403	treatment cohorts
# 404	ii arm
# 405	therapy cohort
# 406	11 dose
# 407	treated arm
# 408	study cohorts
# 409	4 cohorts
# 410	three arm
# 411	both dose
# 412	13 investigational
# 413	single cohort
# 414	multi cohort
# 415	19 study
# 416	16 treatment
# 417	9 dose
# 418	three cohorts
# 419	dosing cohorts
# 420	four dose
# 421	3 cohort
# 422	one cohort
# 423	6 cohorts
# 424	treated cohort
# 425	patient cohorts
# 426	both investigational
# 427	monotherapy arm
# 428	regimen arm
# 429	single study
# 430	by arm
# 431	control arms
# 432	dosing arm
# 433	3 arms
# 434	per cohort
# 435	6 investigational
# 436	one treatment
# 437	comparator arm
# 438	1 arm
# 439	14 investigational
# 440	15 treatment
# 441	two cohorts
# 442	1 cohort
# 443	three study
# 444	9 investigational
# 445	intervention arm
# 446	3 arm
# 447	2 arms
# 448	2 cohorts
# 449	second cohort
# 450	10 dose
# 451	15 dose
# 452	placebo arms
# 453	between cohorts
# 454	8 investigational
# 455	two cohort
# 456	5 investigational
# 457	between arms
# 458	dosing cohort
# 459	11 treatment
# 460	three dose
# 461	18 study
# 462	2 cohort
# 463	7 investigational
# 464	dose arm
# 465	investigational arm
# 466	13 study
# 467	dose cohort
# 468	three arms
# 469	two arm
# 470	3 investigational
# 471	single treatment
# 472	4 investigational
# 473	two study
# 474	experimental arm
# 475	all cohorts
# 476	second arm
# 477	by cohort
# 478	2 investigational
# 479	8 treatment
# 480	14 study
# 481	1 investigational
# 482	10 treatment
# 483	4 treatment
# 484	6 dose
# 485	therapy arm
# 486	separated
# 487	study cohort
# 488	10 study
# 489	15 study
# 490	7 study
# 491	5 dose
# 492	dmc
# 493	both study
# 494	each cohort
# 495	7 treatment
# 496	4 dose
# 497	16 study
# 498	randomisation
# 499	8 dose
# 500	one arm
# 501	single dose
# 502	per arm
# 503	study arms
# 504	randomised
# 505	12 study
# 506	placebo arm
# 507	randomize
# 508	unblinded
# 509	four
# 510	healthy
# 511	unblinding
# 512	6 treatment
# 513	7 dose
# 514	treatment arms
# 515	5 treatment
# 516	11 study
# 517	5 study
# 518	subgroups
# 519	separately
# 520	three treatment
# 521	3 treatment
# 522	blinding
# 523	both treatment
# 524	trial
# 525	1 treatment
# 526	two dose
# 527	participants
# 528	criterion
# 529	4 study
# 530	assay
# 531	3 dose
# 532	proprietary
# 533	unit
# 534	power
# 535	one study
# 536	subgroup
# 537	8 study
# 538	blind
# 539	6 study
# 540	9 study
# 541	sap
# 542	inflammatory
# 543	separate
# 544	insulin
# 545	discharge
# 546	significance
# 547	double
# 548	both arms
# 549	adherence
# 550	unscheduled
# 551	differences
# 552	sided
# 553	2 study
# 554	1 study
# 555	groups
# 556	outcome
# 557	2 treatment
# 558	significantly
# 559	cognitive
# 560	treatments
# 561	recruitment
# 562	doses
# 563	statistical
# 564	primary
# 565	3 study
# 566	group
# 567	beta
# 568	mortality
# 569	average
# 570	factors
# 571	2 dose
# 572	either
# 573	ratio
# 574	two arms
# 575	compare
# 576	1 dose
# 577	standard
# 578	database
# 579	dosing
# 580	outcomes
# 581	variables
# 582	one dose
# 583	studies
# 584	effects
# 585	each arm
# 586	compared
# 587	cardiac
# 588	hypothesis
# 589	versus
# 590	randomization
# 591	blinded
# 592	placebo
# 593	item
# 594	amended
# 595	alpha
# 596	vs
# 597	questionnaire
# 598	side
# 599	scores
# 600	children
# 601	refractory
# 602	remission
# 603	study arm
# 604	metastasis
# 605	metastases
# 606	two treatment
# 607	controlled
# 608	transplant
# 609	dsmb
# 610	tumor
# 611	measurable
# 612	control arm
# 613	metastatic
# 614	block
# 615	three
# 616	single arm
# 617	intervention
# 618	itt
# 619	control
# 620	eight
# 621	recist
# 622	seven
# 623	randomized
# 624	monotherapy
# 625	both
# 626	five
# 627	two
# 628	arms
# 629	experimental
# 630	cohort
# 631	dose
# 632	cohorts
# 633	study
# 634	treatment
# 635	arm
# Strongest predictors for class 4
#
# 0	cohorts
# 1	cohort
# 2	five arms
# 3	regimen arm
# 4	three armed
# 5	6 cohorts
# 6	both cohort
# 7	4 arm
# 8	four arm
# 9	schedule cohort
# 10	five treatment
# 11	iv cohort
# 12	experimental arms
# 13	14 arm
# 14	12 investigational
# 15	10 cohorts
# 16	6 arms
# 17	seven cohorts
# 18	5 arm
# 19	chemotherapy arms
# 20	single cohorted
# 21	three cohort
# 22	single arms
# 23	measurement cohort
# 24	five cohort
# 25	8 armed
# 26	8 arms
# 27	fifteen investigational
# 28	fourteen armed
# 29	ten cohorts
# 30	five cohorts
# 31	ten dose
# 32	ten investigational
# 33	9 armed
# 34	9 arms
# 35	fourteen arms
# 36	response cohort
# 37	investigational cohorts
# 38	ix cohort
# 39	twelve armed
# 40	monotherapy cohort
# 41	7 armed
# 42	nine cohort
# 43	nine arms
# 44	six cohorts
# 45	six cohort
# 46	seven armed
# 47	six arms
# 48	5 armed
# 49	5 arms
# 50	nine armed
# 51	nine arm
# 52	7 arms
# 53	six armed
# 54	various cohorts
# 55	ten cohort
# 56	twelve arm
# 57	five armed
# 58	fourteen arm
# 59	seven arms
# 60	monotherapy cohorts
# 61	seven cohort
# 62	single cohorts
# 63	five investigational
# 64	six arm
# 65	ten study
# 66	interventions cohort
# 67	fourteen dose
# 68	seventeen arms
# 69	boost arms
# 70	boost cohorts
# 71	twelve cohorts
# 72	seven study
# 73	both armed
# 74	seventeen armed
# 75	chemotherapy cohorts
# 76	imaging cohort
# 77	iii cohort
# 78	seventeen cohort
# 79	seventeen arm
# 80	twelve dose
# 81	schedules arms
# 82	schedules cohorts
# 83	fourteen treatment
# 84	four armed
# 85	twelve investigational
# 86	fourteen study
# 87	comparing cohorts
# 88	care cohorts
# 89	fourteen investigational
# 90	seven treatment
# 91	investigational cohort
# 92	blinded cohort
# 93	seventeen cohorts
# 94	active cohorts
# 95	seventeen treatment
# 96	adjuvanted arms
# 97	fourteen cohort
# 98	adjuvanted cohorts
# 99	eight arm
# 100	seven investigational
# 101	allocation arms
# 102	allocation cohort
# 103	allocation cohorts
# 104	independent arms
# 105	two armed
# 106	diabetic cohorts
# 107	intervention cohorts
# 108	seventeen study
# 109	diabetic cohort
# 110	injection cohort
# 111	diabetic arms
# 112	seventeen investigational
# 113	fourteen cohorts
# 114	diabetic arm
# 115	seventeen dose
# 116	twelve arms
# 117	4 armed
# 118	eight arms
# 119	eight armed
# 120	thirteen dose
# 121	sixteen treatment
# 122	thirteen investigational
# 123	ten treatment
# 124	13 armed
# 125	fifteen treatment
# 126	excluded cohort
# 127	13 cohorts
# 128	eleven treatment
# 129	eleven study
# 130	sixteen study
# 131	eleven investigational
# 132	14 armed
# 133	eleven dose
# 134	eleven cohorts
# 135	eleven arms
# 136	eleven armed
# 137	thirteen study
# 138	sixteen investigational
# 139	eleven arm
# 140	thirteen treatment
# 141	15 armed
# 142	15 arms
# 143	15 cohort
# 144	viii cohort
# 145	experimental cohort
# 146	comparing arms
# 147	12 arms
# 148	procedure arm
# 149	1 armed
# 150	thirteen armed
# 151	thirteen arms
# 152	thirteen arm
# 153	fifteen dose
# 154	ten arm
# 155	fifteen cohorts
# 156	ten armed
# 157	fifteen cohort
# 158	10 armed
# 159	10 arms
# 160	10 cohort
# 161	fifteen arms
# 162	radiation arms
# 163	vii cohort
# 164	ten arms
# 165	fifteen armed
# 166	11 armed
# 167	11 arms
# 168	fifteen arm
# 169	11 cohorts
# 170	experimental cohorts
# 171	thirteen cohort
# 172	thirteen cohorts
# 173	procedure cohort
# 174	12 armed
# 175	sixteen dose
# 176	eighteen treatment
# 177	eighteen study
# 178	19 armed
# 179	19 arms
# 180	nineteen treatment
# 181	eight dose
# 182	nineteen study
# 183	eight cohorts
# 184	nineteen investigational
# 185	nineteen dose
# 186	sixteen arms
# 187	eight cohort
# 188	nineteen cohorts
# 189	reference cohorts
# 190	nineteen cohort
# 191	sixteen armed
# 192	sixteen arm
# 193	seven arm
# 194	nineteen armed
# 195	nineteen arm
# 196	nine treatment
# 197	nine investigational
# 198	nine dose
# 199	nine cohorts
# 200	six investigational
# 201	vi cohort
# 202	nineteen arms
# 203	observation arms
# 204	eight investigational
# 205	eight treatment
# 206	16 armed
# 207	16 arms
# 208	eighteen investigational
# 209	eighteen dose
# 210	eighteen cohorts
# 211	16 investigational
# 212	sixteen cohorts
# 213	eighteen cohort
# 214	17 armed
# 215	observation cohorts
# 216	17 cohort
# 217	eighteen arms
# 218	17 arms
# 219	one cohorted
# 220	18 cohorts
# 221	eighteen arm
# 222	one cohorts
# 223	18 armed
# 224	18 arms
# 225	eighteen armed
# 226	one arms
# 227	sixteen cohort
# 228	twelve treatment
# 229	therapy arms
# 230	six treatment
# 231	9 cohorts
# 232	all cohorts
# 233	observational cohort
# 234	five study
# 235	controlled cohort
# 236	8 cohorts
# 237	11 dose
# 238	placebo cohorts
# 239	19 investigational
# 240	therapy cohorts
# 241	therapy cohort
# 242	12 cohorts
# 243	vii arm
# 244	vi arm
# 245	excluded arm
# 246	ix arm
# 247	viii arm
# 248	carcinoma arm
# 249	iii arm
# 250	vaccine cohorts
# 251	17 arm
# 252	interventions arm
# 253	reference arms
# 254	response arm
# 255	11 cohort
# 256	2 armed
# 257	9 cohort
# 258	13 arms
# 259	five dose
# 260	placebo cohort
# 261	13 cohort
# 262	16 cohort
# 263	twelve study
# 264	five arm
# 265	various arms
# 266	multiple arm
# 267	radiation arm
# 268	10 arm
# 269	seven dose
# 270	eleven cohort
# 271	4 arms
# 272	18 investigational
# 273	twelve cohort
# 274	vaccine arms
# 275	18 arm
# 276	13 arm
# 277	14 cohort
# 278	12 cohort
# 279	16 cohorts
# 280	15 cohorts
# 281	17 cohorts
# 282	8 arm
# 283	controlled arm
# 284	four investigational
# 285	immunotherapy arm
# 286	four cohort
# 287	independent cohorts
# 288	fifteen study
# 289	14 arms
# 290	interventional arm
# 291	care arms
# 292	16 arm
# 293	polytherapy
# 294	parallel cohorts
# 295	single treatment
# 296	radiotherapy cohort
# 297	19 cohorts
# 298	control cohorts
# 299	carcinoma cohort
# 300	investigational arms
# 301	regimen cohort
# 302	allocation arm
# 303	radiotherapy arm
# 304	imaging arm
# 305	treatments cohort
# 306	immunotherapy cohort
# 307	7 cohorts
# 308	single investigational
# 309	assignment arm
# 310	vaccine arm
# 311	6 armed
# 312	six dose
# 313	dosing arms
# 314	19 arm
# 315	14 cohorts
# 316	comparator cohort
# 317	8 cohort
# 318	treatments arm
# 319	17 dose
# 320	patient arms
# 321	18 dose
# 322	one armed
# 323	doses cohort
# 324	11 arm
# 325	randomized arm
# 326	6 cohort
# 327	eight study
# 328	radiation cohort
# 329	combination arms
# 330	intervention arms
# 331	nine study
# 332	randomized cohorts
# 333	single armed
# 334	12 arm
# 335	both arm
# 336	18 cohort
# 337	interventional cohort
# 338	nine
# 339	four arms
# 340	assignment cohort
# 341	blinded arm
# 342	combination cohorts
# 343	vaccine cohort
# 344	multi arm
# 345	four cohorts
# 346	7 cohort
# 347	chemotherapy cohort
# 348	19 cohort
# 349	across arms
# 350	two investigational
# 351	trial cohort
# 352	intervention cohort
# 353	16 dose
# 354	multiple cohort
# 355	cancer arm
# 356	monotherapy arms
# 357	doses arm
# 358	15 investigational
# 359	1 arms
# 360	9 dose
# 361	iv arm
# 362	six study
# 363	7 arm
# 364	9 arm
# 365	three investigational
# 366	randomized arms
# 367	3 armed
# 368	17 investigational
# 369	single cohort
# 370	injection arm
# 371	15 arm
# 372	two cohorts
# 373	observational arm
# 374	parallel arms
# 375	4 cohorts
# 376	trial arm
# 377	across cohorts
# 378	measurement arm
# 379	1 cohorts
# 380	18 treatment
# 381	5 cohort
# 382	schedule arm
# 383	6 arm
# 384	13 dose
# 385	cancer cohort
# 386	dosing cohorts
# 387	ii cohort
# 388	dosing arm
# 389	9 investigational
# 390	multi cohort
# 391	19 dose
# 392	patient cohorts
# 393	by arm
# 394	treated cohort
# 395	5 cohorts
# 396	both cohorts
# 397	14 dose
# 398	radiation cohorts
# 399	control cohort
# 400	17 treatment
# 401	per cohort
# 402	four study
# 403	placebo arms
# 404	second cohort
# 405	one investigational
# 406	chemotherapy arm
# 407	three study
# 408	ii arm
# 409	4 cohort
# 410	monotherapy arm
# 411	treated arm
# 412	three arm
# 413	arms
# 414	3 cohort
# 415	12 dose
# 416	19 study
# 417	dose cohort
# 418	treatment cohorts
# 419	12 treatment
# 420	10 investigational
# 421	1 cohort
# 422	all arms
# 423	3 cohorts
# 424	three cohorts
# 425	2 arms
# 426	both dose
# 427	randomized cohort
# 428	three dose
# 429	comparator arm
# 430	one cohort
# 431	four dose
# 432	3 arms
# 433	active arms
# 434	single study
# 435	11 investigational
# 436	control arms
# 437	8 investigational
# 438	each cohort
# 439	13 investigational
# 440	2 cohort
# 441	11 study
# 442	16 treatment
# 443	dose arm
# 444	15 dose
# 445	dosing cohort
# 446	14 treatment
# 447	10 dose
# 448	19 treatment
# 449	11 treatment
# 450	2 cohorts
# 451	13 treatment
# 452	14 investigational
# 453	study cohorts
# 454	intervention arm
# 455	15 treatment
# 456	both investigational
# 457	between arms
# 458	randomise
# 459	by cohort
# 460	therapy arm
# 461	two arm
# 462	between cohorts
# 463	two cohort
# 464	18 study
# 465	3 arm
# 466	dmc
# 467	1 arm
# 468	three treatment
# 469	13 study
# 470	randomisation
# 471	both study
# 472	5 dose
# 473	study cohort
# 474	8 dose
# 475	investigational arm
# 476	7 dose
# 477	7 investigational
# 478	5 investigational
# 479	three arms
# 480	one treatment
# 481	each arm
# 482	four treatment
# 483	6 investigational
# 484	4 investigational
# 485	10 treatment
# 486	second arm
# 487	unblinded
# 488	14 study
# 489	experimental arm
# 490	placebo arm
# 491	9 treatment
# 492	subgroups
# 493	16 study
# 494	two study
# 495	12 study
# 496	two dose
# 497	per arm
# 498	dosing
# 499	separated
# 500	treatment arms
# 501	15 study
# 502	3 investigational
# 503	1 dose
# 504	single dose
# 505	6 dose
# 506	2 arm
# 507	2 investigational
# 508	7 treatment
# 509	5 treatment
# 510	separately
# 511	criterion
# 512	one study
# 513	3 dose
# 514	1 treatment
# 515	unscheduled
# 516	randomize
# 517	6 treatment
# 518	3 treatment
# 519	four
# 520	sap
# 521	randomised
# 522	dose
# 523	17 study
# 524	4 treatment
# 525	7 study
# 526	unblinding
# 527	one dose
# 528	4 dose
# 529	recist
# 530	both arms
# 531	study arms
# 532	dsmb
# 533	8 study
# 534	sided
# 535	2 treatment
# 536	adherence
# 537	one arm
# 538	doses
# 539	8 treatment
# 540	monotherapy
# 541	assay
# 542	eight
# 543	6 study
# 544	healthy
# 545	1 investigational
# 546	separate
# 547	2 dose
# 548	unit
# 549	groups
# 550	vs
# 551	blinding
# 552	2 study
# 553	1 study
# 554	five
# 555	two arms
# 556	both treatment
# 557	primary
# 558	ratio
# 559	database
# 560	group
# 561	differences
# 562	5 study
# 563	statistical
# 564	metastatic
# 565	refractory
# 566	9 study
# 567	significance
# 568	either
# 569	metastases
# 570	metastasis
# 571	variables
# 572	outcome
# 573	10 study
# 574	cardiac
# 575	factors
# 576	treatments
# 577	significantly
# 578	3 study
# 579	studies
# 580	remission
# 581	4 study
# 582	average
# 583	compared
# 584	outcomes
# 585	standard
# 586	recruitment
# 587	measurable
# 588	blind
# 589	power
# 590	double
# 591	subgroup
# 592	amended
# 593	participants
# 594	discharge
# 595	effects
# 596	item
# 597	versus
# 598	beta
# 599	proprietary
# 600	hypothesis
# 601	side
# 602	tumor
# 603	alpha
# 604	randomization
# 605	control arm
# 606	compare
# 607	placebo
# 608	mortality
# 609	inflammatory
# 610	cognitive
# 611	blinded
# 612	questionnaire
# 613	trial
# 614	scores
# 615	children
# 616	intervention
# 617	transplant
# 618	two treatment
# 619	study arm
# 620	controlled
# 621	single arm
# 622	block
# 623	itt
# 624	three
# 625	insulin
# 626	seven
# 627	control
# 628	six
# 629	randomized
# 630	both
# 631	two
# 632	experimental
# 633	study
# 634	treatment
# 635	arm
