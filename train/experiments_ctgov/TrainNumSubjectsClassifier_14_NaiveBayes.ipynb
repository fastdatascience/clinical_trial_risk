# %% [markdown]
# <a href="https://colab.research.google.com/github/fastdatascience/clinical_trial_risk/blob/fixes_nov_2022/train/ctgov/TrainNumSubjectsClassifier_14_NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
import pandas as pd
import re
import os
import sys
import pickle as pkl
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import json

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, auc, roc_curve
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_annotations = pd.read_csv("/content/drive/MyDrive/data/all_annotations.csv")

# %% [markdown]
# # Get data

# %%
stats_stopwords = set("""A&H
Abbott
Actelion
Aesica pharmaceuticals
Air Products
Alcon
ALK-Abello
Allergan
Alpharma
Almus Pharmaceuticals
Altana
Amgen
APS
Assertio
AstraZeneca
Aventis Pharma
Bausch & Lomb
Baxter
Baxter BioScience
Bayer
Becton Dickinson
Beiersdorf
Berk
Biogen
Boehringer Ingelheim
Boots
BPL
Braun
Bristol-Myers Squibb
Celltech
Cephalon
Chemidex
Chugai
Colgate-Palmolive
Coloplast
ConvaTec
Cow & Gate
CP
Crookes
Dentsply
Dista
DuPont
Eisai
Ethicon
Fabre
Ferring
Florizel
Fresenius SE
Galderma
Galpharm Healthcare
Garnier
GE Healthcare
Gilead
GlaxoSmithKline
Grünenthal
Grifols
GSK
GSK Consumer Healthcare
Heinz
Hillcross
Hoechst Marion Roussel
Invicta
Ipsen
ITH Pharma Ltd
IVAX
J&J
J&J Medical
J&J MSD
Janssen-Cilag
King
Kyowa Hakko
Lederie
LEO
LifeScan
Lilly
Lundbeck
Martindale Pharma
Mölnlycke
Mayne
McNeil
Meda
Medac
MediSense
Menarini
Menarini Diagnostics
Merck
Merck Consumer Health
Merck & Co.
Milupa
MSD
Nestlé
Nestlè Clinical
Neutrogena
Novartis
Novartis Consumer Health
Novo Nordisk
Nycomed
Octapharma
Orion
Otsuka
Parke-Davis
Pfizer
Pharmacia
Procter & Gamble
Procter & Gamble Pharm.
Reckitt Benckiser
Rhône-Poulenc
Roche
Roche Consumer Health
Roche Diagnostics
Rosemont
Rybar
Salts
Sandoz
Sankyo
Sanofi-Aventis
Sanofi Oasteur
Sanofi-Synthélabo
Schering-Plough
Schwarz
Searle
Serono
Servier
Shire
SHS
Sigma
SMA Nutrition
SNBTS
Solvay
Squibb
SSL
Stiefel
Takeda
Taro
Teva
Thornton & Ross
Trinity-Chiesi
Tyco
Univar
Valeant
Viatris
W-L
Warner Lambert
Wockhardt
Wyeth
Yamanouchi
title
study
protocol
participant
participants
irb
africa
trial
patient
patients
treatment
short
trial
gov
sponsor
university
delivery
co
usa
phone
edu
principal
investigators
laboratory
department
us
email
institute
centre
com
confidentiality
confidential
information
must
investigator
team
relevant
ethics
regulatory
contents
research
non
summary
background
rationale
primary
sites
population
interventions
pubmed
January
February
March
April
May
June
July
August
September
October
November
December
Jan
Feb
Mar
Apr
May
Jun
Jul
Aug
Sep
Oct
Nov
Dec
Monday
Tuesday
Wednesday
Thursday
Friday
Saturday
Sunday
Mon
Tue
Wed
Thu
Fri
Sat
Sun
recommendations
length
experienced
making
contain
girls
youth
sms
mobile
economic
uptake
vac
rotavirus
vivax
azithromycin
parasite
stool
placental
village
malaria
ya
plasmodium
png
toc
path
iron
measles
anaemia
vitamin
ultrasound
chloroquine
aerosol
supplementation
gestation
dp
cq
transfusion
gestational
skip
pr
iga
ia
vials
relapse
br
pp
growth
tropical
parents
vi
mass
triple
fetal
anemia
endemic
postnatal
diarrhea
feeding
antenatal
water
food
swabs
pcr
nurse
specify
titers
cmc
workers
hvtn
taf
chc
impaact
rpv
cab
mab
hptn
ral
itraconazole
dtg
linkage
amphotericin
ip
alvac
nichd
ftc
wrair
mva
ts
hiv
antepartum
tdf
aidsvax
vrc
efv
ring
crs
infusion
env
daids
subtype
hbv
psrt
cq
rv
viral
vaginal
arv
bivalent
arvs
zdv
sc
meningitis
sti
mcg
virologic
suppression
antiretroviral
combinations
ucsf
neutralizing
counseling
bid
niaid
tenofovir
abc
aeras
dar
qft
bedaquiline
stream
bdq
mtb
bcg
abidjan
sputum
mdr
tb
anrs
alliance
qtcf
moxifloxacin
xpert
att
cld
inh
ppd
igra
ics
tuberculosis
ltbi
iris
pyrazinamide
biologicals
prednisone
mrc
qt
rct
pa
atp
genexpert
proprietary
hair
dst
imp
rif
quantiferon
ifn
si
idmc
ctu
smc
reproduction
injection
shells
multidrug
isoniazid
pulmonary
corticosteroids
focused
mycobacterium
unfavourable
reserved
ds
tubes
lp
vaccinated
cytokine
copyright
qtc
suspicion
allowable
vaccination
ipt
favourable
stimulation
coordination
rifampicin
ray
tnf
pbmcs
cultures
immunology
csf
uln
revaccination
profiling
iec
ap
baby
al
tel
org
community
mailto
md
doi
pk
fax
ac
medicine
communities
uk
pmid
srl
survey
epub
appendix
plasma
prevention
srvge
rawres
rvge
pt
wise
dehydration
serotype
fifth
cut
reactogenicity
whose
stools
vomiting
immunity
immunogenicity
expressing
characteristics
exact
circumference
preferred
intussusception
postpartum
episodes
added
missing
across
yes
prenatal
difference
symptom
markers
end
gastroenteritis
third
maternal
age
second
enrolment
objective
code
month
last
overall
included
populations
excluded
case
blinded
year
term
severity
done
start
group
lead
subjects
definition
subject
definitions
unsolicited
cases
cohort
cohorts
least
days
post
month
months
level
levels
among
per
size
sizes
figure
figures
comparisons
date
dates
birth
births
hospitalization
hospitalizations
hospitalisation
hospitalisations
hospital
hospitals
woman
women
time
times
considered
weight
weights
never
number
dated
listing
breastfeeding
introduction
arm
arms
data
using
use
score
source
use
used
uses
protocol
protocols
subject
subjects
trial
trials
doctor
doctors
eg
get
getting
got
gotten
rx
dapivirine""".split("\n"))

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 23.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pycountry) (57.4.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=13118d78b2808066b31838bae08cb4e2a9d94aaca3be8f3e5a2f65faebbbaeab
#   Stored in directory: /root/.cache/pip/wheels/0e/06/e8/7ee176e95ea9a8a8c3b3afcb1869f20adbd42413d4611c6eb4
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
import pycountry

# %%
tok = RegexpTokenizer(r'[a-zA-Z]+')

stops = set(stopwords.words('english')).union(set(stopwords.words('french')))

for w in stats_stopwords:
  stops.add(w.lower())
  for t in re.split(r'\W+', w):
    stops.add(t.lower())

for c in pycountry.countries:
    for t in tok.tokenize(c.name.lower()):
        if t not in ("monte", "carlo"):
            stops.add(t)

# %%
with open("/content/drive/MyDrive/data/protocols.pkl.gz", "rb") as f:
    file_to_pages = pkl.load(f)

# %%
import operator
texts = []

for i in range(len(df_annotations)):
    file_name = df_annotations.file.iloc[i]
    
    pages= file_to_pages[file_name]

    texts.append(" ".join(pages))
df_annotations["text"] = texts

# %%
 del file_to_pages

# %%
df_annotations = df_annotations[~df_annotations.num_subjects.isna()]

# %%
for i in np.quantile(df_annotations["num_subjects"], [0, 0.2, 0.4, 0.6, 0.8, 1]):
  print (int(np.float(i)))
# Out:
# 0
# 20
# 44
# 100
# 290
# 1371146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
for i in np.quantile(df_annotations["num_subjects"], [0, 0.33333, 0.666666, 1]):
  print (int(np.float(i)))
# Out:
# 0
# 34
# 134
# 1371146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
def get_num_subjects_clean(num):
    if pd.isna(num):
        return None
    # if num >= 10000:
    #     return "10000+"
    # if num >= 1000:
    #     return "1000+"
    if num >= 134:
        return "134+"
    if num >= 34:
        return "34-133"
    return "1-33"
df_annotations["num_subjects_clean"] = df_annotations["num_subjects"].apply(get_num_subjects_clean)

# %%
df_annotations["num_subjects_clean"].value_counts()
# Out:
# 34-133    4059
# 134+      3979
# 1-33      3882
# Name: num_subjects_clean, dtype: int64

# %%
labels = list(sorted(set(df_annotations["num_subjects_clean"]), key = lambda x : int(re.sub(r'\D.*', '', x))))

# %%
labels
# Out:
# ['1-33', '34-133', '134+']

# %%
df_train = df_annotations[df_annotations.train_val == "train"]
df_val = df_annotations[df_annotations.train_val == "val"]

# %%
# Specially engineered regex to include 95%, 95%ci, etc
vectoriser = CountVectorizer(lowercase=True, stop_words = stops, min_df=5,
                            token_pattern=r'[a-z][a-z]+', ngram_range=[1,2], max_features=5000) 

transformer = TfidfTransformer()

nb = MultinomialNB()
model = make_pipeline(vectoriser, transformer, nb)

# %%
# df_train_small = df_train.sample(1000)

# %%
model.fit(df_train.text, df_train.num_subjects_clean)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['gr', 'labo', 'lnlycke', 'nenthal', 'nestl', 'rh', 'synth', 'taient', 'tais', 'tait', 'tant', 'tante', 'tantes', 'tants', 'tiez', 'tions'] not in stop_words.
#   % sorted(inconsistent)
# Pipeline(steps=[('countvectorizer',
#                  CountVectorizer(max_features=5000, min_df=5,
#                                  ngram_range=[1, 2],
#                                  stop_words={'', 'a', 'a&h', 'abbott', 'abc',
#                                              'abello', 'abidjan', 'about',
#                                              'above', 'ac', 'across',
#                                              'actelion', 'added', 'aeras',
#                                              'aerosol', 'aesica',
#                                              'aesica pharmaceuticals',
#                                              'afghanistan', 'africa', 'african',
#                                              'after', 'again', 'against', 'age',
#                                              'ai', 'aidsvax', 'aie', 'aient',
#                                              'aies', 'ain', ...},
#                                  token_pattern='[a-z][a-z]+')),
#                 ('tfidftransformer', TfidfTransformer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
df_val["y_pred"] = model.predict(df_val.text)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_val["y_pred"]
# Out:
# 12         134+
# 49         134+
# 50         134+
# 51         134+
# 52         134+
#           ...
# 11903      134+
# 11904      134+
# 11905    34-133
# 11906      1-33
# 11907      1-33
# Name: y_pred, Length: 1085, dtype: object

# %%
y_pred_proba = model.predict_proba(df_val.text)

# %%
y_pred_proba
# Out:
# array([[0.04421306, 0.84520584, 0.11058109],
#        [0.27679742, 0.46263753, 0.26056505],
#        [0.1640817 , 0.53935506, 0.29656325],
#        ...,
#        [0.28809568, 0.3187553 , 0.39314903],
#        [0.6723212 , 0.0255033 , 0.30217551],
#        [0.42591366, 0.21610536, 0.35798099]])

# %%
ground_truths = df_val.num_subjects_clean
pred = df_val.y_pred

# %%
pred
# Out:
# 12         134+
# 49         134+
# 50         134+
# 51         134+
# 52         134+
#           ...
# 11903      134+
# 11904      134+
# 11905    34-133
# 11906      1-33
# 11907      1-33
# Name: y_pred, Length: 1085, dtype: object

# %%
acc = accuracy_score(ground_truths, pred)
print (f"accuracy {acc}")
# Out:
# accuracy 0.5142857142857142

# %%
ConfusionMatrixDisplay.from_predictions(ground_truths, pred)
plt.xticks(rotation=90)
;
# Out:
# ''

# %%
all_aucs = []
from sklearn.metrics import roc_auc_score
for i, label in enumerate(list(nb.classes_)):
  roc_auc = roc_auc_score(ground_truths==label, y_pred_proba[:,i])
  print (f"ROC AUC {roc_auc}")
  all_aucs.append(roc_auc)
print (np.mean(all_aucs))
# Out:
# ROC AUC 0.7228799861908797
# ROC AUC 0.8029893567092096
# ROC AUC 0.6075457328567766
# 0.711138358585622

# %%
plt.figure()
lw = 2
    
for i, label in enumerate(list(nb.classes_)):
    fpr, tpr, _ = roc_curve(ground_truths==label, y_pred_proba[:,i])
    roc_auc = auc(fpr, tpr)
    plt.plot(
        fpr,
        tpr,
        # color="darkorange",
        lw=lw,
        label=f"ROC curve subjects = {label} (area = {roc_auc:0.2f})"
    )
    plt.plot([0, 1], [0, 1], color="gray", alpha=0.5, lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
vectoriser.vocabulary_
# Out:
# {'pediatric': 3294,
#  'phase': 3371,
#  'iii': 2194,
#  'prepared': 3488,
#  'red': 3759,
#  'run': 3993,
#  'document': 1362,
#  'discussed': 1320,
#  'except': 1701,
#  'individuals': 2288,
#  'distributed': 1344,
#  'page': 3230,
#  'table': 4482,
#  'overview': 3220,
#  'cell': 694,
#  'chronic': 759,
#  'organ': 3184,
#  'damage': 1122,
#  'spleen': 4287,
#  'brain': 600,
#  'lungs': 2663,
#  'hemoglobin': 2076,
#  'decline': 1155,
#  'efficacy': 1484,
#  'induction': 2293,
#  'adults': 120,
#  'children': 751,
#  'young': 4994,
#  'toxicities': 4610,
#  'therapy': 4559,
#  'effects': 1482,
#  'potential': 3449,
#  'acquired': 62,
#  'dna': 1359,
#  'mutations': 2950,
#  'association': 398,
#  'parameters': 3252,
#  'objectives': 3099,
#  'design': 1208,
#  'specific': 4273,
#  'aims': 168,
#  'feasibility': 1792,
#  'safety': 4004,
#  'pilot': 3395,
#  'continued': 974,
#  'endpoints': 1548,
#  'monitoring': 2902,
#  'enrollment': 1560,
#  'maintenance': 2686,
#  'assigned': 390,
#  'eligibility': 1517,
#  'recruitment': 3755,
#  'informed': 2311,
#  'consent': 931,
#  'inclusion': 2261,
#  'exclusion': 1709,
#  'criteria': 1057,
#  'main': 2682,
#  'parent': 3253,
#  'guardian': 2022,
#  'baseline': 471,
#  'assessment': 380,
#  'family': 1773,
#  'responsibilities': 3911,
#  'power': 3456,
#  'endpoint': 1546,
#  'function': 1925,
#  'improvement': 2239,
#  'rates': 3691,
#  'secondary': 4086,
#  'nervous': 2993,
#  'system': 4474,
#  'kidney': 2507,
#  'bladder': 545,
#  'control': 988,
#  'abdominal': 8,
#  'analysis': 254,
#  'immune': 2211,
#  'events': 1666,
#  'complication': 878,
#  'infants': 2297,
#  'hb': 2043,
#  'ss': 4294,
#  'measurements': 2752,
#  'statistical': 4330,
#  'considerations': 944,
#  'comparison': 858,
#  'full': 1922,
#  'tables': 4487,
#  'crossover': 1071,
#  'removed': 3830,
#  'regression': 3794,
#  'analyses': 250,
#  'adjustment': 102,
#  'interim': 2383,
#  'values': 4794,
#  'related': 3802,
#  'outcomes': 3208,
#  'pharmacokinetics': 3365,
#  'adverse': 124,
#  'classification': 781,
#  'reporting': 3855,
#  'absolute': 22,
#  'effect': 1478,
#  'two': 4666,
#  'sample': 4025,
#  'proportions': 3593,
#  'entry': 1569,
#  'exit': 1717,
#  'studies': 4382,
#  'procedure': 3540,
#  'concentrations': 893,
#  'randomization': 3669,
#  'allocation': 189,
#  'treatments': 4642,
#  'dose': 1375,
#  'titration': 4591,
#  'placebo': 3400,
#  'preparation': 3486,
#  'toxicity': 4611,
#  'blinding': 553,
#  'emergency': 1528,
#  'unblinding': 4700,
#  'interruptions': 2399,
#  'compliance': 876,
#  'missed': 2864,
#  'visits': 4854,
#  'drop': 1413,
#  'duration': 1438,
#  'algorithm': 178,
#  'laboratories': 2524,
#  'specimens': 4279,
#  'hematology': 2073,
#  'biochemistry': 527,
#  'core': 1003,
#  'local': 2627,
#  'center': 704,
#  'mutation': 2949,
#  'biomarkers': 535,
#  'assay': 373,
#  'specimen': 4278,
#  'guidelines': 2026,
#  'standard': 4317,
#  'care': 658,
#  'prophylactic': 3589,
#  'medications': 2768,
#  'education': 1472,
#  'special': 4269,
#  'reading': 3709,
#  'groups': 2017,
#  'counts': 1032,
#  'liver': 2613,
#  'scans': 4049,
#  'follow': 1867,
#  'procedures': 3541,
#  'real': 3710,
#  'complete': 864,
#  'blood': 558,
#  'specified': 4277,
#  'possible': 3439,
#  'event': 1658,
#  'elevated': 1513,
#  'rate': 3689,
#  'detection': 1224,
#  'reports': 3862,
#  'death': 1146,
#  'stroke': 4376,
#  'development': 1237,
#  'acute': 81,
#  'chest': 745,
#  'syndrome': 4469,
#  'serious': 4127,
#  'unexpected': 4711,
#  'management': 2700,
#  'collection': 823,
#  'long': 2639,
#  'contacts': 963,
#  'close': 800,
#  'randomized': 3671,
#  'final': 1828,
#  'results': 3925,
#  'conduct': 908,
#  'planning': 3406,
#  'training': 4621,
#  'receipt': 3718,
#  'inventory': 2422,
#  'expected': 1722,
#  'forms': 1891,
#  'progress': 3563,
#  'performance': 3310,
#  'routine': 3982,
#  'violations': 4836,
#  'approval': 329,
#  'structure': 4380,
#  'participating': 3265,
#  'units': 4720,
#  'operations': 3169,
#  'committee': 841,
#  'centers': 705,
#  'coordinator': 998,
#  'pharmacy': 3370,
#  'distribution': 1345,
#  'investigational': 2426,
#  'national': 2965,
#  'heart': 2060,
#  'lung': 2661,
#  'coordinating': 996,
#  'child': 746,
#  'human': 2142,
#  'administration': 109,
#  'steering': 4343,
#  'board': 583,
#  'evaluation': 1653,
#  'chart': 730,
#  'policy': 3429,
#  'quality': 3644,
#  'assurance': 403,
#  'changes': 724,
#  'types': 4675,
#  'access': 34,
#  'files': 1823,
#  'publication': 3624,
#  'interest': 2377,
#  'literature': 2610,
#  'detailed': 1217,
#  'schedule': 4050,
#  'total': 4606,
#  'amount': 242,
#  'list': 2604,
#  'tests': 4547,
#  'diagnostic': 1256,
#  'facilities': 1760,
#  'measurement': 2751,
#  'scale': 4045,
#  'head': 2054,
#  'observational': 3106,
#  'documented': 1364,
#  'disorder': 1330,
#  'affected': 144,
#  'persons': 3347,
#  'majority': 2689,
#  'therapeutic': 4555,
#  'options': 3178,
#  'bone': 590,
#  'marrow': 2717,
#  'transplantation': 4633,
#  'provide': 3606,
#  'cure': 1095,
#  'matched': 2720,
#  'donor': 1370,
#  'transfusions': 4627,
#  'prevent': 3503,
#  'disease': 1322,
#  'appropriate': 327,
#  'available': 449,
#  'yet': 4990,
#  'demonstrated': 1185,
#  'seen': 4103,
#  'characterized': 729,
#  'complications': 879,
#  'cause': 673,
#  'morbidity': 2915,
#  'early': 1446,
#  'mortality': 2919,
#  'result': 3921,
#  'occlusion': 3116,
#  'begin': 495,
#  'life': 2575,
#  'also': 204,
#  'begins': 497,
#  'first': 1841,
#  'years': 4986,
#  'infection': 2300,
#  'abnormality': 18,
#  'increased': 2270,
#  'glomerular': 1984,
#  'filtration': 1826,
#  'followed': 1874,
#  'proteinuria': 3603,
#  'older': 3139,
#  'renal': 3831,
#  'failure': 1769,
#  'organs': 3187,
#  'typically': 4677,
#  'become': 488,
#  'anti': 285,
#  'agent': 155,
#  'recently': 3725,
#  'oral': 3180,
#  'medication': 2766,
#  'increase': 2269,
#  'production': 3554,
#  'reduce': 3765,
#  'hematological': 2072,
#  'benefits': 504,
#  'include': 2254,
#  'higher': 2096,
#  'concentration': 891,
#  'less': 2564,
#  'reducing': 3769,
#  'severely': 4151,
#  'multicenter': 2941,
#  'suggests': 4414,
#  'associated': 396,
#  'reduced': 3766,
#  'well': 4901,
#  'school': 4063,
#  'aged': 151,
#  'proven': 3605,
#  'investigated': 2424,
#  'although': 217,
#  'dysfunction': 1442,
#  'compared': 854,
#  'historical': 2105,
#  'controls': 990,
#  'observed': 3108,
#  'increases': 2272,
#  'correlated': 1014,
#  'challenge': 719,
#  'determine': 1228,
#  'optimal': 3175,
#  'several': 4149,
#  'important': 2233,
#  'questions': 3655,
#  'addressed': 93,
#  'proposed': 3594,
#  'sensitive': 4113,
#  'history': 2106,
#  'investigation': 2425,
#  'involving': 2439,
#  'highest': 2098,
#  'given': 1977,
#  'protection': 3600,
#  'make': 2690,
#  'decisions': 1152,
#  'regarding': 3782,
#  'participation': 3266,
#  'confidence': 914,
#  'offered': 3126,
#  'however': 2128,
#  'would': 4967,
#  'allow': 191,
#  'without': 4949,
#  'benefit': 502,
#  'recent': 3724,
#  'society': 4245,
#  'oncology': 3148,
#  'noted': 3056,
#  'already': 202,
#  'essential': 1620,
#  'therefore': 4561,
#  'formal': 1888,
#  'ensure': 1561,
#  'appropriately': 328,
#  'following': 1876,
#  'three': 4570,
#  'critical': 1067,
#  'best': 505,
#  'range': 3679,
#  'consider': 942,
#  'clearly': 786,
#  'onset': 3159,
#  'appears': 312,
#  'since': 4202,
#  'continue': 972,
#  'severe': 4150,
#  'might': 2845,
#  'even': 1656,
#  'though': 4566,
#  'subset': 4398,
#  'occurs': 3122,
#  'limited': 2589,
#  'address': 92,
#  'capacity': 645,
#  'functional': 1927,
#  'recognized': 3733,
#  'poor': 3433,
#  'prognostic': 3560,
#  'sign': 4179,
#  'goal': 1995,
#  'randomly': 3677,
#  'either': 1500,
#  'help': 2067,
#  'question': 3652,
#  'directly': 1293,
#  'commonly': 845,
#  'childhood': 750,
#  'based': 469,
#  'known': 2516,
#  'previous': 3506,
#  'consideration': 943,
#  'ethical': 1632,
#  'factors': 1765,
#  'tested': 4543,
#  'double': 1404,
#  'controlled': 989,
#  'enroll': 1557,
#  'proper': 3584,
#  'precautions': 3465,
#  'allows': 194,
#  'opportunity': 3174,
#  'true': 4648,
#  'refers': 3777,
#  'genetic': 1965,
#  'disorders': 1332,
#  'one': 3149,
#  'common': 843,
#  'diseases': 1329,
#  'affecting': 145,
#  'approximately': 332,
#  'live': 2612,
#  'currently': 1098,
#  'estimated': 1626,
#  'single': 4204,
#  'amino': 237,
#  'acid': 60,
#  'beta': 508,
#  'formation': 1890,
#  'containing': 967,
#  'instead': 2346,
#  'leading': 2548,
#  'cellular': 702,
#  'membrane': 2789,
#  'represents': 3866,
#  'manifestations': 2704,
#  'primarily': 3511,
#  'including': 2258,
#  'tissue': 4588,
#  'develop': 1234,
#  'due': 1437,
#  'within': 4935,
#  'small': 4235,
#  'many': 2710,
#  'period': 3320,
#  'repeated': 3838,
#  'cooperative': 994,
#  'demonstrate': 1184,
#  'major': 2688,
#  'internal': 2389,
#  'slow': 4233,
#  'circulation': 766,
#  'provides': 3611,
#  'leads': 2549,
#  'infarction': 2298,
#  'identified': 2180,
#  'absence': 20,
#  'presence': 3492,
#  'numbers': 3092,
#  'suggesting': 4412,
#  'reversible': 3942,
#  'similarly': 4200,
#  'able': 12,
#  'correct': 1008,
#  'occur': 3117,
#  'defects': 1163,
#  'specifically': 4275,
#  'ability': 10,
#  'along': 198,
#  'necrosis': 2982,
#  'urinary': 4756,
#  'protein': 3601,
#  'loss': 2646,
#  'prognosis': 3559,
#  'occurring': 3121,
#  'frequently': 1915,
#  'prevalence': 3502,
#  'proliferation': 3574,
#  'described': 1199,
#  'probably': 3537,
#  'gfr': 1972,
#  'later': 2538,
#  'hypertension': 2154,
#  'significantly': 4193,
#  'excretion': 1712,
#  'significant': 4190,
#  'deaths': 1149,
#  'occurred': 3119,
#  'collected': 820,
#  'prospective': 3595,
#  'magnetic': 2679,
#  'resonance': 3891,
#  'imaging': 2207,
#  'mri': 2928,
#  'ischemia': 2450,
#  'lesions': 2563,
#  'referred': 3776,
#  'reflect': 3778,
#  'present': 3494,
#  'found': 1897,
#  'abnormalities': 17,
#  'wang': 4874,
#  'often': 3129,
#  'large': 2533,
#  'intracranial': 2411,
#  'arteries': 354,
#  'distal': 1341,
#  'artery': 355,
#  'proximal': 3613,
#  'middle': 2844,
#  'cerebral': 707,
#  'abnormal': 13,
#  'flow': 1854,
#  'shown': 4172,
#  'identify': 2183,
#  'risk': 3961,
#  'developing': 1236,
#  'maximum': 2726,
#  'cm': 805,
#  'high': 2093,
#  'stop': 4356,
#  'received': 3720,
#  'monthly': 2913,
#  'fewer': 1814,
#  'taken': 4498,
#  'together': 4596,
#  'suggest': 4410,
#  'intervention': 2403,
#  'neurological': 2997,
#  'sequelae': 4121,
#  'functioning': 1929,
#  'impaired': 2226,
#  'motor': 2921,
#  'frequent': 1914,
#  'target': 4504,
#  'obstructive': 3110,
#  'reactive': 3706,
#  'pattern': 3284,
#  'suggested': 4411,
#  'identical': 2177,
#  'phenotype': 3380,
#  'variation': 4800,
#  'explained': 1731,
#  'differences': 1272,
#  'mean': 2739,
#  'proportion': 3591,
#  'cells': 701,
#  'alpha': 201,
#  'parameter': 3251,
#  'normal': 3049,
#  'persistence': 3340,
#  'reach': 3702,
#  'decreased': 1157,
#  'threshold': 4571,
#  'experience': 1725,
#  'rather': 3692,
#  'located': 2633,
#  'percentage': 3303,
#  'ranges': 3680,
#  'much': 2936,
#  'peripheral': 3330,
#  'equal': 1590,
#  'greater': 2015,
#  'importance': 2232,
#  'individual': 2287,
#  'accurately': 53,
#  'methods': 2818,
#  'staining': 4316,
#  'monoclonal': 2909,
#  'antibodies': 294,
#  'visual': 4855,
#  'cytometry': 1116,
#  'produced': 3550,
#  'adult': 119,
#  'nadir': 2959,
#  'reached': 3703,
#  'brown': 614,
#  'rarely': 3686,
#  'sepsis': 4120,
#  'observations': 3107,
#  'maintaining': 2685,
#  'measured': 2750,
#  'minute': 2860,
#  'calculated': 629,
#  'formula': 1892,
#  'corpuscular': 1007,
#  'fashion': 1776,
#  'average': 452,
#  'pg': 3355,
#  'vitro': 4861,
#  'value': 4793,
#  'sufficient': 4409,
#  'inhibit': 2319,
#  'support': 4438,
#  'concept': 894,
#  'intention': 2371,
#  'vivo': 4862,
#  'achieved': 58,
#  'variety': 4801,
#  'agents': 156,
#  'cytotoxic': 1117,
#  'drugs': 1431,
#  'hematopoietic': 2075,
#  'chain': 717,
#  'fatty': 1783,
#  'acids': 61,
#  'increasing': 2273,
#  'side': 4176,
#  'direct': 1288,
#  'reported': 3847,
#  'profile': 3556,
#  'ii': 2192,
#  'receiving': 3723,
#  'daily': 1119,
#  'led': 2551,
#  'reduction': 3770,
#  'annual': 276,
#  'responses': 3910,
#  'substantial': 4401,
#  'respond': 3899,
#  'possibly': 3440,
#  'dependent': 1192,
#  'completed': 868,
#  'seven': 4148,
#  'institutions': 2351,
#  'administered': 107,
#  'sponsored': 4288,
#  'provided': 3607,
#  'evidence': 1686,
#  'improved': 2238,
#  'mild': 2848,
#  'stated': 4327,
#  'clear': 784,
#  'course': 1033,
#  'reasonable': 3713,
#  'report': 3843,
#  'eight': 1499,
#  'minimal': 2855,
#  'performed': 3312,
#  'eligible': 1519,
#  'four': 1898,
#  'st': 4296,
#  'college': 824,
#  'mg': 2823,
#  'kg': 2502,
#  'day': 1127,
#  'additional': 89,
#  'physical': 3386,
#  'examinations': 1695,
#  'every': 1680,
#  'weeks': 4893,
#  'closely': 803,
#  'monitored': 2901,
#  'especially': 1616,
#  'testing': 4544,
#  'count': 1026,
#  'untreated': 4736,
#  'tolerated': 4600,
#  'showed': 4170,
#  'tolerate': 4599,
#  'prolonged': 3578,
#  'sustained': 4462,
#  'hematologic': 2070,
#  'preliminary': 3480,
#  'possibility': 3438,
#  'consistent': 949,
#  'median': 2763,
#  'assessed': 378,
#  'estimation': 1628,
#  'height': 2065,
#  'divided': 1347,
#  'creatinine': 1050,
#  'ml': 2872,
#  'min': 2852,
#  'change': 721,
#  'strongly': 4379,
#  'elevation': 1514,
#  'presented': 3496,
#  'lower': 2653,
#  'carefully': 659,
#  'studied': 4381,
#  'depression': 1194,
#  'neutropenia': 2999,
#  'thrombocytopenia': 4573,
#  'clinic': 791,
#  'hepatic': 2080,
#  'fold': 1863,
#  'alt': 208,
#  'test': 4539,
#  'infant': 2296,
#  'statistically': 4335,
#  'different': 1273,
#  'rank': 3682,
#  'sum': 4420,
#  'abstract': 26,
#  'scores': 4071,
#  'animal': 273,
#  'toxic': 4609,
#  'almost': 195,
#  'rats': 3696,
#  'gain': 1940,
#  'activity': 77,
#  'learning': 2550,
#  'eyes': 1755,
#  'face': 1757,
#  'impairment': 2227,
#  'doses': 1398,
#  'exposure': 1739,
#  'half': 2030,
#  'clearance': 785,
#  'neither': 2988,
#  'establish': 1622,
#  'exclude': 1707,
#  'marked': 2713,
#  'could': 1024,
#  'risks': 3966,
#  'leukemia': 2568,
#  'malignancies': 2694,
#  'determined': 1231,
#  'settings': 4147,
#  'established': 1623,
#  'potent': 3448,
#  'inhibitor': 2321,
#  'reduces': 3768,
#  'repair': 3836,
#  'mechanisms': 2758,
#  'develops': 1239,
#  'spontaneously': 4290,
#  'environmental': 1571,
#  'cannot': 642,
#  'fully': 1924,
#  'accumulation': 50,
#  'li': 2571,
#  'biochemical': 526,
#  'mechanism': 2756,
#  'incidence': 2253,
#  'treated': 4639,
#  'alone': 197,
#  'concern': 895,
#  'setting': 4146,
#  'usage': 4766,
#  'congenital': 922,
#  'malignancy': 2695,
#  'need': 2983,
#  'evaluated': 1651,
#  'light': 2580,
#  'cancer': 636,
#  'general': 1957,
#  'lymphoma': 2673,
#  'tumor': 4653,
#  'original': 3190,
#  'subsequent': 4395,
#  'retrospective': 3936,
#  'members': 2788,
#  'international': 2390,
#  'physician': 3391,
#  'ages': 157,
#  'wide': 4916,
#  'inhibitory': 2323,
#  'malignant': 2696,
#  'assays': 374,
#  'measure': 2749,
#  'measures': 2753,
#  'frequency': 1913,
#  'gene': 1953,
#  'detect': 1220,
#  'receptor': 3726,
#  'quantitative': 3648,
#  'low': 2651,
#  'serial': 4125,
#  'mf': 2822,
#  'longer': 2642,
#  'pbmc': 3287,
#  'according': 43,
#  'lost': 2648,
#  'accordingly': 46,
#  'designed': 1211,
#  'appear': 310,
#  'absent': 21,
#  'top': 4604,
#  'panel': 3247,
#  'sd': 4085,
#  'versus': 4829,
#  'showing': 4171,
#  'decrease': 1156,
#  'inhibits': 2324,
#  'volume': 4863,
#  'transient': 4628,
#  'old': 3138,
#  'similar': 4199,
#  'demonstrating': 1186,
#  'issues': 2457,
#  'remain': 3823,
#  'issue': 2455,
#  'whether': 4906,
#  'suggestive': 4413,
#  'another': 280,
#  'action': 68,
#  'occurrence': 3120,
#  'accurate': 52,
#  'validated': 4790,
#  'reasons': 3716,
#  'evaluating': 1652,
#  'aim': 167,
#  'relationship': 3813,
#  'investigate': 2423,
#  'involve': 2435,
#  'enrolled': 1558,
#  'receive': 3719,
#  'selected': 4107,
#  'dsmb': 1434,
#  'decision': 1151,
#  'made': 2676,
#  'untoward': 4734,
#  'discontinuing': 1316,
#  'requested': 3869,
#  'five': 1849,
#  'liquid': 2603,
#  'formulation': 1893,
#  'equivalent': 1592,
#  'volumes': 4864,
#  'classified': 782,
#  'blind': 550,
#  'plans': 3407,
#  'outlined': 3210,
#  'separate': 4118,
#  'prior': 3515,
#  'terminated': 4533,
#  'anticipated': 298,
#  'obtained': 3112,
#  'authorized': 441,
#  'immediately': 2209,
#  'continuing': 976,
#  'remaining': 3824,
#  'periods': 3329,
#  'terms': 4538,
#  'adherence': 99,
#  'assess': 376,
#  'intra': 2410,
#  'variability': 4796,
#  'dual': 1436,
#  'independent': 2276,
#  'evaluate': 1647,
#  'validity': 4792,
#  'serum': 4133,
#  'gold': 1996,
#  'pharmacokinetic': 3361,
#  'hours': 2122,
#  'addition': 88,
#  'saved': 4042,
#  'frozen': 1917,
#  'radiation': 3658,
#  'shipped': 4166,
#  'dry': 1432,
#  'ice': 2167,
#  'evaluations': 1655,
#  'hour': 2121,
#  'handled': 2034,
#  'commercial': 838,
#  'recommended': 3737,
#  'manufacturer': 2707,
#  'purposes': 3634,
#  'determination': 1226,
#  'chair': 718,
#  'project': 3573,
#  'reviewed': 3947,
#  'vs': 4868,
#  'actual': 78,
#  'screened': 4077,
#  'race': 3657,
#  'gender': 1952,
#  'scan': 4047,
#  'estimates': 1627,
#  'urine': 4757,
#  'cbc': 682,
#  'chemistries': 739,
#  'saturation': 4041,
#  'examination': 1691,
#  'supported': 4439,
#  'adjustments': 103,
#  'agreement': 163,
#  'assessments': 384,
#  'percentages': 3304,
#  'summarized': 4423,
#  'immediate': 2208,
#  'review': 3943,
#  'reviews': 3949,
#  'recommend': 3735,
#  'interrupted': 2397,
#  'worse': 4961,
#  'proceed': 3544,
#  'degree': 1171,
#  'chance': 720,
#  'discontinued': 1314,
#  'outcome': 3205,
#  'features': 1794,
#  'necessary': 2980,
#  'stopping': 4358,
#  'rules': 3992,
#  'defined': 1166,
#  'relative': 3816,
#  'deleted': 1177,
#  'urinalysis': 4755,
#  'oxygen': 3223,
#  'percutaneous': 3305,
#  'monitor': 2900,
#  'bilirubin': 521,
#  'chemistry': 740,
#  'indirect': 2286,
#  'pain': 3241,
#  'threatening': 4568,
#  'icu': 2173,
#  'platelets': 3411,
#  'etc': 1631,
#  'antibody': 295,
#  'response': 3902,
#  'antigen': 301,
#  'section': 4093,
#  'recommendation': 3736,
#  'lines': 2597,
#  'th': 4551,
#  'confirmed': 921,
#  'interruption': 2398,
#  'physicians': 3392,
#  'standardized': 4322,
#  'mental': 2798,
#  'repeat': 3837,
#  'unless': 4722,
#  'condition': 904,
#  'initiated': 2331,
#  'unanticipated': 4697,
#  'ae': 132,
#  'submitted': 4394,
#  'tabulated': 4491,
#  'consisting': 951,
#  'suspected': 4457,
#  'sae': 3996,
#  'staff': 4312,
#  'material': 2723,
#  'forward': 1895,
#  'send': 4112,
#  'fda': 1786,
#  'aes': 137,
#  'institution': 2347,
#  'requirements': 3876,
#  'sections': 4097,
#  'fi': 1816,
#  'ec': 1453,
#  'ro': 3976,
#  'nt': 3072,
#  'ig': 2188,
#  'ud': 4684,
#  'tr': 4616,
#  'ea': 1444,
#  'tm': 4592,
#  'ra': 3656,
#  'nd': 2977,
#  'ol': 3133,
#  'lo': 2623,
#  'om': 3145,
#  'er': 1593,
#  'io': 2440,
#  'im': 2204,
#  'fo': 1861,
#  'ff': 1815,
#  'ic': 2165,
#  'ct': 1076,
#  'ed': 1464,
#  'nr': 3063,
#  'lm': 2622,
#  'gh': 1974,
#  'fe': 1791,
#  'ib': 2163,
#  'af': 142,
#  'pi': 3393,
#  'ch': 716,
#  'ar': 338,
#  'ov': 3214,
#  'gr': 2002,
#  'ay': 458,
#  'em': 1525,
#  'ha': 2029,
#  'lin': 2593,
#  'oh': 3130,
#  'dd': 1145,
#  'iti': 2461,
#  'hi': 2091,
#  'ld': 2545,
#  'rs': 3986,
#  'zero': 4998,
#  'extensive': 1747,
#  'usually': 4776,
#  'ten': 4529,
#  'systems': 4478,
#  'timing': 4585,
#  'variable': 4797,
#  'example': 1698,
#  'avoid': 453,
#  'english': 1553,
#  'language': 2531,
#  'highly': 2099,
#  'financial': 1837,
#  'services': 4141,
#  'documentation': 1363,
#  'form': 1886,
#  'required': 3873,
#  'enrolling': 1559,
#  'needed': 2984,
#  'purpose': 3633,
#  'experimental': 1728,
#  'sf': 4156,
#  ...}

# %%
fake_document = " ".join(vectoriser.vocabulary_)
vectorised_document = vectoriser.transform([fake_document])
transformed_document = transformer.transform(vectorised_document)
probas = np.zeros((transformed_document.shape[1]))

vocab_lookup = {i:w for w, i in vectoriser.vocabulary_.items()}
with open("num_subjects_diagnostics.txt", "w", encoding="utf-8") as f:
  for prediction_idx in [0, 1, 2]:
        f.write(f"Strongest predictors for class {nb.classes_[prediction_idx]}\n")
        for i in range(transformed_document.shape[1]):
            zeros = np.zeros(transformed_document.shape)
            zeros[0, i] = transformed_document[0, i]
            proba = nb.predict_log_proba(zeros)
            probas[i] = proba[0, prediction_idx]


        for ctr, j in enumerate(np.argsort(-probas)):
          f.write(f"{ctr}\t{vocab_lookup[j]}\n")

# %%
import bz2
with bz2.open("subjects_classifier_document_level.pkl.bz2", "wb") as f:
    pkl.dump(model, f)

# %%
# from google.colab import runtime
# runtime.unassign()
