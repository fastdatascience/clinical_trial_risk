# %% [markdown]
# <a href="https://colab.research.google.com/github/fastdatascience/clinical_trial_risk/blob/fixes_nov_2022/train/ctgov/TrainSAPClassifier_02_NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pycountry) (57.4.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=3778f1bb6310165347920a5278e535c1ce7fdd366b090de6af4bc3dc3f192783
#   Stored in directory: /root/.cache/pip/wheels/0e/06/e8/7ee176e95ea9a8a8c3b3afcb1869f20adbd42413d4611c6eb4
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
import spacy
import pandas as pd
import re
import os
import sys
import pickle as pkl
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import json

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, auc, roc_curve
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_annotations = pd.read_csv("/content/drive/MyDrive/data/all_annotations.csv")

# %% [markdown]
# # Get data

# %%
stats_stopwords = set("""A&H
Abbott
Actelion
Aesica pharmaceuticals
Air Products
Alcon
ALK-Abello
Allergan
Alpharma
Almus Pharmaceuticals
Altana
Amgen
APS
Assertio
AstraZeneca
Aventis Pharma
Bausch & Lomb
Baxter
Baxter BioScience
Bayer
Becton Dickinson
Beiersdorf
Berk
Biogen
Boehringer Ingelheim
Boots
BPL
Braun
Bristol-Myers Squibb
Celltech
Cephalon
Chemidex
Chugai
Colgate-Palmolive
Coloplast
ConvaTec
Cow & Gate
CP
Crookes
Dentsply
Dista
DuPont
Eisai
Ethicon
Fabre
Ferring
Florizel
Fresenius SE
Galderma
Galpharm Healthcare
Garnier
GE Healthcare
Gilead
GlaxoSmithKline
Grünenthal
Grifols
GSK
GSK Consumer Healthcare
Heinz
Hillcross
Hoechst Marion Roussel
Invicta
Ipsen
ITH Pharma Ltd
IVAX
J&J
J&J Medical
J&J MSD
Janssen-Cilag
King
Kyowa Hakko
Lederie
LEO
LifeScan
Lilly
Lundbeck
Martindale Pharma
Mölnlycke
Mayne
McNeil
Meda
Medac
MediSense
Menarini
Menarini Diagnostics
Merck
Merck Consumer Health
Merck & Co.
Milupa
MSD
Nestlé
Nestlè Clinical
Neutrogena
Novartis
Novartis Consumer Health
Novo Nordisk
Nycomed
Octapharma
Orion
Otsuka
Parke-Davis
Pfizer
Pharmacia
Procter & Gamble
Procter & Gamble Pharm.
Reckitt Benckiser
Rhône-Poulenc
Roche
Roche Consumer Health
Roche Diagnostics
Rosemont
Rybar
Salts
Sandoz
Sankyo
Sanofi-Aventis
Sanofi Oasteur
Sanofi-Synthélabo
Schering-Plough
Schwarz
Searle
Serono
Servier
Shire
SHS
Sigma
SMA Nutrition
SNBTS
Solvay
Squibb
SSL
Stiefel
Takeda
Taro
Teva
Thornton & Ross
Trinity-Chiesi
Tyco
Univar
Valeant
Viatris
W-L
Warner Lambert
Wockhardt
Wyeth
Yamanouchi
title
study
protocol
participant
participants
irb
africa
trial
patient
patients
treatment
short
trial
gov
sponsor
university
delivery
co
usa
phone
edu
principal
investigators
laboratory
department
us
email
institute
centre
com
confidentiality
confidential
information
must
investigator
team
relevant
ethics
regulatory
contents
research
non
summary
background
rationale
primary
sites
population
interventions
pubmed
January
February
March
April
May
June
July
August
September
October
November
December
Jan
Feb
Mar
Apr
May
Jun
Jul
Aug
Sep
Oct
Nov
Dec
Monday
Tuesday
Wednesday
Thursday
Friday
Saturday
Sunday
Mon
Tue
Wed
Thu
Fri
Sat
Sun
recommendations
length
experienced
making
contain
girls
youth
sms
mobile
economic
uptake
vac
rotavirus
vivax
azithromycin
parasite
stool
placental
village
malaria
ya
plasmodium
png
toc
path
iron
measles
anaemia
vitamin
ultrasound
chloroquine
aerosol
supplementation
gestation
dp
cq
transfusion
gestational
skip
pr
iga
ia
vials
relapse
br
pp
growth
tropical
parents
vi
mass
triple
fetal
anemia
endemic
postnatal
diarrhea
feeding
antenatal
water
food
swabs
pcr
nurse
specify
titers
cmc
workers
hvtn
taf
chc
impaact
rpv
cab
mab
hptn
ral
itraconazole
dtg
linkage
amphotericin
ip
alvac
nichd
ftc
wrair
mva
ts
hiv
antepartum
tdf
aidsvax
vrc
efv
ring
crs
infusion
env
daids
subtype
hbv
psrt
cq
rv
viral
vaginal
arv
bivalent
arvs
zdv
sc
meningitis
sti
mcg
virologic
suppression
antiretroviral
combinations
ucsf
neutralizing
counseling
bid
niaid
tenofovir
abc
aeras
dar
qft
bedaquiline
stream
bdq
mtb
bcg
abidjan
sputum
mdr
tb
anrs
alliance
qtcf
moxifloxacin
xpert
att
cld
inh
ppd
igra
ics
tuberculosis
ltbi
iris
pyrazinamide
biologicals
prednisone
mrc
qt
rct
pa
atp
genexpert
proprietary
hair
dst
imp
rif
quantiferon
ifn
si
idmc
ctu
smc
reproduction
injection
shells
multidrug
isoniazid
pulmonary
corticosteroids
focused
mycobacterium
unfavourable
reserved
ds
tubes
lp
vaccinated
cytokine
copyright
qtc
suspicion
allowable
vaccination
ipt
favourable
stimulation
coordination
rifampicin
ray
tnf
pbmcs
cultures
immunology
csf
uln
revaccination
profiling
iec
ap
baby
al
tel
org
community
mailto
md
doi
pk
fax
ac
medicine
communities
uk
pmid
srl
survey
epub
appendix
plasma
prevention
srvge
rawres
rvge
pt
wise
dehydration
serotype
fifth
cut
reactogenicity
whose
stools
vomiting
immunity
immunogenicity
expressing
characteristics
exact
circumference
preferred
intussusception
postpartum
episodes
added
missing
across
yes
prenatal
difference
symptom
markers
end
gastroenteritis
third
maternal
age
second
enrolment
objective
code
month
last
overall
included
populations
excluded
case
blinded
year
term
severity
done
start
group
lead
subjects
definition
subject
definitions
unsolicited
cases
cohort
cohorts
least
days
post
month
months
level
levels
among
per
size
sizes
figure
figures
comparisons
date
dates
birth
births
hospitalization
hospitalizations
hospitalisation
hospitalisations
hospital
hospitals
woman
women
time
times
considered
weight
weights
never
number
dated
listing
breastfeeding
introduction
arm
arms
data
using
use
score
source
use
used
uses
protocol
protocols
subject
subjects
trial
trials
doctor
doctors
eg
get
getting
got
gotten
rx
dapivirine""".split("\n"))

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pycountry

# %%
tok = RegexpTokenizer(r'[a-zA-Z]+')

stops = set(stopwords.words('english')).union(set(stopwords.words('french'))).union(stats_stopwords)

for c in pycountry.countries:
    for t in tok.tokenize(c.name.lower()):
        if t not in ("monte", "carlo"):
            stops.add(t)

# %%
with open("/content/drive/MyDrive/data/protocols.pkl.gz", "rb") as f:
    file_to_pages = pkl.load(f)

# %%
import operator
texts = []

for i in range(len(df_annotations)):
    file_name = df_annotations.file.iloc[i]
    
    pages= file_to_pages[file_name]

    texts.append(" ".join(pages))
df_annotations["text"] = texts

# %%
 del file_to_pages

# %%
df_annotations = df_annotations[~df_annotations.has_sap.isna()]

# %%
df_annotations["has_sap"].value_counts()
# Out:
# 0    6150
# 1    5774
# Name: has_sap, dtype: int64

# %%
df_train = df_annotations[df_annotations.train_val == "train"]
df_val = df_annotations[df_annotations.train_val == "val"]

# %%
# Specially engineered regex to include 95%, 95%ci, etc
vectoriser = CountVectorizer(lowercase=True, stop_words=stops, min_df=5, max_features=1500,
                             token_pattern=r'[59][05]%?(?:ci)?|[a-z][a-z]+')
transformer = TfidfTransformer()

nb = MultinomialNB()
model = make_pipeline(vectoriser, transformer, nb)

# %%
model.fit(df_train.text, df_train.has_sap)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abbott', 'abello', 'actelion', 'aesica', 'air', 'alcon', 'alk', 'allergan', 'almus', 'alpharma', 'altana', 'amgen', 'apr', 'april', 'aps', 'assertio', 'astrazeneca', 'aug', 'august', 'aventis', 'bausch', 'baxter', 'bayer', 'becton', 'beiersdorf', 'benckiser', 'berk', 'biogen', 'bioscience', 'boehringer', 'boots', 'bpl', 'braun', 'bristol', 'celltech', 'cephalon', 'chemidex', 'chiesi', 'chugai', 'cilag', 'clinical', 'colgate', 'coloplast', 'consumer', 'convatec', 'cow', 'cp', 'crookes', 'davis', 'dec', 'december', 'dentsply', 'diagnostics', 'dickinson', 'dista', 'dupont', 'eisai', 'ethicon', 'fabre', 'feb', 'february', 'ferring', 'florizel', 'fresenius', 'fri', 'friday', 'galderma', 'galpharm', 'gamble', 'garnier', 'gate', 'ge', 'gilead', 'glaxosmithkline', 'gr', 'grifols', 'gsk', 'hakko', 'health', 'healthcare', 'heinz', 'hillcross', 'hoechst', 'ingelheim', 'invicta', 'ipsen', 'ith', 'ivax', 'janssen', 'january', 'jul', 'july', 'jun', 'june', 'king', 'kyowa', 'labo', 'lambert', 'lederie', 'leo', 'lifescan', 'lilly', 'lnlycke', 'lomb', 'ltd', 'lundbeck', 'mar', 'march', 'marion', 'martindale', 'may', 'mayne', 'mcneil', 'meda', 'medac', 'medical', 'medisense', 'menarini', 'merck', 'milupa', 'monday', 'msd', 'myers', 'nenthal', 'nestl', 'neutrogena', 'nordisk', 'nov', 'novartis', 'november', 'novo', 'nutrition', 'nycomed', 'oasteur', 'oct', 'octapharma', 'october', 'orion', 'otsuka', 'palmolive', 'parke', 'pfizer', 'pharm', 'pharma', 'pharmaceuticals', 'pharmacia', 'plough', 'poulenc', 'procter', 'products', 'reckitt', 'rh', 'roche', 'rosemont', 'ross', 'roussel', 'rybar', 'salts', 'sandoz', 'sankyo', 'sanofi', 'sat', 'saturday', 'schering', 'schwarz', 'searle', 'sep', 'september', 'serono', 'servier', 'shire', 'shs', 'sigma', 'sma', 'snbts', 'solvay', 'squibb', 'ssl', 'stiefel', 'sun', 'sunday', 'synth', 'taient', 'tais', 'tait', 'takeda', 'tant', 'tante', 'tantes', 'tants', 'taro', 'teva', 'thornton', 'thu', 'thursday', 'tiez', 'tions', 'trinity', 'tue', 'tuesday', 'tyco', 'univar', 'valeant', 'viatris', 'warner', 'wed', 'wednesday', 'wockhardt', 'wyeth', 'yamanouchi'] not in stop_words.
#   % sorted(inconsistent)
# Pipeline(steps=[('countvectorizer',
#                  CountVectorizer(max_features=1500, min_df=5,
#                                  stop_words={'A&H', 'ALK-Abello', 'APS',
#                                              'Abbott', 'Actelion',
#                                              'Aesica pharmaceuticals',
#                                              'Air Products', 'Alcon',
#                                              'Allergan',
#                                              'Almus Pharmaceuticals',
#                                              'Alpharma', 'Altana', 'Amgen',
#                                              'Apr', 'April', 'Assertio',
#                                              'AstraZeneca', 'Aug', 'August',
#                                              'Aventis Pharma', 'BPL',
#                                              'Bausch & Lomb', 'Baxter',
#                                              'Baxter BioScience', 'Bayer',
#                                              'Becton Dickinson', 'Beiersdorf',
#                                              'Berk', 'Biogen',
#                                              'Boehringer Ingelheim', ...},
#                                  token_pattern='[59][05]%?(?:ci)?|[a-z][a-z]+')),
#                 ('tfidftransformer', TfidfTransformer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
df_val["y_pred"] = model.predict(df_val.text)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_val["y_pred_proba"] = model.predict_proba(df_val.text)[:,1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sap_ground_truths = df_val.has_sap
pred_sap = df_val.y_pred

# %%
acc = accuracy_score(sap_ground_truths, pred_sap)
print (f"SAP accuracy {acc}")
# Out:
# SAP accuracy 0.8175115207373271

# %%
ConfusionMatrixDisplay.from_predictions(sap_ground_truths, pred_sap)
plt.xticks(rotation=90)
;
# Out:
# ''

# %%
all_aucs = []
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(sap_ground_truths, pred_sap)
print (f"SAP ROC AUC {roc_auc}")
# Out:
# SAP ROC AUC 0.817525415896488

# %%
plt.figure()
lw = 2
    
for i in [1]:
    fpr, tpr, _ = roc_curve(sap_ground_truths, pred_sap)
    roc_auc = auc(fpr, tpr)
    plt.plot(
        fpr,
        tpr,
        # color="darkorange",
        lw=lw,
        label=f"ROC curve SAP = {i} (area = {roc_auc:0.2f})"
    )
    plt.plot([0, 1], [0, 1], color="gray", alpha=0.5, lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
fake_document = " ".join(vectoriser.vocabulary_)
vectorised_document = vectoriser.transform([fake_document])
transformed_document = transformer.transform(vectorised_document)
probas = np.zeros((transformed_document.shape[1]))

for prediction_idx in [1]:
      print(f"Strongest predictors for class {prediction_idx}\n")
      for i in range(transformed_document.shape[1]):
          zeros = np.zeros(transformed_document.shape)
          zeros[0, i] = transformed_document[0, i]
          proba = nb.predict_log_proba(zeros)
          probas[i] = proba[0, prediction_idx]

      for ctr, j in enumerate(np.argsort(-probas)):
          for w, i in vectoriser.vocabulary_.items():
              if i == j:
                  print(f"{ctr}\t{w}")
# Out:
# Strongest predictors for class 1
#
# 0	gvhd
# 1	mk
# 2	ctep
# 3	donor
# 4	encounter
# 5	accrual
# 6	lenalidomide
# 7	pembrolizumab
# 8	dilation
# 9	intraluminal
# 10	stem
# 11	transplant
# 12	trastuzumab
# 13	bevacizumab
# 14	radiation
# 15	transplantation
# 16	leukemia
# 17	myeloma
# 18	nih
# 19	nci
# 20	carboplatin
# 21	aml
# 22	paclitaxel
# 23	melanoma
# 24	smoking
# 25	https
# 26	prostate
# 27	specimens
# 28	oncol
# 29	specimen
# 30	block
# 31	registration
# 32	hemorrhage
# 33	pet
# 34	ki
# 35	tumors
# 36	marrow
# 37	artery
# 38	cognitive
# 39	biopsies
# 40	metastatic
# 41	journal
# 42	dr
# 43	atezolizumab
# 44	chemotherapy
# 45	toxicities
# 46	dsmb
# 47	relapsed
# 48	depression
# 49	expression
# 50	breast
# 51	brain
# 52	http
# 53	cbc
# 54	hold
# 55	res
# 56	unspecified
# 57	consciousness
# 58	oncology
# 59	side
# 60	office
# 61	hematologic
# 62	pi
# 63	lymphoma
# 64	metastases
# 65	true
# 66	tube
# 67	vascular
# 68	vein
# 69	metabolic
# 70	nf
# 71	percutaneous
# 72	pathway
# 73	project
# 74	tumor
# 75	activation
# 76	refractory
# 77	cancer
# 78	neck
# 79	gr
# 80	mice
# 81	dexamethasone
# 82	tissue
# 83	molecular
# 84	rt
# 85	rituximab
# 86	www
# 87	probability
# 88	calendar
# 89	dysfunction
# 90	measurable
# 91	fracture
# 92	recovery
# 93	improve
# 94	prospective
# 95	neutropenia
# 96	lymph
# 97	survival
# 98	inflammation
# 99	anc
# 100	models
# 101	treating
# 102	children
# 103	surgery
# 104	sum
# 105	mortality
# 106	induction
# 107	malignant
# 108	peripheral
# 109	carcinoma
# 110	cells
# 111	edema
# 112	template
# 113	preliminary
# 114	many
# 115	cc
# 116	advanced
# 117	po
# 118	gene
# 119	center
# 120	recurrent
# 121	prophylaxis
# 122	disorders
# 123	contrast
# 124	role
# 125	large
# 126	resistant
# 127	recurrence
# 128	kidney
# 129	problems
# 130	immune
# 131	future
# 132	individuals
# 133	six
# 134	cd
# 135	decreased
# 136	pharmacy
# 137	metabolism
# 138	agent
# 139	differences
# 140	go
# 141	sleep
# 142	men
# 143	coronary
# 144	experimental
# 145	toxicity
# 146	nausea
# 147	med
# 148	alpha
# 149	nodes
# 150	complications
# 151	hypothesis
# 152	recruitment
# 153	improved
# 154	cycles
# 155	biopsy
# 156	resistance
# 157	portion
# 158	ii
# 159	seen
# 160	mutations
# 161	fluid
# 162	insulin
# 163	pain
# 164	scan
# 165	rates
# 166	mail
# 167	mediated
# 168	effects
# 169	working
# 170	thus
# 171	lung
# 172	clin
# 173	estimate
# 174	vs
# 175	small
# 176	mri
# 177	urinary
# 178	progressive
# 179	lesions
# 180	benefits
# 181	approach
# 182	myocardial
# 183	like
# 184	cell
# 185	ef
# 186	society
# 187	alone
# 188	beta
# 189	proposed
# 190	setting
# 191	muscle
# 192	art
# 193	bone
# 194	submission
# 195	risks
# 196	compare
# 197	develop
# 198	although
# 199	power
# 200	reduce
# 201	significantly
# 202	mtd
# 203	endoscopic
# 204	responses
# 205	describe
# 206	limiting
# 207	imaging
# 208	cm
# 209	diabetic
# 210	scans
# 211	five
# 212	hypertension
# 213	intravenous
# 214	despite
# 215	members
# 216	expedited
# 217	steroids
# 218	ind
# 219	light
# 220	decrease
# 221	several
# 222	cardiac
# 223	solid
# 224	program
# 225	better
# 226	room
# 227	questionnaires
# 228	flow
# 229	dna
# 230	exam
# 231	material
# 232	abdominal
# 233	rash
# 234	inhibition
# 235	vial
# 236	diabetes
# 237	alcohol
# 238	closed
# 239	invasive
# 240	cr
# 241	prolonged
# 242	fda
# 243	greater
# 244	oxygen
# 245	induced
# 246	modifications
# 247	psychiatric
# 248	possibly
# 249	four
# 250	li
# 251	receptor
# 252	scores
# 253	platelet
# 254	pdf
# 255	unknown
# 256	ctcae
# 257	iii
# 258	surgical
# 259	release
# 260	adults
# 261	multi
# 262	fatigue
# 263	three
# 264	member
# 265	infections
# 266	common
# 267	mechanism
# 268	fever
# 269	increased
# 270	undergo
# 271	50%
# 272	various
# 273	likely
# 274	institution
# 275	resume
# 276	showed
# 277	malignancy
# 278	remission
# 279	agents
# 280	specifically
# 281	routine
# 282	less
# 283	adherence
# 284	identify
# 285	delayed
# 286	policy
# 287	types
# 288	family
# 289	reduced
# 290	experience
# 291	increases
# 292	grade
# 293	binding
# 294	questions
# 295	wk
# 296	gastrointestinal
# 297	kept
# 298	performance
# 299	panel
# 300	outcomes
# 301	comparison
# 302	suggest
# 303	chest
# 304	found
# 305	safe
# 306	vitro
# 307	dependent
# 308	gi
# 309	lab
# 310	acid
# 311	left
# 312	diagnosed
# 313	inflammatory
# 314	high
# 315	inpatient
# 316	application
# 317	enroll
# 318	care
# 319	asked
# 320	free
# 321	nivolumab
# 322	low
# 323	recent
# 324	supportive
# 325	loss
# 326	acute
# 327	demonstrated
# 328	disorder
# 329	stored
# 330	ecog
# 331	amount
# 332	please
# 333	shown
# 334	processing
# 335	two
# 336	would
# 337	burden
# 338	support
# 339	ms
# 340	work
# 341	nsclc
# 342	usually
# 343	association
# 344	pediatric
# 345	targeted
# 346	iv
# 347	effect
# 348	versus
# 349	differential
# 350	brief
# 351	much
# 352	begin
# 353	whole
# 354	solution
# 355	able
# 356	drawn
# 357	ability
# 358	frequently
# 359	compared
# 360	intervention
# 361	determine
# 362	stage
# 363	renal
# 364	syndrome
# 365	started
# 366	therapy
# 367	studies
# 368	cycle
# 369	process
# 370	discharge
# 371	measure
# 372	standard
# 373	involved
# 374	participating
# 375	bleeding
# 376	social
# 377	removed
# 378	risk
# 379	mm
# 380	kinase
# 381	injury
# 382	thyroid
# 383	plan
# 384	higher
# 385	clearly
# 386	function
# 387	dlt
# 388	involvement
# 389	affect
# 390	infected
# 391	target
# 392	progression
# 393	median
# 394	physician
# 395	similar
# 396	regimens
# 397	skin
# 398	taking
# 399	partial
# 400	lesion
# 401	causes
# 402	beginning
# 403	unexpected
# 404	factors
# 405	head
# 406	impact
# 407	submitted
# 408	call
# 409	factor
# 410	dis
# 411	developed
# 412	distribution
# 413	purposes
# 414	given
# 415	plus
# 416	human
# 417	minimal
# 418	forms
# 419	elevated
# 420	already
# 421	recist
# 422	line
# 423	protection
# 424	prevent
# 425	unit
# 426	different
# 427	incidence
# 428	past
# 429	evidence
# 430	chronic
# 431	could
# 432	monitored
# 433	preparation
# 434	clearance
# 435	enrollment
# 436	topical
# 437	response
# 438	associated
# 439	sent
# 440	measures
# 441	numbers
# 442	institutional
# 443	groups
# 444	reduction
# 445	continuous
# 446	involving
# 447	stop
# 448	previously
# 449	via
# 450	initial
# 451	cfr
# 452	avoid
# 453	increase
# 454	lower
# 455	knowledge
# 456	infectious
# 457	infection
# 458	weekly
# 459	currently
# 460	etc
# 461	hi
# 462	sodium
# 463	provides
# 464	twice
# 465	chart
# 466	resulting
# 467	ct
# 468	consider
# 469	sterile
# 470	place
# 471	noted
# 472	sensitivity
# 473	ph
# 474	submit
# 475	treated
# 476	controlled
# 477	concurrent
# 478	additionally
# 479	combined
# 480	major
# 481	control
# 482	applied
# 483	location
# 484	counts
# 485	receiving
# 486	however
# 487	intake
# 488	outcome
# 489	dm
# 490	unique
# 491	take
# 492	nature
# 493	one
# 494	admission
# 495	directly
# 496	combination
# 497	established
# 498	diagnostic
# 499	heart
# 500	interaction
# 501	intensive
# 502	persistent
# 503	published
# 504	well
# 505	participate
# 506	strong
# 507	significance
# 508	clear
# 509	identified
# 510	potentially
# 511	reports
# 512	white
# 513	characterized
# 514	component
# 515	references
# 516	back
# 517	deaths
# 518	authorization
# 519	unable
# 520	still
# 521	nct
# 522	cause
# 523	evaluating
# 524	step
# 525	effective
# 526	glucose
# 527	therapeutic
# 528	self
# 529	none
# 530	multiple
# 531	therefore
# 532	along
# 533	meeting
# 534	disease
# 535	address
# 536	treat
# 537	achieved
# 538	minute
# 539	pressure
# 540	allergic
# 541	ml
# 542	genetic
# 543	national
# 544	even
# 545	lack
# 546	delay
# 547	illness
# 548	training
# 549	requiring
# 550	board
# 551	creatinine
# 552	fatal
# 553	child
# 554	red
# 555	core
# 556	diseases
# 557	requires
# 558	general
# 559	negative
# 560	expected
# 561	since
# 562	hr
# 563	capsules
# 564	kg
# 565	monitoring
# 566	cns
# 567	important
# 568	also
# 569	stroke
# 570	management
# 571	inhibitor
# 572	normal
# 573	biological
# 574	receive
# 575	activity
# 576	improvement
# 577	clinic
# 578	calcium
# 579	might
# 580	symptomatic
# 581	devices
# 582	another
# 583	issues
# 584	evaluable
# 585	type
# 586	pd
# 587	indicate
# 588	rate
# 589	means
# 590	stopping
# 591	person
# 592	update
# 593	main
# 594	needed
# 595	staff
# 596	best
# 597	become
# 598	rights
# 599	possibility
# 600	known
# 601	present
# 602	organ
# 603	randomized
# 604	basis
# 605	course
# 606	failure
# 607	abstinence
# 608	obtained
# 609	designed
# 610	procedure
# 611	min
# 612	health
# 613	initiated
# 614	visual
# 615	hour
# 616	need
# 617	scientific
# 618	orally
# 619	resolution
# 620	mi
# 621	stopped
# 622	derived
# 623	initiation
# 624	public
# 625	reviewed
# 626	headache
# 627	adverse
# 628	interest
# 629	measured
# 630	every
# 631	depending
# 632	reaction
# 633	tolerated
# 634	retention
# 635	cyp
# 636	cs
# 637	blood
# 638	recommended
# 639	sequence
# 640	later
# 641	eligibility
# 642	pregnant
# 643	benefit
# 644	generally
# 645	functional
# 646	95
# 647	guidelines
# 648	particular
# 649	antigen
# 650	check
# 651	potential
# 652	regimen
# 653	id
# 654	consent
# 655	evaluation
# 656	item
# 657	whether
# 658	participation
# 659	beyond
# 660	50
# 661	experiences
# 662	investigation
# 663	access
# 664	question
# 665	generated
# 666	questionnaire
# 667	achieve
# 668	minutes
# 669	95%
# 670	next
# 671	current
# 672	either
# 673	anti
# 674	due
# 675	protein
# 676	outside
# 677	xi
# 678	diagnosis
# 679	measurement
# 680	regular
# 681	eligible
# 682	maintained
# 683	rest
# 684	uncontrolled
# 685	presence
# 686	systems
# 687	life
# 688	cardiovascular
# 689	remaining
# 690	long
# 691	occur
# 692	include
# 693	form
# 694	sd
# 695	require
# 696	oral
# 697	scale
# 698	pro
# 699	bp
# 700	threatening
# 701	complete
# 702	specific
# 703	database
# 704	version
# 705	pre
# 706	category
# 707	hepatic
# 708	contains
# 709	practice
# 710	years
# 711	affected
# 712	approval
# 713	related
# 714	containing
# 715	reporting
# 716	total
# 717	frequency
# 718	review
# 719	anticipated
# 720	inhibitors
# 721	adequate
# 722	stable
# 723	followed
# 724	development
# 725	modification
# 726	variable
# 727	detected
# 728	caused
# 729	ntr
# 730	daily
# 731	occurred
# 732	evaluated
# 733	reactions
# 734	positive
# 735	ut
# 736	death
# 737	certain
# 738	approved
# 739	starting
# 740	drugs
# 741	replacement
# 742	single
# 743	assess
# 744	st
# 745	based
# 746	name
# 747	potassium
# 748	entire
# 749	make
# 750	congenital
# 751	prolongation
# 752	upon
# 753	copy
# 754	materials
# 755	respectively
# 756	reported
# 757	55
# 758	previous
# 759	concentrations
# 760	hours
# 761	significant
# 762	rules
# 763	systemic
# 764	cannot
# 765	action
# 766	status
# 767	order
# 768	prepared
# 769	mg
# 770	average
# 771	addition
# 772	volume
# 773	assay
# 774	obtain
# 775	standards
# 776	subsequent
# 777	90
# 778	direct
# 779	count
# 780	report
# 781	symptoms
# 782	withdraw
# 783	statistical
# 784	respiratory
# 785	provide
# 786	model
# 787	file
# 788	inclusion
# 789	phase
# 790	alternative
# 791	occurs
# 792	upper
# 793	right
# 794	entry
# 795	estimated
# 796	grading
# 797	asymptomatic
# 798	immediate
# 799	limited
# 800	log
# 801	ra
# 802	first
# 803	existing
# 804	adjusted
# 805	note
# 806	events
# 807	allow
# 808	index
# 809	quality
# 810	determined
# 811	confidence
# 812	design
# 813	possible
# 814	example
# 815	half
# 816	system
# 817	duration
# 818	request
# 819	may
# 820	includes
# 821	without
# 822	responsible
# 823	fu
# 824	observations
# 825	mild
# 826	personal
# 827	validated
# 828	identification
# 829	effort
# 830	test
# 831	purpose
# 832	secondary
# 833	surface
# 834	extent
# 835	event
# 836	wit
# 837	enrolled
# 838	discussed
# 839	adult
# 840	range
# 841	variables
# 842	severe
# 843	occurring
# 844	deviation
# 845	paper
# 846	limit
# 847	systolic
# 848	90%
# 849	active
# 850	results
# 851	result
# 852	equivalent
# 853	apply
# 854	underlying
# 855	dl
# 856	supply
# 857	within
# 858	serious
# 859	maintain
# 860	criteria
# 861	available
# 862	repeated
# 863	early
# 864	injections
# 865	exclusion
# 866	assigned
# 867	albumin
# 868	hormone
# 869	calculated
# 870	healthy
# 871	highly
# 872	disability
# 873	follows
# 874	impairment
# 875	manner
# 876	regarding
# 877	good
# 878	fully
# 879	profile
# 880	close
# 881	doses
# 882	selection
# 883	percent
# 884	met
# 885	rna
# 886	condition
# 887	weeks
# 888	indicated
# 889	testing
# 890	immediately
# 891	outlined
# 892	collection
# 893	measurements
# 894	discussion
# 895	body
# 896	received
# 897	sufficient
# 898	decision
# 899	methods
# 900	pfs
# 901	observed
# 902	record
# 903	informed
# 904	history
# 905	sit
# 906	following
# 907	necessary
# 908	tr
# 909	soc
# 910	point
# 911	finding
# 912	hypersensitivity
# 913	demographic
# 914	description
# 915	area
# 916	administer
# 917	meet
# 918	administration
# 919	mean
# 920	procedures
# 921	ar
# 922	except
# 923	locally
# 924	dosage
# 925	emergency
# 926	considerations
# 927	authorized
# 928	egfr
# 929	medical
# 930	storage
# 931	confirmation
# 932	regardless
# 933	absence
# 934	consistent
# 935	biomarkers
# 936	intervals
# 937	evaluate
# 938	maintenance
# 939	including
# 940	dose
# 941	wi
# 942	analysis
# 943	objectives
# 944	serum
# 945	contact
# 946	conditions
# 947	receipt
# 948	rating
# 949	points
# 950	classified
# 951	instructed
# 952	sample
# 953	changes
# 954	ul
# 955	administered
# 956	prior
# 957	findings
# 958	deemed
# 959	discretion
# 960	full
# 961	eye
# 962	region
# 963	additional
# 964	assessed
# 965	continued
# 966	abuse
# 967	document
# 968	sign
# 969	made
# 970	compliance
# 971	home
# 972	continue
# 973	individual
# 974	di
# 975	telephone
# 976	bl
# 977	tested
# 978	signed
# 979	deviations
# 980	ci
# 981	overview
# 982	described
# 983	moderate
# 984	leading
# 985	liver
# 986	method
# 987	phosphatase
# 988	ca
# 989	medication
# 990	intensity
# 991	entered
# 992	onset
# 993	vaccines
# 994	temperature
# 995	according
# 996	listed
# 997	relative
# 998	defined
# 999	error
# 1000	device
# 1001	ab
# 1002	ratio
# 1003	urine
# 1004	records
# 1005	longer
# 1006	medications
# 1007	absolute
# 1008	follow
# 1009	required
# 1010	tests
# 1011	fr
# 1012	hemoglobin
# 1013	completion
# 1014	placebo
# 1015	responsibility
# 1016	occurrence
# 1017	conducted
# 1018	world
# 1019	ensure
# 1020	resolved
# 1021	maximum
# 1022	physical
# 1023	alkaline
# 1024	clinical
# 1025	mutation
# 1026	vaccine
# 1027	relationship
# 1028	collect
# 1029	sub
# 1030	act
# 1031	documentation
# 1032	day
# 1033	copies
# 1034	collected
# 1035	analyzed
# 1036	perform
# 1037	committee
# 1038	drug
# 1039	suspected
# 1040	requested
# 1041	inform
# 1042	taken
# 1043	completed
# 1044	open
# 1045	modified
# 1046	af
# 1047	exposure
# 1048	requirements
# 1049	monotherapy
# 1050	notify
# 1051	arthritis
# 1052	class
# 1053	substance
# 1054	key
# 1055	value
# 1056	indication
# 1057	performed
# 1058	randomization
# 1059	supplied
# 1060	assurance
# 1061	selected
# 1062	assignment
# 1063	exception
# 1064	fixed
# 1065	ongoing
# 1066	rd
# 1067	conduct
# 1068	optional
# 1069	agree
# 1070	permanently
# 1071	separate
# 1072	personnel
# 1073	read
# 1074	intended
# 1075	appropriate
# 1076	requirement
# 1077	clinically
# 1078	notified
# 1079	er
# 1080	remain
# 1081	statement
# 1082	consecutive
# 1083	reasonable
# 1084	meets
# 1085	otherwise
# 1086	minimum
# 1087	treatments
# 1088	formulation
# 1089	samples
# 1090	independent
# 1091	instructions
# 1092	reasons
# 1093	audit
# 1094	covid
# 1095	written
# 1096	evaluations
# 1097	approximately
# 1098	discontinue
# 1099	expansion
# 1100	ng
# 1101	documented
# 1102	joint
# 1103	influenza
# 1104	th
# 1105	multicenter
# 1106	shall
# 1107	return
# 1108	usual
# 1109	repeat
# 1110	withdrawal
# 1111	baseline
# 1112	list
# 1113	abnormal
# 1114	statistics
# 1115	local
# 1116	brochure
# 1117	confirm
# 1118	assessment
# 1119	march
# 1120	discontinued
# 1121	determination
# 1122	fasting
# 1123	ps
# 1124	unless
# 1125	terms
# 1126	hormonal
# 1127	double
# 1128	documents
# 1129	females
# 1130	cti
# 1131	sided
# 1132	antibody
# 1133	ny
# 1134	substantial
# 1135	signature
# 1136	april
# 1137	bilirubin
# 1138	oct
# 1139	provided
# 1140	products
# 1141	accurate
# 1142	thereafter
# 1143	scheduled
# 1144	ri
# 1145	monitor
# 1146	safety
# 1147	recorded
# 1148	allowed
# 1149	interval
# 1150	screen
# 1151	july
# 1152	therapies
# 1153	confirmed
# 1154	orr
# 1155	pregnancy
# 1156	escalation
# 1157	notification
# 1158	promptly
# 1159	comply
# 1160	judgment
# 1161	consultation
# 1162	position
# 1163	june
# 1164	revised
# 1165	aft
# 1166	withdrawn
# 1167	international
# 1168	pulse
# 1169	items
# 1170	soon
# 1171	sections
# 1172	reference
# 1173	acceptable
# 1174	abnormalities
# 1175	interruption
# 1176	page
# 1177	observation
# 1178	labeling
# 1179	august
# 1180	original
# 1181	retained
# 1182	bj
# 1183	os
# 1184	destruction
# 1185	adjustment
# 1186	actual
# 1187	throughout
# 1188	classification
# 1189	timing
# 1190	accordance
# 1191	feb
# 1192	efficacy
# 1193	endpoint
# 1194	medically
# 1195	organization
# 1196	guideline
# 1197	special
# 1198	site
# 1199	proportion
# 1200	blinding
# 1201	ast
# 1202	product
# 1203	demographics
# 1204	concentration
# 1205	publication
# 1206	height
# 1207	values
# 1208	separately
# 1209	parent
# 1210	mar
# 1211	antibodies
# 1212	ae
# 1213	intent
# 1214	examination
# 1215	supplies
# 1216	regulations
# 1217	parameters
# 1218	ni
# 1219	electronic
# 1220	detailed
# 1221	label
# 1222	becomes
# 1223	change
# 1224	igg
# 1225	visits
# 1226	interim
# 1227	apr
# 1228	analyses
# 1229	september
# 1230	female
# 1231	corresponding
# 1232	opinion
# 1233	november
# 1234	presented
# 1235	planned
# 1236	signing
# 1237	dispensing
# 1238	enter
# 1239	ethical
# 1240	table
# 1241	causal
# 1242	biomarker
# 1243	agreement
# 1244	descriptive
# 1245	na
# 1246	schedule
# 1247	worsening
# 1248	week
# 1249	stratified
# 1250	signs
# 1251	disclosure
# 1252	reason
# 1253	recording
# 1254	tablets
# 1255	exploratory
# 1256	designated
# 1257	male
# 1258	amendments
# 1259	virus
# 1260	alt
# 1261	lost
# 1262	pharmacokinetics
# 1263	law
# 1264	abnormality
# 1265	endpoints
# 1266	percentage
# 1267	set
# 1268	activities
# 1269	applicable
# 1270	pharmacology
# 1271	returned
# 1272	pe
# 1273	legal
# 1274	investigational
# 1275	visit
# 1276	ss
# 1277	crfs
# 1278	sae
# 1279	discontinuation
# 1280	final
# 1281	european
# 1282	february
# 1283	bilateral
# 1284	accountability
# 1285	january
# 1286	guidance
# 1287	nd
# 1288	hepatitis
# 1289	whichever
# 1290	im
# 1291	handling
# 1292	concomitant
# 1293	dec
# 1294	screening
# 1295	neurological
# 1296	dosing
# 1297	nti
# 1298	pl
# 1299	december
# 1300	qualified
# 1301	specified
# 1302	blind
# 1303	randomised
# 1304	corrected
# 1305	dispensed
# 1306	october
# 1307	childbearing
# 1308	ei
# 1309	period
# 1310	saes
# 1311	administrative
# 1312	assent
# 1313	coagulation
# 1314	permitted
# 1315	ot
# 1316	jun
# 1317	unused
# 1318	representative
# 1319	responsibilities
# 1320	window
# 1321	overdose
# 1322	details
# 1323	section
# 1324	termination
# 1325	tolerability
# 1326	updated
# 1327	vital
# 1328	authority
# 1329	pri
# 1330	refer
# 1331	aes
# 1332	contraceptive
# 1333	sep
# 1334	nov
# 1335	captured
# 1336	jul
# 1337	causality
# 1338	asthma
# 1339	tables
# 1340	gcp
# 1341	inr
# 1342	property
# 1343	contraception
# 1344	abbreviations
# 1345	nt
# 1346	alanine
# 1347	global
# 1348	ed
# 1349	inspection
# 1350	ib
# 1351	legally
# 1352	partner
# 1353	ich
# 1354	ur
# 1355	hcv
# 1356	laws
# 1357	eri
# 1358	oll
# 1359	packaging
# 1360	ad
# 1361	ti
# 1362	crf
# 1363	assessments
# 1364	periods
# 1365	auc
# 1366	examinations
# 1367	premature
# 1368	sciences
# 1369	tablet
# 1370	pharmacokinetic
# 1371	morning
# 1372	cl
# 1373	manual
# 1374	diary
# 1375	aminotransferase
# 1376	run
# 1377	ic
# 1378	cts
# 1379	medicinal
# 1380	ec
# 1381	representatives
# 1382	ns
# 1383	ion
# 1384	changed
# 1385	summarized
# 1386	chemistry
# 1387	sampling
# 1388	hematology
# 1389	unblinding
# 1390	ati
# 1391	pharmacodynamic
# 1392	roche
# 1393	prohibited
# 1394	authorities
# 1395	criterion
# 1396	designee
# 1397	ol
# 1398	oi
# 1399	aug
# 1400	amendment
# 1401	urinalysis
# 1402	countries
# 1403	emergent
# 1404	ort
# 1405	cmax
# 1406	electrocardiogram
# 1407	mln
# 1408	cli
# 1409	synopsis
# 1410	ee
# 1411	unblinded
# 1412	clarification
# 1413	ecg
# 1414	ak
# 1415	itt
# 1416	text
# 1417	nts
# 1418	rescue
# 1419	inc
# 1420	hoffmann
# 1421	fi
# 1422	esti
# 1423	country
# 1424	copd
# 1425	ys
# 1426	mc
# 1427	ess
# 1428	restrictions
# 1429	eli
# 1430	unscheduled
# 1431	titration
# 1432	icf
# 1433	su
# 1434	extension
# 1435	qd
# 1436	ers
# 1437	ay
# 1438	ro
# 1439	mmol
# 1440	sap
# 1441	ltd
# 1442	cro
# 1443	ecrf
# 1444	ecrfs
# 1445	amended
# 1446	hba
# 1447	ie
# 1448	ass
# 1449	eudract
# 1450	novo
# 1451	bi
# 1452	dmc
# 1453	pharmaceuticals
# 1454	teaes
# 1455	therapeutics
# 1456	ecgs
# 1457	cu
# 1458	nn
# 1459	psoriasis
# 1460	ari
# 1461	fo
# 1462	bms
# 1463	ada
# 1464	om
# 1465	predose
# 1466	eti
# 1467	eq
# 1468	io
# 1469	gs
# 1470	eot
# 1471	pfizer
# 1472	pf
# 1473	gmbh
# 1474	pli
# 1475	clean
# 1476	tio
# 1477	medi
# 1478	ert
# 1479	cci
# 1480	ly
# 1481	novartis
# 1482	ub
# 1483	boehringer
# 1484	ingelheim
# 1485	tak
# 1486	gsk
# 1487	gilead
# 1488	ble
# 1489	prop
# 1490	tho
# 1491	ark
# 1492	ial
# 1493	riz
# 1494	xte
# 1495	reo
# 1496	lica
# 1497	nly
# 1498	jec
# 1499	merc
