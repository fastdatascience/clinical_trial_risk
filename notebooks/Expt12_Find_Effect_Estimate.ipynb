# %%
import os, re
import numpy as np
import pickle as pkl

# %%
input_folder = "../data/preprocessed_tika/"

# %%
file_to_text = {}
for root, folder, files in os.walk(input_folder):
    for file_name in files:
        if not file_name.endswith("pkl"):
            continue
        pdf_file = re.sub(".pkl", "", file_name)
        
        full_file = input_folder + "/" + file_name
#         print (full_file)
        with open(full_file, 'rb') as f:
            text = pkl.load(f)
        file_to_text[pdf_file] = text

# %%
sap_regex = re.compile(r"(?i)statistical\s*analysis\s*plan")

sap_regex = re.compile(r"(?i)\bSAP\b")

sap_regex = re.compile(r"(?i)\bdata\s*analysis\s*plan\b")

sap_regex = re.compile(r"(?i)\bDAP\b")


sap_regex = re.compile(r"(?i)\b(effect\s*(?:estimate|size)s?|reductions)\b|\d%+\b")

# %%
file_to_text["TB-TB-2018-M-P-A.pdf"][146]
# Out:
# '\n\t\nStatistical\tanalysis\tplan,\tdated\t14\tDecember\t2016 \n\n'

# %%
for file, pages in file_to_text.items():
    print (file, len(pages))
    for page_no, page_text in enumerate(pages):
        matches = sap_regex.finditer(page_text)
               
        for match in matches:
            l = int(np.max((0, match.start() - 30)))
            r = int(np.min((len(page_text), match.end() + 30)))
            print ("\t", page_no, "\t",  page_text[l:r].replace("\n", " "))
# Out:
# TB-TB-2018-DAR-PIA.pdf 68
# TB-TB-2018-M-P-A.pdf 161
# 	 18 	 lity (relative risk = 0.78,  95%CI = 0.59 -1.04). Significantl
# 	 88 	 ity (relative risk = 0.78,   95%CI = 0.59 -1.04). Significantl
# HIV-HIV-2016-Ayles-A Study of the HIV prevention Trials Network.pdf 166
# 	 12 	 ilto:epiwowa@jhmi.edu tel:%2B44%20%280%2920%207637%204314 mail
# 	 12 	 o:epiwowa@jhmi.edu tel:%2B44%20%280%2920%207637%204314 mailto:
# 	 12 	 iwowa@jhmi.edu tel:%2B44%20%280%2920%207637%204314 mailto:kalp
# 	 12 	 @jhmi.edu tel:%2B44%20%280%2920%207637%204314 mailto:kalpana.s
# 	 12 	 du tel:%2B44%20%280%2920%207637%204314 mailto:kalpana.sabapath
# 	 19 	 eral countries have reported  reductions in HIV prevalence, prevalence
# 	 21 	 ed to have contributed to the reductions in HIV prevalence  in Uganda,
# 	 23 	  arm, as well  as significant reductions in morbidity in HIV-infected
# 	 23 	 al-level benefits in terms of reductions in morbidity and mortality  a
# 	 78 	 tly  unblinded to data on the effect size after 12 months. The DSMB wil
# 	 78 	 ysis.     Review of estimated effect size (by comparing HIV incidence b
# 	 112 	 anges in behaviour leading to reductions in  HIV prevalence in urban M
# TB-TB-2019-T-A-b.pdf 389
# 	 184 	  whenever a HIV prevalence >  1%test is done, according to the
# HIV-HIV-2016-Laufer-Trimethoprim-Sulfamethoxazole-Chloroquine.pdf 100
# NTD-Filariasis-2019-Weil-DOLF IDA Papua New Guinea.pdf 90
# 	 35 	 , 80%  power for detecting an effect size of 30%). The primary endpoint
# HIV-HIV-2017-Abrams-IMPAACT P1101.pdf 85
# 	 5 	 : frieda@sun.ac.za       tel:27%2011%20989%209707 tel:(271)%20
# 	 5 	 eda@sun.ac.za       tel:27%2011%20989%209707 tel:(271)%20198-9
# 	 5 	 n.ac.za       tel:27%2011%20989%209707 tel:(271)%20198-99742 t
# 	 18 	 pected to lead to significant reductions in RAL concentrations in  chi
# NUT-A-2019-M-T.pdf 196
#    hospitalisation
#   infectial	s
#    reduction
#   longer-­‐te
#   largenably
# 	 102 	 on that have led directly to  reductions in hospitalisation of childre
# 	 104 	 generally been attributed to  reductions in bacterial infections[45, 4
# 	 105 	 moxazole) resulted in a 57% (95%CI 24%–76%) reduction in all-c
# 	 106 	 rategies for maintaining risk reductions over the longer-term.    The
# 	 126 	 this to 3954 SA cases. As the effect sizes are reasonably large  on the
# HIV-HIV-2018-IMPAACT-P1112.pdf 155
# EDD-rotavirus-2017-Isanaka-ROSE.pdf 210
# NTD-Y-2019-M-Y.pdf 66
# NTD-Chagas-2015-Morillo-BENEFIT.pdf 76
# 	 11 	  to 25% and stroke in 10% to 15%34. Sudden death is more frequ
# 	 38 	  to 25% and stroke in 10% to 15%34. Sudden death is more frequ
# MAT-V-2018-R-M.pdf 193
# 	 8 	 sh, have witnessed remarkable reductions in under-5 mortality rates ov
# 	 11 	 average, 0.44 z-score units (95%CI 0.06, 0.82) higher than inf
# 	 54 	 ortions, incidence rates) and effect  estimates (i.e., regression coefficient
# 	 75 	 sh, have witnessed remarkable reductions in under-5 mortality rates ov
# 	 78 	 average, 0.44 z-score units (95%CI 0.06, 0.82) higher than inf
# 	 124 	 ortions, incidence rates) and effect  estimates (i.e., regression coefficient
# 	 153 	 te progress towards achieving reductions in child mortality in low-inc
# 	 167 	 te progress towards achieving reductions in child mortality in low-inc
# HIV-HIV-2018-GSK1265744.pdf 124
# 	 30 	 K Parameter (Geometric mean [95%CI] (CVb%)  AUC(0- )  (g•h/m
# 	 41 	 treatment delays and/or dose  reductions will also be recorded in the
# POL-P-2018-O-A-L.pdf 97
# MAT-Hypothermia-2018-Hansen-Electricity-free Infant Warmer.pdf 56
# 	 4 	 on die in their first day. 1  Reductions in the neonatal mortality mus
# EDD-T-2019-S-T.pdf 105
# 	 12 	 CI: 26.8 – 71.8%] and 52.0% [95%CI:   23.2-70.0%], respectivel
# 	 12 	 accine   increased to 87.1% [95%CI: 44.2-96.9%] compared to 52
# 	 12 	 .2-96.9%] compared to 52.3% [95%CI: -4.2%, 78.2%] for the unco
# 	 54 	 CI: 26.8 – 71.8%] and 52.0% [95%CI:   23.2-70.0%], respectivel
# 	 54 	 accine   increased to 87.1% [95%CI: 44.2-96.9%] compared to 52
# 	 54 	 .2-96.9%] compared to 52.3% [95%CI: -4.2%, 78.2%] for the unco
# NTD-Hookwork-2018-Keiser-Efficacy and safety of a single.pdf 51
# 	 7 	 led-trials.com%2fISRCTN86603231%2f
# TB-TB-2018-Piazza-A Phase 1b, Randomized, Double-blind.pdf 56
# MAL-Malaria-2019-Llanos-Cuentas-Tafenoquine vs. Primaquine to.pdf 402
# HIV-HIV-2017-Corey-HVTN703-HPTN081.pdf 193
# 	 20 	 cally significant   transient reductions in HIV viral load in adults w
# 	 47 	 f H1: PE > 0% under different effect sizes  PE = PE10 = PE30    Uncondit
# 	 53 	 elevant prevention   efficacy effect sizes if annual incidence rates are
# 	 70 	 correlate of protection (with effect size 15%, 60%,   85% efficacy) at
# 	 73 	 e Wilcoxon rank sum test. The effect size indexing a difference between
# 	 73 	 two groups. Four   correlates effect sizes are considered, ranging from
# 	 73 	 ed, ranging from the weakest (Effect Size 1) to   the strongest (Effect
# 	 73 	 t Size 1) to   the strongest (Effect Size 4). The results show that the
# 	 73 	 is moderate power to   detect Effect Size 3 phenotypic sieve effects (s
# 	 74 	 group  breakthrough HIV-1s.   Effect Size 3 is biologically plausible b
# 	 74 	  each of the four   specified effect sizes PE(x) in Figure 4-11. For exa
# 	 74 	 Figure 4-11. For example, for Effect Size 3, the   most susceptible 11.
# 	 74 	 cacies is plausible. For this effect size there is 79.3% power to detec
# 	 75 	  = 0%) for the four different effect sizes studied in Figure 4-11   PE(x
# 	 75 	 tudied in Figure 4-11   PE(x) Effect Size in Figure 1-16 Susceptible
# 	 75 	 0%]   Resistant   [PE = 0%]   Effect Size 4 41.9% 23.3%   Effect Size 3
# 	 75 	   Effect Size 4 41.9% 23.3%   Effect Size 3 11.6% 2.8%   Effect Size 2
# 	 75 	    Effect Size 3 11.6% 2.8%   Effect Size 2 1.0% <0.1%   Effect Size 1
# 	 75 	    Effect Size 2 1.0% <0.1%   Effect Size 1 <0.1% <0.1%   Null Hypothes
# MAL-M-2019-A-S.pdf 92
# 	 60 	 .... 22    Crude and adjusted effect estimates..............................
# 	 63 	 . No interim  analysis of the effect size was conducted.   A total of 2
# 	 74 	 ing and standalone estimates  Effect estimates will be computed and presente
# 	 74 	 for each site separately. All effect  estimates will take the cluster design
# 	 77 	 will be calculated as  (RRR=100%x[1-RR]) and can be expressed
# 	 78 	 nalysis    Crude and adjusted effect estimates  The primary analyses will be
# 	 79 	  >10% relative difference in  effect estimate [e.g. RR 1.4 vs RR 1.6]) the
# 	 89 	 ach group, and the  estimated effect size and its  precision (such as 9
# 	 89 	 f both  absolute and relative effect  sizes is recommended       Ancillar
# 	 91 	 s 	10.3.1. Crude and adjusted effect estimates 	10.3.2. Adjustment for basel
# NTD-E-2017-A-A.pdf 60
# HIV-HIV-2017-Bekker-HVTN100.pdf 154
# MAL-Malaria-2019-Tinto-Extension to study MALARIA-055 PRI.pdf 100
# NUT-NUT-2019-A-I.pdf 132
# 	 53 	 action?uri=info%3Adoi%2F10.1371%2Fjournal.pone.0093776&represe
# 	 53 	 action?uri=info%3Adoi%2F10.1371%2Fjournal.pone.0093776&represe
# 	 53 	 action?uri=info%3Adoi%2F10.1371%2Fjournal.pone.0093776&represe
# 	 56 	 .nlm.nih.gov/pubmed/?term=Br%26%23x000fc%3Bssow%20H%5Bauth%5D
# 	 68 	 ine report 2011.     - “…with effect size=0.3…” – Should not the effect
# 	 68 	 t size=0.3…” – Should not the effect size be 0.4 based on information a
# 	 68 	  information above. Why this  effect size is chosen? Justify. May be we
# 	 68 	 stify why we cannot choose an effect size smaller  than this? This migh
# 	 68 	 gnificance.   - Response- The effect size has been calculated based on
# 	 68 	 p.  According to literatures, effect size is small if ≤0.2 and medium i
# 	 68 	  if ≤0.5. We have selected an effect size  between small and medium bas
# HIV-HIV-2018-M-A.pdf 182
# HIV-HIV-2017-L-I.pdf 148
# TB-TB-2019-M-A.pdf 115
# VAC-G-2016-VAC-G-2016-V.pdf 48
# 	 45 	 V-1&_user=7789910&_coverDate=12%2F11%2F2009&_alid=1269910819&_
# 	 45 	 user=7789910&_coverDate=12%2F11%2F2009&_alid=1269910819&_rdoc=
# 	 45 	 V-1&_user=7789910&_coverDate=12%2F11%2F2009&_alid=1269910819&_
# 	 45 	 user=7789910&_coverDate=12%2F11%2F2009&_alid=1269910819&_rdoc=
# 	 45 	 V-1&_user=7789910&_coverDate=12%2F11%2F2009&_alid=1269910819&_
# 	 45 	 user=7789910&_coverDate=12%2F11%2F2009&_alid=1269910819&_rdoc=
# HIV-HIV-2016-N-S.pdf 358
# 	 338 	  explore the influence on the effect size of those participants   repor
# VAC-Shigellosis-2019-Raqib-Shigella WRSS1 Vaccine trial in Bangladesh.pdf 64
# HIV-HIV-2017-Evolocumab-AMG145.pdf 95
# TB-TB-2015-D-A.pdf 124
# POL-P-2016-G-T.pdf 62
# 	 10 	 f 10%. Under the same assumed effect size  this sample size will provid
# 	 47 	 f 10%. Under the same assumed effect size this sample size will provide
# TB-TB-2019-Suliman-A Phase I_IIa Double-Blind.pdf 75
# MAT-Anemia-2015-Etheredge-Prenatal Iron Supplements Safety and.pdf 46
# 	 9 	 %; P = 0.017) [123]. Observed reductions in the prevalence of low birt
# 	 27 	 atment effects expressed as % reductions) based on a 2-sided  test for
# 	 28 	 ve good power to detect a 35% effect size, for placental malaria rates
# 	 28 	 ve good power to detect a 30% effect size and excellent power to detect
# 	 28 	 cellent power to detect a 40% effect size.     Continuous Variables: Th
# 	 28 	 ressed as percent changes in  effect size) based on a 2-sided test for
# 	 28 	 have  good power to detect an effect size of 8.5%, and excellent power
# 	 28 	 good power to  detect an 8.5% effect size, and excellent power to detec
# 	 28 	  excellent power to detect an effect size of 10% or greater.     Matern
# 	 28 	 ave good power to detect a 5% effect size, and excellent power to detec
# 	 28 	 (Units)    Mean  SD  Minimal  effect size  for 80%  power    Power for
# 	 29 	 ave good power to detect a 2% effect size, and  excellent power to dete
# HIV-HIV-2016-R-E.pdf 452
# HIV-HIV-2019-H-S.pdf 242
# 	 10 	 variates in order to  achieve effect estimates with greater precision.
# 	 13 	 ional cohort  studies showing reductions in HIV transmission by ART in
# 	 14 	 Finally, ART (despite 10-fold reductions in drug price over the last d
# 	 44 	 dy power and the precision of effect  estimates if communities are matched we
# 	 48 	 d to improve the precision of effect  estimates, to identify the causal effec
# 	 54 	  improve the precision of our effect estimates, by  making use of individual
# 	 57 	 hould  provide a conservative effect estimate given the potential for covar
# 	 57 	 mately 2%. Figure 1 shows the effect size we are powered to detect unde
# 	 58 	 sample sizes), homogeneity in effect size, and a  constant coefficient
# 	 58 	 stigate heterogeneity  in the effect size. By this method of simulation
# 	 71 	  This benefit may accrue from reductions in  immune activation and sys
# 	 97 	 ional cohort  studies showing reductions in HIV transmission by ART in
# 	 98 	 Finally, ART (despite 10-fold reductions in drug price over the last d
# 	 131 	 dy power and the precision of effect  estimates if communities are matched we
# 	 139 	 hould  provide a conservative effect estimate given the potential for covar
# 	 139 	 mately 2%. Figure 1 shows the effect size we are powered to detect unde
# 	 152 	  This benefit may accrue from reductions in  immune activation and sys
# 	 176 	  and type I error control for effect estimates based on this approach.  2.5
# 	 181 	 on (km) and to detect smaller effect sizes under more plausible km value
# 	 182 	 000  2 0  2 5  3 0  3 5  4 0  Effect Size Detected with 80% Power for a
# 	 182 	 40 km=0.30 km=0.20  Figure 1: Effect size (in percent reduction) that w
# 	 183 	 there was a constant relative effect size of 35% within each region. Co
# 	 183 	 r. The x-axis is the absolute effect size in percent and the y-axis pow
# 	 183 	  E), even though the absolute effect size was increased.  2. Adjusting
# 	 183 	 imator and Scenario  Absolute Effect Size (in percent)  P o w  e r a  b
# 	 197 	 . URL http://dx.doi.org/10.1371%2Fjournal.pone. 0016986.  29
# 	 201 	 for baseline factors. Primary effect estimates will be reported on a relativ
# 	 206 	  and type I error control for effect estimates based on this approach.  In t
# 	 210 	 on (km) and to detect smaller effect sizes under more plausible km value
# 	 211 	 200 3400  2 5  3 0  3 5  4 0  Effect Size Detected with 80% Power for a
# 	 211 	 =0.4 km=0.3 km=0.2  Figure 1: Effect size (in percent reduction) that w
# 	 211 	 400  2 0  2 5  3 0  3 5  4 0  Effect Size Detected with 80% Power   Wit
# 	 211 	 m from 0.3 to 0.25  Figure 2: Effect size (in percent reduction) that w
# 	 237 	 . URL http://dx.doi.org/10.1371%2Fjournal.pone. 0016986.  [35]
# NTD-Filariasis-2019-Weil-DOLF IDA Haiti.pdf 67
# 	 29 	 , 80%  power for detecting an effect size of 30%). The primary endpoint
# MAT-MAT-2018-G-F.pdf 60
# 	 9 	 rnal and child mortality, and reductions in the size   and cost of ele
# 	 25 	 s per 1000 deliveries, target reductions of 20% to 25%, at ICC of 0.00
# EDD-R-2017-G-V.pdf 125
# 	 53 	 icacy, there were substantial reductions in shedding (at any time) in
# MAT-HIV-2016-Fowler-PROMISE.pdf 902
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 57 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 57 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 57 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 58 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 135 	  the potential  absolute risk reductions associated with treatment in
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 150 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 181 	 ry precisely, and substantial reductions in plasma HIV  RNA concentrat
# 	 196 	 dels for estimating treatment effect sizes.  In light of the conservativ
# 	 325 	 d the potential absolute risk reductions associated with treatment  in
# 	 351 	 ry precisely, and substantial reductions in plasma HIV RNA concentrati
# 	 363 	 dels for estimating treatment effect sizes. In light of  the conservativ
# 	 372 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 372 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 372 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 372 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 372 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 372 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 372 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 372 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 373 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 373 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 373 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 474 	 d=Search&Term=%22Squires%20K%22%5BAuthor%5D&itool=EntrezSystem
# 	 474 	 =Search&Term=%22Pozniak%20AL%22%5BAuthor%5D&itool=EntrezSystem
# 	 474 	 rch&Term=%22Pierone%20G%20Jr%22%5BAuthor%5D&itool=EntrezSystem
# 	 474 	 &Cmd=Search&Term=%22Study%20907%20Team%22%5BCorporate%20Author
# 	 474 	 h&Term=%22Study%20907%20Team%22%5BCorporate%20Author%5D&itool=
# 	 474 	 ch&Term=%22Van%20Rompay%20KK%22%5BAuthor%5D&itool=EntrezSystem
# 	 474 	 &Term=%22Durand-Gasselin%20L%22%5BAuthor%5D&itool=EntrezSystem
# 	 474 	 Search&Term=%22Brignolo%20LL%22%5BAuthor%5D&itool=EntrezSystem
# 	 559 	 d the potential absolute risk reductions associated with treatment in
# 	 575 	 Cmd=Search&Term=%22Emery%20S%22%5BAuthor%5D&itool=EntrezSystem
# 	 575 	 =Search&Term=%22Neuhaus%20JA%22%5BAuthor%5D&itool=EntrezSystem
# 	 575 	 Search&Term=%22Phillips%20AN%22%5BAuthor%5D&itool=EntrezSystem
# 	 588 	 ry precisely, and substantial reductions in plasma HIV RNA concentrati
# 	 590 	 e in power, provided that the effect size in these two extra days is co
# 	 593 	 formed to examine whether the effect size for the primary efficacy  ana
# 	 607 	 dels for estimating treatment effect sizes.  In light of  the conservati
# 	 748 	 d the potential absolute risk reductions associated with treatment in
# 	 777 	 ry precisely, and substantial reductions in plasma HIV RNA concentrati
# 	 779 	 e in power, provided that the effect size in these two extra days in co
# 	 782 	 formed to examine whether the effect size for the primary efficacy  ana
# 	 791 	 dels for estimating treatment effect sizes. In light of  the conservativ
# TB-TB-2018-H-A.pdf 365
# HIV-HIV-2016-HVTN114.pdf 126
# 	 17 	 imens elicited similar 61-64% reductions in the per challenge risk of
# 	 32 	 oups for detecting a range of effect sizes. Effect size is the differenc
# 	 32 	 ting a range of effect sizes. Effect size is the difference of means pe
# 	 32 	 mple,  the power of detecting effect size of 1 between 2 groups of size
# 	 32 	 p means corresponding to this effect size will depend on the variation
# 	 32 	 Difference in 2 group Means   Effect Size n1 = n2 = 18 n1 = n2 = 36 n1
# 	 34 	 onses, the power of detecting effect size of 1 between 2  groups of siz
# HIV-HIV-2018-Long-acting Cabotegravir Plus Long-acting Rilpivirine.pdf 242
# 	 29 	  Dose Modifications:  No dose reductions, modifications, or changes in
# 	 59 	  Dose Modifications:  No dose reductions, modifications, or changes in
# 	 64 	 3) 53 (87) 157 (87) 46 (74)  95%CI  Proportion  (82, 98) (74,
# 	 64 	 5) 53 (87) 156 (86) 46 (74)  95%CI  Proportion  (78, 95) (76,
# 	 64 	 0) 53 (87) 149 (82) 44 (71)  95%CI  Proportion  (70, 90) (70,
# 	 64 	 5) 51 (84) 137 (76) 39 (63)  95%CI  Proportion  (57,80) (64,86
# 	 65 	 K Parameter (Geometric mean [95%CI] (CVb%)  AUC(0-) (g.h/mL)
# 	 68 	 K Parameter (Geometric mean [95%CI] (CVb%)  AUC(0- )  (g•h/m
# 	 75 	 K Parameter (Geometric mean [95%CI] (CVb%)  AUC(0- )  (g•h/m
# 	 143 	 ce.  No toxicity-related dose reductions of IP will be allowed.  IP sh
# NUT-S-2018-R-S.pdf 113
# 	 8 	 ical period leads to greater  reductions in child undernutrition than
# 	 43 	 family ration.  The estimated effect size is therefore  set to 0.325 HA
# 	 43 	  (and the small difference in effect size found between Haiti [with  fo
# 	 98 	 amily ration.  The estimated  effect size is therefore set to 0.325 HAZ
# 	 98 	 (and the small difference in  effect size found in Haiti and Peru), the
# VAC-Tdap-2019-Sancovski-A Post-marketing, Observational, Retrospective.pdf 82
# 	 50 	 . -Early miscarriage:  Up to 20%of  pregnancies. -Late miscarr
# NTD-t-2017-M-E.pdf 118
# 	 92 	 ov/pubmed?term=%22Camara%20M%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 ov/pubmed?term=%22Camara%20O%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 v/pubmed?term=%22Ilboudo%20H%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 v/pubmed?term=%22Sakande%20H%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 nih.gov/pubmed?term=%22Kabor%C3%A9%20J%22%5BAuthor%5D http://w
# 	 92 	 .gov/pubmed?term=%22Kabor%C3%A9%20J%22%5BAuthor%5D http://www.
# 	 92 	 bmed?term=%22Kabor%C3%A9%20J%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 gov/pubmed?term=%22N'Dri%20L%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 pubmed?term=%22Jamonneau%20V%22%5BAuthor%5D http://www.ncbi.nl
# 	 92 	 /pubmed?term=%22Bucheton%20B%22%5BAuthor%5D http://www.ncbi.nl
# MAL-M-2018-D-C.pdf 74
# NTD-D-2017-S-P.pdf 85
# HIV-HIV-2016-Garrett-HVTN108.pdf 155
# 	 51 	 very low chance of achieving 40%VE;  note that a perfect binar
# 	 51 	 ery low chance of  achieving 40%VE.   4. The fourth category i
# 	 51 	 ery  low chance of achieving 40%VE.
# HIV-HIV-2018-Labhardt-CASCADE.pdf 90
# TB-TB-2019-Dawson-A Phase 2 Open‐Label Partially .pdf 112
# MAL-MAL-2018-Dorsey-PROMOTE Birth Cohort 1.pdf 94
# 	 14 	 nd 51I mutations (OR = 10.7, 95%CI 1.8-64.4, p = 0.009).    We
# PNE-P-2019-C-P.pdf 91
# 	 88 	 ns Program Network. Sustained reductions in invasive pneumococcal  dis
# 	 88 	 .org/content/documents/21252030%20Agenda%20for%20Sustaina ble%
# HIV-HIV-2019-Venter-ADVANCE.pdf 184
# 	 44 	 ivsoc.org/upload/documents/2013%20ART%20Guidelines- Short%20Co
# 	 44 	 FINAL%20draft%20guidelines%2014%20March%202013.pdf.  Accessed
# 	 44 	 ivsoc.org/upload/documents/2013%20ART%20Guidelines-Short%20Com
# 	 44 	 FINAL%20draft%20guidelines%2014%20March%202013.pdf http://www.
# 	 44 	 ivsoc.org/upload/documents/2013%20ART%20Guidelines-Short%20Com
# 	 44 	 FINAL%20draft%20guidelines%2014%20March%202013.pdf
# 	 100 	 ivsoc.org/upload/documents/2013%20ART%20Guidelines- Short%20Co
# 	 100 	 FINAL%20draft%20guidelines%2014%20March%202013.pdf. Accessed 4
# 	 100 	 ivsoc.org/upload/documents/2013%20ART%20Guidelines-Short%20Com
# 	 100 	 FINAL%20draft%20guidelines%2014%20March%202013.pdf http://www.
# 	 100 	 ivsoc.org/upload/documents/2013%20ART%20Guidelines-Short%20Com
# 	 100 	 FINAL%20draft%20guidelines%2014%20March%202013.pdf http://hivt
# HIV-HIV-2019-K-C.pdf 191
# 	 11 	 ce was reported to be 18.4% (95%CI  16.1-21.1) in the Northern
# 	 12 	  Rustenburg [14], 6.5/100wy (95%CI 4.4–9.2) in Vulindlela,   6
# 	 12 	  in Vulindlela,   6.4/100wy (95%CI 2.6–13.2) in Durban 14.8/10
# 	 12 	 lela)  women  was 9.0/100wy (95%CI 5.3-14.3) and  9.1/100wy  (
# 	 12 	 I 5.3-14.3) and  9.1/100wy  (95%CI 6.6-12.3) respectively  in
# 	 25 	 alence increased from 32.4% (95%CI 27.6-37.6) in 2001 to  40.0
# 	 25 	 ated  mortality rate of 5.2 (95%CI 2.9-7.5) /100pyo in young w
# PNE-Pneumonia-2019-Alexander-LEAP2.pdf 175
# 	 20 	 the inverse  variance of each effect size) pooled population from this
# 	 81 	  the inverse variance of each effect size) pooled  population from this
# MAT-Cervical Disease-2019-Greene-LEEP.pdf 296
# 	 96 	 page are based on a power of 80%to 2012   detect a treatment g
# TB-TB-2018-Churchyard-Bedaquiline-Delamanid.pdf 119
# 	 19 	 2% and 25%, respectively, but reductions in BDQ and  M2 metabolite con
# MAL-Malaria-2019-Foy-RIMDAMAL.pdf 58
# 	 14 	 ial capacity, and significant reductions  (>77%) in sporozoite rates f
# 	 14 	  While very transient, these  reductions are in-line with changes seen
# 	 17 	 ed, and result in significant reductions in Plasmodium spp. transmissi
# TB-TB-2019-N-S.pdf 224
# 	 82 	 l outcome and a mortality of 11%11.    Van Deun et al (2010)1
# 	 87 	 pared to 125  days, HR 2.44, 95%CI 1.57-3.80).  However, there
# NUT-Stunting-2019-Humphrey-SHINE.pdf 91
# 	 25 	 oup we will be able to detect effect sizes ranging from 35% to 40% of on
# 	 25 	 ve, we will be able to detect effect sizes  on the order of 25% of one s
# 	 25 	   sampled per cluster.  These effect sizes are small compared to the obs
# 	 90 	 /pubmed?term=%22Zijenah%20LS%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 /pubmed?term=%22Humphrey%20J%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 du/pubmed?term=%22Nathoo%20K%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 du/pubmed?term=%22Malaba%20L%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 ubmed?term=%22Zvandasara%20P%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 u/pubmed?term=%22Mahomva%20A%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 edu/pubmed?term=%22Iliff%20P%22%5BAuthor%5D http://www.ncbi.nl
# 	 90 	 u/pubmed?term=%22Mbizvo%20MT%22%5BAuthor%5D
# PNE-Pneumonia-2018-Keenan-Mortality Reduction After Oral Azithromycin.pdf 184
# 	 160 	 ovide  80% power to detect an effect size of 35%.  9
# 	 163 	  • The effect size is 0.15.  The number of clust
# 	 163 	 Z. Zhou, pers. comm.).  • The effect size is 0.15.  The number of clust
# 	 164 	 to follow-up per year.  • The effect size is 0.15.  The number of clust
# 	 176 	  follow-up per year.    • The effect size is 0.15.   • The desired powe
# 	 177 	 pproximately 41% power for an effect size  of 15% for Malawi alone.   3
# 	 177 	  Zhou, pers. comm.).    • The effect size is 0.15.    • The desired pow
# 	 177 	 proximately 84% power for an  effect size of 15% for Niger alone.
# 	 178 	  follow-up per year.    • The effect size is 0.15.    • The desired pow
# 	 178 	 proximately  31% power for an effect size of 15% for Tanzania alone.
# 	 178 	  than 80% power to  detect an effect size of approximately 0.10, or ten
# EDD-Cholera-2016-Qadri-Shanchol.pdf 124
# TB-TB-2020-John-Stewart-iTIPS.pdf 85
# 	 18 	 sequent   active TB (aOR 4.8 95%CI 1.2-19.7, p=0.03) and with
# VAC-Ecoli-2019-Qadri-ETVAX.pdf 65
# HIV-HIV-2018-Havlir-SEARCH.pdf 101
# 	 14 	 ional cohort  studies showing reductions in HIV transmission by ART in
# 	 15 	 Finally, ART (despite 10-fold reductions in drug price over the last d
# 	 60 	 y power  and the precision of effect estimates if communities are matched we
# 	 68 	 should provide a conservative effect estimate given the potential for covar
# 	 68 	 tely 1.3%. Figure 1 shows the effect size we are powered to detect in P
# 	 81 	  This benefit may accrue from reductions in  immune activation and sys
# HIV-HIV-2016-Kurth-High-yield HIV testing, facilitated linkage to care.pdf 111
# 	 62 	 needed to detect a particular effect size with at least 80%  power. Rat
# HIV-HIV-2017-Corey-HVTN704-HPTN085.pdf 175
# 	 19 	 tically significant transient reductions in HIV viral load in adults w
# 	 44 	 f H1: PE > 0% under different effect sizes  PE = PE10 = PE30    Uncondit
# 	 47 	 mary null hypothesis H0: PE ≤ 0%with 900 control  recipients a
# 	 50 	 relevant prevention  efficacy effect sizes if annual incidence rates are
# 	 65 	 correlate of protection (with effect size 15%, 60%, 85% efficacy)  at t
# 	 66 	 r for the PE = 15%,  60%, 85% effect size if 25%, 50%, 25% of PYRs at r
# 	 69 	 e Wilcoxon rank sum test. The effect size indexing a difference between
# 	 69 	 e two groups. Four correlates effect sizes are  considered, ranging from
# 	 69 	 ed, ranging from the weakest (Effect Size 1) to the strongest (Effect S
# 	 69 	 ect Size 1) to the strongest (Effect Size 4). The  results show that th
# 	 69 	 e is moderate power to detect Effect Size 3 phenotypic sieve effects  (
# 	 70 	 group  breakthrough HIV-1s.   Effect Size 3 is biologically plausible b
# 	 70 	 or each of the four specified effect sizes PE(x) in Figure  4-12. For ex
# 	 70 	 igure  4-12. For example, for Effect Size 3, the most susceptible 11.6%
# 	 70 	 cacies is plausible. For this effect size there is 79.3% power  to dete
# 	 70 	  = 0%) for the four different effect sizes studied in Figure 4-12   PE(x
# 	 70 	 tudied in Figure 4-12   PE(x) Effect Size in Figure 1-16 Susceptible  [
# 	 70 	 00%]   Resistant  [PE = 0%]   Effect Size 4 41.9% 23.3%   Effect Size 3
# 	 70 	   Effect Size 4 41.9% 23.3%   Effect Size 3 11.6% 2.8%   Effect Size 2
# 	 70 	    Effect Size 3 11.6% 2.8%   Effect Size 2 1.0% <0.1%   Effect Size 1
# 	 70 	    Effect Size 2 1.0% <0.1%   Effect Size 1 <0.1% <0.1%   Null Hypothes
# 	 79 	 hloride for Injection USP,  0.9%to the 100 mL IV bag of Sodium
# HIV-HIV-2016_Tebas-A5354.pdf 133
# HIV-HIV-2016-Weinberg-NICHP1091.pdf 93
# MAL-Malaria-2016-Valencia-Phase 1 and 2a Clinical.pdf 61
# 	 47 	 y group and percentages and  95%CI intervals will be estimated
# NTD-Filariasis-2019-Weil-DOLF IDA Indonesia.pdf 108
# 	 31 	 A, 80% power for detecting an effect size of 30%). The primary endpoint
# VAC-M-2015-L-W.pdf 193
# 	 50 	 nalysis: calculate two-sided 95%CI for the difference in propo
# 	 51 	  91.   • Calculate two-sided 95%CI for difference in proportio
# 	 52 	 bserved by day 364 the upper 95%CI  will be 3.6% (1 in 28).
# 	 53 	  is to calculate the 2-sided 95%CI for the difference in propo
# 	 114 	 nalysis: calculate two-sided 95%CI for the difference in propo
# 	 115 	  91.   • Calculate two-sided 95%CI for difference in proportio
# 	 116 	 bserved by day 364 the upper 95%CI  will be 3.6% (1 in 28).
# 	 117 	  is to calculate the 2-sided 95%CI for the difference in propo
# 	 141 	 etation on examination of the effect size, confidence interval and p va
# 	 163 	 tes  Seropositivity  *    OR 95%CI P   value Age (months):

# %%
len(files)
# Out:
# 76
